# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_names = []
for i in range(1, 11):
    item = 'load_stimulus_exp{}.csv'.format(i)
    file_names.append(item)

folder_path = os.path.abspath(os.path.join("../datasets"))
load_stimulus_global = pd.DataFrame()

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_csv(file_path)
    load_stimulus_global = pd.concat([load_stimulus_global, df], ignore_index=True)

# Save the combined DataFrame as a new CSV file
abs_path = os.path.join("..\\datasets", 'load_stimulus_global.csv')
load_stimulus_global.to_csv(abs_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 11
#       9 for file_name in file_names:
#      10     file_path = os.path.join(folder_path, file_name)
# ---> 11     df = pd.read_csv(file_path)
#      12     load_stimulus_global = pd.concat([load_stimulus_global, df], ignore_index=True)
#      14 # Save the combined DataFrame as a new CSV file
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Qiong\\ml_for_highspeed_worlds\\Dag\\dag-2\\datasets\\load_stimulus_exp1.csv'

# %%
current_dir = os.getcwd()

exp_ls = "load_stimulus_global.csv"
#exp_ls="load_stimulus_exp1.csv"
file_path = os.path.abspath(os.path.join("..\\datasets", exp_ls))

data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1499 entries, 0 to 44
# Data columns (total 64 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   input_rate                          1499 non-null   float64
#  1   output_rate                         1499 non-null   float64
#  2   latency                             1499 non-null   float64
#  3   flow_tracker_instructions           1499 non-null   float64
#  4   nf_router_instructions              1499 non-null   float64
#  5   ndpi_stats_instructions             1499 non-null   float64
#  6   payload_scan_instructions           1499 non-null   float64
#  7   bridge_instructions                 1499 non-null   float64
#  8   flow_tracker_branches               1499 non-null   float64
#  9   nf_router_branches                  1499 non-null   float64
#  10  ndpi_stats_branches                 1499 non-null   float64
#  11  payload_scan_branches               1499 non-null   float64
#  12  bridge_branches                     1499 non-null   float64
#  13  flow_tracker_branch-misses          1499 non-null   float64
#  14  nf_router_branch-misses             1499 non-null   float64
#  15  ndpi_stats_branch-misses            1499 non-null   float64
#  16  payload_scan_branch-misses          1499 non-null   float64
#  17  bridge_branch-misses                1499 non-null   float64
#  18  flow_tracker_branch-load-misses     1499 non-null   float64
#  19  nf_router_branch-load-misses        1499 non-null   float64
#  20  ndpi_stats_branch-load-misses       1499 non-null   float64
#  21  payload_scan_branch-load-misses     1499 non-null   float64
#  22  bridge_branch-load-misses           1499 non-null   float64
#  23  flow_tracker_cache-misses           1499 non-null   float64
#  24  nf_router_cache-misses              1499 non-null   float64
#  25  ndpi_stats_cache-misses             1499 non-null   float64
#  26  payload_scan_cache-misses           1499 non-null   float64
#  27  bridge_cache-misses                 1499 non-null   float64
#  28  flow_tracker_cache-references       1499 non-null   float64
#  29  nf_router_cache-references          1499 non-null   float64
#  30  ndpi_stats_cache-references         1499 non-null   float64
#  31  payload_scan_cache-references       1499 non-null   float64
#  32  bridge_cache-references             1499 non-null   float64
#  33  flow_tracker_cycles                 1499 non-null   float64
#  34  nf_router_cycles                    1499 non-null   float64
#  35  ndpi_stats_cycles                   1499 non-null   float64
#  36  payload_scan_cycles                 1499 non-null   float64
#  37  bridge_cycles                       1499 non-null   float64
#  38  flow_tracker_L1-dcache-load-misses  1499 non-null   float64
#  39  nf_router_L1-dcache-load-misses     1499 non-null   float64
#  40  ndpi_stats_L1-dcache-load-misses    1499 non-null   float64
#  41  payload_scan_L1-dcache-load-misses  1499 non-null   float64
#  42  bridge_L1-dcache-load-misses        1499 non-null   float64
#  43  flow_tracker_L1-dcache-loads        1499 non-null   float64
#  44  nf_router_L1-dcache-loads           1499 non-null   float64
#  45  ndpi_stats_L1-dcache-loads          1499 non-null   float64
#  46  payload_scan_L1-dcache-loads        1499 non-null   float64
#  47  bridge_L1-dcache-loads              1499 non-null   float64
#  48  flow_tracker_LLC-load-misses        1499 non-null   float64
#  49  nf_router_LLC-load-misses           1499 non-null   float64
#  50  ndpi_stats_LLC-load-misses          1499 non-null   float64
#  51  payload_scan_LLC-load-misses        1499 non-null   float64
#  52  bridge_LLC-load-misses              1499 non-null   float64
#  53  flow_tracker_LLC-stores             1499 non-null   float64
#  54  nf_router_LLC-stores                1499 non-null   float64
#  55  ndpi_stats_LLC-stores               1499 non-null   float64
#  56  payload_scan_LLC-stores             1499 non-null   float64
#  57  bridge_LLC-stores                   1499 non-null   float64
#  58  flow_tracker_LLC-loads              1499 non-null   float64
#  59  nf_router_LLC-loads                 1499 non-null   float64
#  60  ndpi_stats_LLC-loads                1499 non-null   float64
#  61  payload_scan_LLC-loads              1499 non-null   float64
#  62  bridge_LLC-loads                    1499 non-null   float64
#  63  Unnamed: 0.1                        45 non-null     float64
# dtypes: float64(64)
# memory usage: 761.2 KB

# %%
# heatmap
import seaborn as sns   
corr = data.corr()
plt.figure()
sns.heatmap(corr, cmap="coolwarm", annot=False, fmt=".2f")
plt.show()

# %%
# Reset the index starting from 0
data = data.reset_index(drop=True)
data
# Out:
#        input_rate  output_rate  latency  flow_tracker_instructions  \
# 0      184.956628   183.017093   25.991               1.037270e+10
# 1      517.102853   528.319057   12.672               9.807607e+09
# 2      528.252899   528.300284    5.453               1.029055e+10
# 3      528.281269   528.262879   12.035               1.022163e+10
# 4      528.374269   528.357146    9.885               1.020038e+10
# ...           ...          ...      ...                        ...
# 1494  2113.213395  2110.138348    7.200               9.696371e+09
# 1495  2113.051748  2110.498911   15.434               9.801869e+09
# 1496  2113.063275  2110.307194   11.197               9.801007e+09
# 1497  2113.446832  2110.508682    9.949               9.804699e+09
# 1498  2113.159000  2110.369655   15.203               9.750416e+09
#
#       nf_router_instructions  ndpi_stats_instructions  \
# 0               1.100358e+10             1.109050e+10
# 1               1.101116e+10             1.101843e+10
# 2               1.028421e+10             1.107497e+10
# 3               1.101305e+10             1.100970e+10
# 4               1.090671e+10             1.097442e+10
# ...                      ...                      ...
# 1494            4.109314e+09             1.039996e+10
# 1495            4.107745e+09             1.039845e+10
# 1496            4.106248e+09             1.040421e+10
# 1497            4.113047e+09             1.040568e+10
# 1498            4.034292e+09             1.007323e+10
#
#       payload_scan_instructions  bridge_instructions  flow_tracker_branches  \
# 0                  1.129255e+10         1.110242e+10           2.026474e+09
# 1                  1.092338e+10         1.110717e+10           1.914203e+09
# 2                  1.120433e+10         1.109601e+10           2.013210e+09
# 3                  1.113345e+10         1.110011e+10           2.003568e+09
# 4                  1.110801e+10         1.099739e+10           2.000374e+09
# ...                         ...                  ...                    ...
# 1494               1.054275e+10         9.596474e+09           1.891752e+09
# 1495               1.039913e+10         9.701764e+09           1.875948e+09
# 1496               1.028907e+10         9.604891e+09           1.892953e+09
# 1497               1.042526e+10         9.809028e+09           1.893558e+09
# 1498               1.019748e+10         9.796915e+09           1.897420e+09
#
#       nf_router_branches  ...  nf_router_LLC-stores  ndpi_stats_LLC-stores  \
# 0           2.145019e+09  ...             1187278.0               411144.0
# 1           2.158891e+09  ...             1192687.0               422881.0
# 2           2.027344e+09  ...             1185122.0               419500.0
# 3           2.170894e+09  ...             1191518.0               419629.0
# 4           2.155497e+09  ...             1193583.0               410286.0
# ...                  ...  ...                   ...                    ...
# 1494        8.072155e+08  ...             4928241.0              1699685.0
# 1495        8.131446e+08  ...             4943013.0              1700063.0
# 1496        8.134800e+08  ...             4972417.0              1710116.0
# 1497        8.139116e+08  ...             4950357.0              1702913.0
# 1498        8.037506e+08  ...             4625439.0              1574538.0
#
#       payload_scan_LLC-stores  bridge_LLC-stores  flow_tracker_LLC-loads  \
# 0                    396848.0           856388.0               1043532.0
# 1                    396439.0           867070.0               1046231.0
# 2                    393803.0           854391.0               1034971.0
# 3                    394180.0           857864.0               1039429.0
# 4                    392936.0           854237.0               1043210.0
# ...                       ...                ...                     ...
# 1494                1594917.0          3870166.0               2957002.0
# 1495                1576709.0          3939566.0               2982183.0
# 1496                1573531.0          3918028.0               2989389.0
# 1497                1531491.0          3920478.0               2985770.0
# 1498                1480720.0          3563120.0               2802135.0
#
#       nf_router_LLC-loads  ndpi_stats_LLC-loads  payload_scan_LLC-loads  \
# 0               1596898.0             1257844.0                981158.0
# 1               1593752.0             1278065.0                988833.0
# 2               1593328.0             1271563.0                969735.0
# 3               1626552.0             1238004.0                992282.0
# 4               1576361.0             1219233.0                993850.0
# ...                   ...                   ...                     ...
# 1494            5745117.0             4780613.0               3524476.0
# 1495            5813833.0             4854854.0               3523967.0
# 1496            5765334.0             4846529.0               3545560.0
# 1497            5723658.0             4835926.0               3527712.0
# 1498            5158270.0             4521340.0               3347932.0
#
#       bridge_LLC-loads  Unnamed: 0.1
# 0            1766648.0           NaN
# 1            1768829.0           NaN
# 2            1771058.0           NaN
# 3            1810667.0           NaN
# 4            1720734.0           NaN
# ...                ...           ...
# 1494         5894068.0          40.0
# 1495         5830346.0          41.0
# 1496         5866319.0          42.0
# 1497         5919068.0          43.0
# 1498         5419765.0          44.0
#
# [1499 rows x 64 columns]

# %%
data.iloc[:, 1:3].plot(logy=True)
# Out:
# <Axes: >

# %%
corr = data.corr()
correlation_list = []
for i in range(1,2):
    for j in range(i+1, len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between output_rate and payload_scan_LLC-loads: 0.98
# Correlation between output_rate and payload_scan_L1-dcache-load-misses: 0.98
# Correlation between output_rate and payload_scan_cache-references: 0.98
# Correlation between output_rate and flow_tracker_LLC-loads: 0.98
# Correlation between output_rate and flow_tracker_L1-dcache-load-misses: 0.98
# Correlation between output_rate and flow_tracker_cache-references: 0.98
# Correlation between output_rate and payload_scan_LLC-stores: 0.97
# Correlation between output_rate and ndpi_stats_cache-references: 0.97
# Correlation between output_rate and ndpi_stats_L1-dcache-load-misses: 0.97
# Correlation between output_rate and ndpi_stats_LLC-loads: 0.97
# Correlation between output_rate and nf_router_LLC-loads: 0.97
# Correlation between output_rate and flow_tracker_LLC-stores: 0.97
# Correlation between output_rate and ndpi_stats_LLC-stores: 0.97
# Correlation between output_rate and nf_router_cache-references: 0.97
# Correlation between output_rate and nf_router_L1-dcache-load-misses: 0.97
# Correlation between output_rate and nf_router_LLC-stores: 0.97
# Correlation between output_rate and bridge_LLC-stores: 0.96
# Correlation between output_rate and bridge_cache-references: 0.95
# Correlation between output_rate and bridge_LLC-load-misses: 0.95
# Correlation between output_rate and bridge_L1-dcache-load-misses: 0.95
# Correlation between output_rate and flow_tracker_cache-misses: 0.95
# Correlation between output_rate and bridge_LLC-loads: 0.95
# Correlation between output_rate and flow_tracker_LLC-load-misses: 0.95
# Correlation between output_rate and ndpi_stats_cache-misses: 0.91
# Correlation between output_rate and payload_scan_cache-misses: 0.89
# Correlation between output_rate and bridge_cache-misses: 0.85
# Correlation between output_rate and nf_router_L1-dcache-loads: 0.82
# Correlation between output_rate and flow_tracker_L1-dcache-loads: 0.82
# Correlation between output_rate and nf_router_instructions: 0.81
# Correlation between output_rate and nf_router_branches: 0.81
# Correlation between output_rate and flow_tracker_branches: 0.81
# Correlation between output_rate and flow_tracker_instructions: 0.79
# Correlation between output_rate and bridge_L1-dcache-loads: 0.76
# Correlation between output_rate and bridge_branches: 0.76
# Correlation between output_rate and bridge_instructions: 0.76
# Correlation between output_rate and nf_router_cache-misses: 0.76
# Correlation between output_rate and nf_router_LLC-load-misses: 0.75
# Correlation between output_rate and ndpi_stats_branches: 0.72
# Correlation between output_rate and ndpi_stats_L1-dcache-loads: 0.72
# Correlation between output_rate and ndpi_stats_instructions: 0.72
# Correlation between output_rate and payload_scan_L1-dcache-loads: 0.71
# Correlation between output_rate and payload_scan_instructions: 0.71
# Correlation between output_rate and payload_scan_branches: 0.70
# Correlation between output_rate and ndpi_stats_LLC-load-misses: 0.67
# Correlation between output_rate and ndpi_stats_branch-misses: 0.55
# Correlation between output_rate and ndpi_stats_branch-load-misses: 0.55
# Correlation between output_rate and flow_tracker_branch-load-misses: 0.53
# Correlation between output_rate and flow_tracker_branch-misses: 0.53
# Correlation between output_rate and payload_scan_LLC-load-misses: 0.52
# Correlation between output_rate and bridge_branch-misses: 0.51
# Correlation between output_rate and bridge_branch-load-misses: 0.51
# Correlation between output_rate and payload_scan_branch-misses: 0.48
# Correlation between output_rate and payload_scan_branch-load-misses: 0.48
# Correlation between output_rate and nf_router_branch-load-misses: 0.44
# Correlation between output_rate and nf_router_branch-misses: 0.44
# Correlation between output_rate and Unnamed: 0.1: 0.27
# Correlation between output_rate and ndpi_stats_cycles: 0.14
# Correlation between output_rate and latency: 0.12
# Correlation between output_rate and bridge_cycles: 0.03
# Correlation between output_rate and nf_router_cycles: 0.02
# Correlation between output_rate and payload_scan_cycles: 0.02
# Correlation between output_rate and flow_tracker_cycles: 0.01

# %% [markdown]
# # Resource stimulus

# %%
resouce_stimulus_global = pd.DataFrame()
file_names = []

for i in range(3, 8):
    for j in [1,3]:
        for k in range(1,6):
            item = 'resource_stimulus_exp-{}-{}-{}.csv'.format(i,j,k)
            file_names.append(item)

file_names.remove('resource_stimulus_exp-3-1-1.csv')
print(file_names)

folder_path = os.path.abspath(os.path.join("../datasets"))
resource_stimulus_global = pd.DataFrame()

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_csv(file_path)
    resource_stimulus_global = pd.concat([resource_stimulus_global, df], ignore_index=True)

# Save the combined DataFrame as a new CSV file
abs_path = os.path.join("..\\datasets", 'resource_stimulus_global.csv')
resource_stimulus_global.to_csv(abs_path, index=False)
# Out:
# ['resource_stimulus_exp-3-1-2.csv', 'resource_stimulus_exp-3-1-3.csv', 'resource_stimulus_exp-3-1-4.csv', 'resource_stimulus_exp-3-1-5.csv', 'resource_stimulus_exp-3-3-1.csv', 'resource_stimulus_exp-3-3-2.csv', 'resource_stimulus_exp-3-3-3.csv', 'resource_stimulus_exp-3-3-4.csv', 'resource_stimulus_exp-3-3-5.csv', 'resource_stimulus_exp-4-1-1.csv', 'resource_stimulus_exp-4-1-2.csv', 'resource_stimulus_exp-4-1-3.csv', 'resource_stimulus_exp-4-1-4.csv', 'resource_stimulus_exp-4-1-5.csv', 'resource_stimulus_exp-4-3-1.csv', 'resource_stimulus_exp-4-3-2.csv', 'resource_stimulus_exp-4-3-3.csv', 'resource_stimulus_exp-4-3-4.csv', 'resource_stimulus_exp-4-3-5.csv', 'resource_stimulus_exp-5-1-1.csv', 'resource_stimulus_exp-5-1-2.csv', 'resource_stimulus_exp-5-1-3.csv', 'resource_stimulus_exp-5-1-4.csv', 'resource_stimulus_exp-5-1-5.csv', 'resource_stimulus_exp-5-3-1.csv', 'resource_stimulus_exp-5-3-2.csv', 'resource_stimulus_exp-5-3-3.csv', 'resource_stimulus_exp-5-3-4.csv', 'resource_stimulus_exp-5-3-5.csv', 'resource_stimulus_exp-6-1-1.csv', 'resource_stimulus_exp-6-1-2.csv', 'resource_stimulus_exp-6-1-3.csv', 'resource_stimulus_exp-6-1-4.csv', 'resource_stimulus_exp-6-1-5.csv', 'resource_stimulus_exp-6-3-1.csv', 'resource_stimulus_exp-6-3-2.csv', 'resource_stimulus_exp-6-3-3.csv', 'resource_stimulus_exp-6-3-4.csv', 'resource_stimulus_exp-6-3-5.csv', 'resource_stimulus_exp-7-1-1.csv', 'resource_stimulus_exp-7-1-2.csv', 'resource_stimulus_exp-7-1-3.csv', 'resource_stimulus_exp-7-1-4.csv', 'resource_stimulus_exp-7-1-5.csv', 'resource_stimulus_exp-7-3-1.csv', 'resource_stimulus_exp-7-3-2.csv', 'resource_stimulus_exp-7-3-3.csv', 'resource_stimulus_exp-7-3-4.csv', 'resource_stimulus_exp-7-3-5.csv']

# %%
current_dir = os.getcwd()

exp_rs = "resource_stimulus_global.csv"

file_path = os.path.abspath(os.path.join("..\\datasets", exp_rs))

data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2219 entries, 0 to 44
# Data columns (total 63 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   input_rate                          2219 non-null   float64
#  1   output_rate                         2219 non-null   float64
#  2   latency                             2219 non-null   float64
#  3   flow_tracker_instructions           2219 non-null   float64
#  4   nf_router_instructions              2219 non-null   float64
#  5   ndpi_stats_instructions             2219 non-null   float64
#  6   payload_scan_instructions           2219 non-null   float64
#  7   bridge_instructions                 2219 non-null   float64
#  8   flow_tracker_branches               2219 non-null   float64
#  9   nf_router_branches                  2219 non-null   float64
#  10  ndpi_stats_branches                 2219 non-null   float64
#  11  payload_scan_branches               2219 non-null   float64
#  12  bridge_branches                     2219 non-null   float64
#  13  flow_tracker_branch-misses          2219 non-null   float64
#  14  nf_router_branch-misses             2219 non-null   float64
#  15  ndpi_stats_branch-misses            2219 non-null   float64
#  16  payload_scan_branch-misses          2219 non-null   float64
#  17  bridge_branch-misses                2219 non-null   float64
#  18  flow_tracker_branch-load-misses     2219 non-null   float64
#  19  nf_router_branch-load-misses        2219 non-null   float64
#  20  ndpi_stats_branch-load-misses       2219 non-null   float64
#  21  payload_scan_branch-load-misses     2219 non-null   float64
#  22  bridge_branch-load-misses           2219 non-null   float64
#  23  flow_tracker_cache-misses           2219 non-null   float64
#  24  nf_router_cache-misses              2219 non-null   float64
#  25  ndpi_stats_cache-misses             2219 non-null   float64
#  26  payload_scan_cache-misses           2219 non-null   float64
#  27  bridge_cache-misses                 2219 non-null   float64
#  28  flow_tracker_cache-references       2219 non-null   float64
#  29  nf_router_cache-references          2219 non-null   float64
#  30  ndpi_stats_cache-references         2219 non-null   float64
#  31  payload_scan_cache-references       2219 non-null   float64
#  32  bridge_cache-references             2219 non-null   float64
#  33  flow_tracker_cycles                 2219 non-null   float64
#  34  nf_router_cycles                    2219 non-null   float64
#  35  ndpi_stats_cycles                   2219 non-null   float64
#  36  payload_scan_cycles                 2219 non-null   float64
#  37  bridge_cycles                       2219 non-null   float64
#  38  flow_tracker_L1-dcache-load-misses  2219 non-null   float64
#  39  nf_router_L1-dcache-load-misses     2219 non-null   float64
#  40  ndpi_stats_L1-dcache-load-misses    2219 non-null   float64
#  41  payload_scan_L1-dcache-load-misses  2219 non-null   float64
#  42  bridge_L1-dcache-load-misses        2219 non-null   float64
#  43  flow_tracker_L1-dcache-loads        2219 non-null   float64
#  44  nf_router_L1-dcache-loads           2219 non-null   float64
#  45  ndpi_stats_L1-dcache-loads          2219 non-null   float64
#  46  payload_scan_L1-dcache-loads        2219 non-null   float64
#  47  bridge_L1-dcache-loads              2219 non-null   float64
#  48  flow_tracker_LLC-load-misses        2219 non-null   float64
#  49  nf_router_LLC-load-misses           2219 non-null   float64
#  50  ndpi_stats_LLC-load-misses          2219 non-null   float64
#  51  payload_scan_LLC-load-misses        2219 non-null   float64
#  52  bridge_LLC-load-misses              2219 non-null   float64
#  53  flow_tracker_LLC-stores             2219 non-null   float64
#  54  nf_router_LLC-stores                2219 non-null   float64
#  55  ndpi_stats_LLC-stores               2219 non-null   float64
#  56  payload_scan_LLC-stores             2219 non-null   float64
#  57  bridge_LLC-stores                   2219 non-null   float64
#  58  flow_tracker_LLC-loads              2219 non-null   float64
#  59  nf_router_LLC-loads                 2219 non-null   float64
#  60  ndpi_stats_LLC-loads                2219 non-null   float64
#  61  payload_scan_LLC-loads              2219 non-null   float64
#  62  bridge_LLC-loads                    2219 non-null   float64
# dtypes: float64(63)
# memory usage: 1.1 MB

# %%
# heatmap
import seaborn as sns   
corr = data.corr()
plt.figure()
sns.heatmap(corr, cmap="coolwarm", annot=False, fmt=".2f")
plt.show()

# %%
# Reset the index starting from 0
data = data.reset_index(drop=True)
data
# Out:
#        input_rate  output_rate  latency  flow_tracker_instructions  \
# 0      429.425476   398.089316   15.428               9.720476e+09
# 1     1949.338873  2110.707420    8.950               9.831880e+09
# 2     2112.982338  2110.569312   15.283               9.713599e+09
# 3     2112.723464  2109.757998    7.299               9.939057e+09
# 4     2113.162133  2111.318450   13.414               9.940065e+09
# ...           ...          ...      ...                        ...
# 2214  2113.213395  2110.138348    7.200               9.696371e+09
# 2215  2113.051748  2110.498911   15.434               9.801869e+09
# 2216  2113.063275  2110.307194   11.197               9.801007e+09
# 2217  2113.446832  2110.508682    9.949               9.804699e+09
# 2218  2113.159000  2110.369655   15.203               9.750416e+09
#
#       nf_router_instructions  ndpi_stats_instructions  \
# 0               9.405182e+09             1.045412e+10
# 1               9.509040e+09             1.055987e+10
# 2               9.377884e+09             1.056911e+10
# 3               9.506664e+09             1.055735e+10
# 4               9.426232e+09             1.034724e+10
# ...                      ...                      ...
# 2214            4.109314e+09             1.039996e+10
# 2215            4.107745e+09             1.039845e+10
# 2216            4.106248e+09             1.040421e+10
# 2217            4.113047e+09             1.040568e+10
# 2218            4.034292e+09             1.007323e+10
#
#       payload_scan_instructions  bridge_instructions  flow_tracker_branches  \
# 0                  1.047333e+10         9.680502e+09           1.907426e+09
# 1                  1.059076e+10         9.759741e+09           1.918631e+09
# 2                  1.044061e+10         9.641703e+09           1.899348e+09
# 3                  4.678122e+09         9.613500e+09           1.918889e+09
# 4                  4.634950e+09         9.626807e+09           1.904962e+09
# ...                         ...                  ...                    ...
# 2214               1.054275e+10         9.596474e+09           1.891752e+09
# 2215               1.039913e+10         9.701764e+09           1.875948e+09
# 2216               1.028907e+10         9.604891e+09           1.892953e+09
# 2217               1.042526e+10         9.809028e+09           1.893558e+09
# 2218               1.019748e+10         9.796915e+09           1.897420e+09
#
#       nf_router_branches  ...  flow_tracker_LLC-stores  nf_router_LLC-stores  \
# 0           1.872652e+09  ...                1725382.0             4634181.0
# 1           1.881937e+09  ...                1745726.0             4580293.0
# 2           1.863416e+09  ...                1746841.0             4626773.0
# 3           1.883064e+09  ...                1719819.0             4399026.0
# 4           1.869613e+09  ...                1725372.0             4570394.0
# ...                  ...  ...                      ...                   ...
# 2214        8.072155e+08  ...                1689299.0             4928241.0
# 2215        8.131446e+08  ...                1710497.0             4943013.0
# 2216        8.134800e+08  ...                1696416.0             4972417.0
# 2217        8.139116e+08  ...                1691373.0             4950357.0
# 2218        8.037506e+08  ...                1543736.0             4625439.0
#
#       ndpi_stats_LLC-stores  payload_scan_LLC-stores  bridge_LLC-stores  \
# 0                 1734795.0                1579920.0          3737329.0
# 1                 1743950.0                1560785.0          3762933.0
# 2                 1718510.0                1568986.0          3828364.0
# 3                 1696079.0                1454698.0          4054681.0
# 4                 1689680.0                1508686.0          4062025.0
# ...                     ...                      ...                ...
# 2214              1699685.0                1594917.0          3870166.0
# 2215              1700063.0                1576709.0          3939566.0
# 2216              1710116.0                1573531.0          3918028.0
# 2217              1702913.0                1531491.0          3920478.0
# 2218              1574538.0                1480720.0          3563120.0
#
#       flow_tracker_LLC-loads  nf_router_LLC-loads  ndpi_stats_LLC-loads  \
# 0                  2976658.0            6018772.0             4639650.0
# 1                  2938749.0            5937736.0             4674646.0
# 2                  2956195.0            5921459.0             4726595.0
# 3                  2863291.0            5760903.0             4842715.0
# 4                  2962416.0            5896009.0             4841785.0
# ...                      ...                  ...                   ...
# 2214               2957002.0            5745117.0             4780613.0
# 2215               2982183.0            5813833.0             4854854.0
# 2216               2989389.0            5765334.0             4846529.0
# 2217               2985770.0            5723658.0             4835926.0
# 2218               2802135.0            5158270.0             4521340.0
#
#       payload_scan_LLC-loads  bridge_LLC-loads
# 0                  3529356.0         5710953.0
# 1                  3475825.0         5686125.0
# 2                  3444223.0         5766608.0
# 3                  3238221.0         5702339.0
# 4                  3281081.0         5929688.0
# ...                      ...               ...
# 2214               3524476.0         5894068.0
# 2215               3523967.0         5830346.0
# 2216               3545560.0         5866319.0
# 2217               3527712.0         5919068.0
# 2218               3347932.0         5419765.0
#
# [2219 rows x 63 columns]

# %%
data.iloc[:, 1:3].plot(logy=True)
# Out:
# <Axes: >

# %%
corr = data.corr()
correlation_list = []
for i in range(1,2):
    for j in range(i+1, len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between output_rate and bridge_cache-references: 0.79
# Correlation between output_rate and bridge_L1-dcache-load-misses: 0.78
# Correlation between output_rate and bridge_LLC-loads: 0.78
# Correlation between output_rate and bridge_LLC-stores: 0.77
# Correlation between output_rate and ndpi_stats_LLC-loads: 0.54
# Correlation between output_rate and bridge_cycles: 0.51
# Correlation between output_rate and nf_router_LLC-stores: 0.51
# Correlation between output_rate and ndpi_stats_cache-references: 0.49
# Correlation between output_rate and nf_router_cache-references: 0.49
# Correlation between output_rate and bridge_branch-load-misses: 0.49
# Correlation between output_rate and bridge_branch-misses: 0.48
# Correlation between output_rate and nf_router_L1-dcache-load-misses: 0.48
# Correlation between output_rate and ndpi_stats_L1-dcache-load-misses: 0.48
# Correlation between output_rate and payload_scan_L1-dcache-load-misses: 0.48
# Correlation between output_rate and latency: 0.46
# Correlation between output_rate and nf_router_LLC-loads: 0.46
# Correlation between output_rate and bridge_instructions: 0.43
# Correlation between output_rate and bridge_branches: 0.43
# Correlation between output_rate and bridge_L1-dcache-loads: 0.43
# Correlation between output_rate and nf_router_branch-misses: 0.43
# Correlation between output_rate and nf_router_cycles: 0.43
# Correlation between output_rate and nf_router_branch-load-misses: 0.43
# Correlation between output_rate and nf_router_instructions: 0.43
# Correlation between output_rate and nf_router_branches: 0.42
# Correlation between output_rate and nf_router_L1-dcache-loads: 0.42
# Correlation between output_rate and payload_scan_LLC-loads: 0.39
# Correlation between output_rate and payload_scan_cache-references: 0.39
# Correlation between output_rate and flow_tracker_LLC-loads: 0.38
# Correlation between output_rate and flow_tracker_cache-references: 0.37
# Correlation between output_rate and flow_tracker_L1-dcache-load-misses: 0.36
# Correlation between output_rate and payload_scan_LLC-stores: 0.35
# Correlation between output_rate and ndpi_stats_LLC-stores: 0.33
# Correlation between output_rate and flow_tracker_LLC-stores: 0.33
# Correlation between output_rate and nf_router_cache-misses: 0.07
# Correlation between output_rate and nf_router_LLC-load-misses: 0.07
# Correlation between output_rate and bridge_cache-misses: 0.06
# Correlation between output_rate and flow_tracker_L1-dcache-loads: 0.05
# Correlation between output_rate and flow_tracker_branches: 0.05
# Correlation between output_rate and flow_tracker_instructions: 0.05
# Correlation between output_rate and ndpi_stats_L1-dcache-loads: 0.05
# Correlation between output_rate and ndpi_stats_branches: 0.04
# Correlation between output_rate and ndpi_stats_instructions: 0.04
# Correlation between output_rate and payload_scan_L1-dcache-loads: 0.04
# Correlation between output_rate and flow_tracker_branch-load-misses: 0.04
# Correlation between output_rate and payload_scan_branches: 0.04
# Correlation between output_rate and flow_tracker_branch-misses: 0.04
# Correlation between output_rate and payload_scan_instructions: 0.04
# Correlation between output_rate and payload_scan_branch-load-misses: 0.03
# Correlation between output_rate and flow_tracker_LLC-load-misses: 0.03
# Correlation between output_rate and ndpi_stats_branch-load-misses: 0.03
# Correlation between output_rate and ndpi_stats_branch-misses: 0.03
# Correlation between output_rate and payload_scan_branch-misses: 0.03
# Correlation between output_rate and flow_tracker_cycles: 0.03
# Correlation between output_rate and payload_scan_LLC-load-misses: 0.03
# Correlation between output_rate and ndpi_stats_LLC-load-misses: 0.02
# Correlation between output_rate and payload_scan_cycles: 0.02
# Correlation between output_rate and ndpi_stats_cache-misses: 0.02
# Correlation between output_rate and ndpi_stats_cycles: 0.01
# Correlation between output_rate and bridge_LLC-load-misses: 0.00
# Correlation between output_rate and flow_tracker_cache-misses: 0.00
# Correlation between output_rate and payload_scan_cache-misses: 0.00
