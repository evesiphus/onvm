# %%
import sys, re, os
import numpy as np
import pandas as pd

# %%
# Change the work directory to the parent
try:
    if chdir:
        pass
except:
    current_dir = os.getcwd()
    os.chdir(current_dir +"/..")
    os.path.abspath(os.curdir)

# %%
chdir = True

# %%
import zipfile

def unzip_file(zip_file_path, destination_folder):
    with zipfile.ZipFile(zip_file_path, 'r') as files:
        files.extractall(destination_folder)

# %%
load_stimulus_global = pd.DataFrame()
file_names = []

for i in range(3, 8):
    for j in [1,3]:
        for k in range(1,6):
            item = 'resource_stimulus_exp-{}-{}-{}.csv'.format(i,j,k)
            file_names.append(item)

file_names.remove('resource_stimulus_exp-3-1-1.csv')
print(file_names)
# Out:
# ['resource_stimulus_exp-3-1-2.csv', 'resource_stimulus_exp-3-1-3.csv', 'resource_stimulus_exp-3-1-4.csv', 'resource_stimulus_exp-3-1-5.csv', 'resource_stimulus_exp-3-3-1.csv', 'resource_stimulus_exp-3-3-2.csv', 'resource_stimulus_exp-3-3-3.csv', 'resource_stimulus_exp-3-3-4.csv', 'resource_stimulus_exp-3-3-5.csv', 'resource_stimulus_exp-4-1-1.csv', 'resource_stimulus_exp-4-1-2.csv', 'resource_stimulus_exp-4-1-3.csv', 'resource_stimulus_exp-4-1-4.csv', 'resource_stimulus_exp-4-1-5.csv', 'resource_stimulus_exp-4-3-1.csv', 'resource_stimulus_exp-4-3-2.csv', 'resource_stimulus_exp-4-3-3.csv', 'resource_stimulus_exp-4-3-4.csv', 'resource_stimulus_exp-4-3-5.csv', 'resource_stimulus_exp-5-1-1.csv', 'resource_stimulus_exp-5-1-2.csv', 'resource_stimulus_exp-5-1-3.csv', 'resource_stimulus_exp-5-1-4.csv', 'resource_stimulus_exp-5-1-5.csv', 'resource_stimulus_exp-5-3-1.csv', 'resource_stimulus_exp-5-3-2.csv', 'resource_stimulus_exp-5-3-3.csv', 'resource_stimulus_exp-5-3-4.csv', 'resource_stimulus_exp-5-3-5.csv', 'resource_stimulus_exp-6-1-1.csv', 'resource_stimulus_exp-6-1-2.csv', 'resource_stimulus_exp-6-1-3.csv', 'resource_stimulus_exp-6-1-4.csv', 'resource_stimulus_exp-6-1-5.csv', 'resource_stimulus_exp-6-3-1.csv', 'resource_stimulus_exp-6-3-2.csv', 'resource_stimulus_exp-6-3-3.csv', 'resource_stimulus_exp-6-3-4.csv', 'resource_stimulus_exp-6-3-5.csv', 'resource_stimulus_exp-7-1-1.csv', 'resource_stimulus_exp-7-1-2.csv', 'resource_stimulus_exp-7-1-3.csv', 'resource_stimulus_exp-7-1-4.csv', 'resource_stimulus_exp-7-1-5.csv', 'resource_stimulus_exp-7-3-1.csv', 'resource_stimulus_exp-7-3-2.csv', 'resource_stimulus_exp-7-3-3.csv', 'resource_stimulus_exp-7-3-4.csv', 'resource_stimulus_exp-7-3-5.csv']

# %%
folder_path = os.path.abspath(os.path.join("../dag-1/datasets"))
combined_df = pd.DataFrame()
for file_name in file_names:
    print(file_name)
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Save the combined DataFrame as a new CSV file
abs_path = os.path.join("..\\dag-1\\datasets", 'resource_stimulus_global_A-B-C.csv')
combined_df.to_csv(abs_path, index=False)

# Read the combined DataFrame from the CSV file
file_path = os.path.abspath('../dag-1/datasets/resource_stimulus_global_A-B-C.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
df = data.dropna()
df.info()
df.latency
# Out:
# resource_stimulus_exp-3-1-2.csv
# resource_stimulus_exp-3-1-3.csv
# resource_stimulus_exp-3-1-4.csv
# resource_stimulus_exp-3-1-5.csv
# resource_stimulus_exp-3-3-1.csv
# resource_stimulus_exp-3-3-2.csv
# resource_stimulus_exp-3-3-3.csv
# resource_stimulus_exp-3-3-4.csv
# resource_stimulus_exp-3-3-5.csv
# resource_stimulus_exp-4-1-1.csv
# resource_stimulus_exp-4-1-2.csv
# resource_stimulus_exp-4-1-3.csv
# resource_stimulus_exp-4-1-4.csv
# resource_stimulus_exp-4-1-5.csv
# resource_stimulus_exp-4-3-1.csv
# resource_stimulus_exp-4-3-2.csv
# resource_stimulus_exp-4-3-3.csv
# resource_stimulus_exp-4-3-4.csv
# resource_stimulus_exp-4-3-5.csv
# resource_stimulus_exp-5-1-1.csv
# resource_stimulus_exp-5-1-2.csv
# resource_stimulus_exp-5-1-3.csv
# resource_stimulus_exp-5-1-4.csv
# resource_stimulus_exp-5-1-5.csv
# resource_stimulus_exp-5-3-1.csv
# resource_stimulus_exp-5-3-2.csv
# resource_stimulus_exp-5-3-3.csv
# resource_stimulus_exp-5-3-4.csv
# resource_stimulus_exp-5-3-5.csv
# resource_stimulus_exp-6-1-1.csv
# resource_stimulus_exp-6-1-2.csv
# resource_stimulus_exp-6-1-3.csv
# resource_stimulus_exp-6-1-4.csv
# resource_stimulus_exp-6-1-5.csv
# resource_stimulus_exp-6-3-1.csv
# resource_stimulus_exp-6-3-2.csv
# resource_stimulus_exp-6-3-3.csv
# resource_stimulus_exp-6-3-4.csv
# resource_stimulus_exp-6-3-5.csv
# resource_stimulus_exp-7-1-1.csv
# resource_stimulus_exp-7-1-2.csv
# resource_stimulus_exp-7-1-3.csv
# resource_stimulus_exp-7-1-4.csv
# resource_stimulus_exp-7-1-5.csv
# resource_stimulus_exp-7-3-1.csv
# resource_stimulus_exp-7-3-2.csv
# resource_stimulus_exp-7-3-3.csv
# resource_stimulus_exp-7-3-4.csv
# resource_stimulus_exp-7-3-5.csv
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2229 entries, 0 to 45
# Data columns (total 63 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   input_rate                          2229 non-null   float64
#  1   output_rate                         2229 non-null   float64
#  2   latency                             2229 non-null   float64
#  3   firewall_instructions               2229 non-null   float64
#  4   nf_router_instructions              2229 non-null   float64
#  5   ndpi_stats_instructions             2229 non-null   float64
#  6   payload_scan_instructions           2229 non-null   float64
#  7   bridge_instructions                 2229 non-null   float64
#  8   firewall_branches                   2229 non-null   float64
#  9   nf_router_branches                  2229 non-null   float64
#  10  ndpi_stats_branches                 2229 non-null   float64
#  11  payload_scan_branches               2229 non-null   float64
#  12  bridge_branches                     2229 non-null   float64
#  13  firewall_branch-misses              2229 non-null   float64
#  14  nf_router_branch-misses             2229 non-null   float64
#  15  ndpi_stats_branch-misses            2229 non-null   float64
#  16  payload_scan_branch-misses          2229 non-null   float64
#  17  bridge_branch-misses                2229 non-null   float64
#  18  firewall_branch-load-misses         2229 non-null   float64
#  19  nf_router_branch-load-misses        2229 non-null   float64
#  20  ndpi_stats_branch-load-misses       2229 non-null   float64
#  21  payload_scan_branch-load-misses     2229 non-null   float64
#  22  bridge_branch-load-misses           2229 non-null   float64
#  23  firewall_cache-misses               2229 non-null   float64
#  24  nf_router_cache-misses              2229 non-null   float64
#  25  ndpi_stats_cache-misses             2229 non-null   float64
#  26  payload_scan_cache-misses           2229 non-null   float64
#  27  bridge_cache-misses                 2229 non-null   float64
#  28  firewall_cache-references           2229 non-null   float64
#  29  nf_router_cache-references          2229 non-null   float64
#  30  ndpi_stats_cache-references         2229 non-null   float64
#  31  payload_scan_cache-references       2229 non-null   float64
#  32  bridge_cache-references             2229 non-null   float64
#  33  firewall_cycles                     2229 non-null   float64
#  34  nf_router_cycles                    2229 non-null   float64
#  35  ndpi_stats_cycles                   2229 non-null   float64
#  36  payload_scan_cycles                 2229 non-null   float64
#  37  bridge_cycles                       2229 non-null   float64
#  38  firewall_L1-dcache-load-misses      2229 non-null   float64
#  39  nf_router_L1-dcache-load-misses     2229 non-null   float64
#  40  ndpi_stats_L1-dcache-load-misses    2229 non-null   float64
#  41  payload_scan_L1-dcache-load-misses  2229 non-null   float64
#  42  bridge_L1-dcache-load-misses        2229 non-null   float64
#  43  firewall_L1-dcache-loads            2229 non-null   float64
#  44  nf_router_L1-dcache-loads           2229 non-null   float64
#  45  ndpi_stats_L1-dcache-loads          2229 non-null   float64
#  46  payload_scan_L1-dcache-loads        2229 non-null   float64
#  47  bridge_L1-dcache-loads              2229 non-null   float64
#  48  firewall_LLC-load-misses            2229 non-null   float64
#  49  nf_router_LLC-load-misses           2229 non-null   float64
#  50  ndpi_stats_LLC-load-misses          2229 non-null   float64
#  51  payload_scan_LLC-load-misses        2229 non-null   float64
#  52  bridge_LLC-load-misses              2229 non-null   float64
#  53  firewall_LLC-stores                 2229 non-null   float64
#  54  nf_router_LLC-stores                2229 non-null   float64
#  55  ndpi_stats_LLC-stores               2229 non-null   float64
#  56  payload_scan_LLC-stores             2229 non-null   float64
#  57  bridge_LLC-stores                   2229 non-null   float64
#  58  firewall_LLC-loads                  2229 non-null   float64
#  59  nf_router_LLC-loads                 2229 non-null   float64
#  60  ndpi_stats_LLC-loads                2229 non-null   float64
#  61  payload_scan_LLC-loads              2229 non-null   float64
#  62  bridge_LLC-loads                    2229 non-null   float64
# dtypes: float64(63)
# memory usage: 1.1 MB
# Unnamed: 0
# 0     176.230
# 1     122.137
# 2     124.307
# 3     127.223
# 4     194.749
#        ...
# 41     14.156
# 42      9.344
# 43     10.467
# 44      9.972
# 45     10.419
# Name: latency, Length: 2229, dtype: float64

# %%
# heatmap
import matplotlib.pyplot as plt
import seaborn as sns   
corr = df.corr()
plt.figure()
sns.heatmap(corr, cmap="coolwarm", annot=False, fmt=".2f")
plt.show()

# %%
corr = data.corr()
correlation_list = []
for i in range(1,2):
    for j in range(i+1, len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between output_rate and bridge_cache-references: 0.80
# Correlation between output_rate and bridge_L1-dcache-load-misses: 0.80
# Correlation between output_rate and bridge_LLC-loads: 0.80
# Correlation between output_rate and bridge_LLC-stores: 0.79
# Correlation between output_rate and nf_router_cache-references: 0.57
# Correlation between output_rate and nf_router_LLC-stores: 0.57
# Correlation between output_rate and nf_router_L1-dcache-load-misses: 0.57
# Correlation between output_rate and nf_router_LLC-loads: 0.56
# Correlation between output_rate and payload_scan_cache-references: 0.55
# Correlation between output_rate and payload_scan_LLC-stores: 0.55
# Correlation between output_rate and ndpi_stats_cache-references: 0.54
# Correlation between output_rate and ndpi_stats_LLC-loads: 0.54
# Correlation between output_rate and payload_scan_L1-dcache-load-misses: 0.54
# Correlation between output_rate and payload_scan_LLC-loads: 0.54
# Correlation between output_rate and ndpi_stats_L1-dcache-load-misses: 0.53
# Correlation between output_rate and ndpi_stats_LLC-stores: 0.52
# Correlation between output_rate and firewall_L1-dcache-load-misses: 0.50
# Correlation between output_rate and firewall_cache-references: 0.50
# Correlation between output_rate and firewall_LLC-stores: 0.48
# Correlation between output_rate and firewall_LLC-loads: 0.48
# Correlation between output_rate and latency: 0.48
# Correlation between output_rate and bridge_cycles: 0.42
# Correlation between output_rate and firewall_cycles: 0.36
# Correlation between output_rate and firewall_instructions: 0.35
# Correlation between output_rate and firewall_L1-dcache-loads: 0.35
# Correlation between output_rate and firewall_branches: 0.35
# Correlation between output_rate and firewall_branch-misses: 0.34
# Correlation between output_rate and firewall_branch-load-misses: 0.34
# Correlation between output_rate and bridge_branch-misses: 0.34
# Correlation between output_rate and bridge_branch-load-misses: 0.34
# Correlation between output_rate and nf_router_cycles: 0.32
# Correlation between output_rate and nf_router_branch-misses: 0.31
# Correlation between output_rate and nf_router_branch-load-misses: 0.31
# Correlation between output_rate and nf_router_instructions: 0.26
# Correlation between output_rate and nf_router_L1-dcache-loads: 0.26
# Correlation between output_rate and nf_router_branches: 0.26
# Correlation between output_rate and bridge_instructions: 0.26
# Correlation between output_rate and bridge_branches: 0.26
# Correlation between output_rate and bridge_L1-dcache-loads: 0.26
# Correlation between output_rate and firewall_LLC-load-misses: 0.10
# Correlation between output_rate and firewall_cache-misses: 0.10
# Correlation between output_rate and payload_scan_L1-dcache-loads: 0.09
# Correlation between output_rate and payload_scan_branches: 0.09
# Correlation between output_rate and payload_scan_instructions: 0.09
# Correlation between output_rate and bridge_LLC-load-misses: 0.06
# Correlation between output_rate and ndpi_stats_L1-dcache-loads: 0.06
# Correlation between output_rate and ndpi_stats_branches: 0.06
# Correlation between output_rate and ndpi_stats_instructions: 0.05
# Correlation between output_rate and payload_scan_cache-misses: 0.05
# Correlation between output_rate and bridge_cache-misses: 0.04
# Correlation between output_rate and payload_scan_branch-load-misses: 0.04
# Correlation between output_rate and payload_scan_branch-misses: 0.04
# Correlation between output_rate and ndpi_stats_cache-misses: 0.04
# Correlation between output_rate and payload_scan_LLC-load-misses: 0.03
# Correlation between output_rate and ndpi_stats_cycles: 0.02
# Correlation between output_rate and nf_router_LLC-load-misses: 0.02
# Correlation between output_rate and ndpi_stats_branch-load-misses: 0.02
# Correlation between output_rate and ndpi_stats_branch-misses: 0.02
# Correlation between output_rate and ndpi_stats_LLC-load-misses: 0.02
# Correlation between output_rate and payload_scan_cycles: 0.01
# Correlation between output_rate and nf_router_cache-misses: 0.01

# %%
corr = data.corr()
correlation_list = []
for i in range(2,3):
    for j in range(len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between latency and latency: 1.00
# Correlation between latency and bridge_L1-dcache-load-misses: 0.59
# Correlation between latency and bridge_cache-references: 0.59
# Correlation between latency and bridge_LLC-stores: 0.59
# Correlation between latency and bridge_LLC-loads: 0.59
# Correlation between latency and ndpi_stats_LLC-stores: 0.59
# Correlation between latency and ndpi_stats_LLC-loads: 0.58
# Correlation between latency and ndpi_stats_cache-references: 0.58
# Correlation between latency and ndpi_stats_L1-dcache-load-misses: 0.58
# Correlation between latency and nf_router_L1-dcache-load-misses: 0.49
# Correlation between latency and nf_router_LLC-stores: 0.49
# Correlation between latency and nf_router_LLC-loads: 0.49
# Correlation between latency and nf_router_cache-references: 0.48
# Correlation between latency and output_rate: 0.48
# Correlation between latency and firewall_LLC-loads: 0.43
# Correlation between latency and firewall_L1-dcache-load-misses: 0.43
# Correlation between latency and firewall_cache-references: 0.42
# Correlation between latency and firewall_LLC-stores: 0.40
# Correlation between latency and payload_scan_LLC-loads: 0.38
# Correlation between latency and payload_scan_L1-dcache-load-misses: 0.36
# Correlation between latency and payload_scan_cache-references: 0.36
# Correlation between latency and payload_scan_LLC-stores: 0.34
# Correlation between latency and firewall_cycles: 0.30
# Correlation between latency and firewall_L1-dcache-loads: 0.30
# Correlation between latency and firewall_instructions: 0.30
# Correlation between latency and firewall_branch-misses: 0.30
# Correlation between latency and firewall_branches: 0.30
# Correlation between latency and firewall_branch-load-misses: 0.29
# Correlation between latency and ndpi_stats_cycles: 0.27
# Correlation between latency and nf_router_cycles: 0.26
# Correlation between latency and nf_router_branch-misses: 0.24
# Correlation between latency and nf_router_branch-load-misses: 0.24
# Correlation between latency and bridge_cycles: 0.23
# Correlation between latency and ndpi_stats_branch-load-misses: 0.23
# Correlation between latency and ndpi_stats_branch-misses: 0.23
# Correlation between latency and nf_router_branches: 0.20
# Correlation between latency and nf_router_L1-dcache-loads: 0.20
# Correlation between latency and nf_router_instructions: 0.20
# Correlation between latency and ndpi_stats_branches: 0.20
# Correlation between latency and ndpi_stats_instructions: 0.20
# Correlation between latency and ndpi_stats_L1-dcache-loads: 0.20
# Correlation between latency and payload_scan_L1-dcache-loads: 0.19
# Correlation between latency and payload_scan_branches: 0.18
# Correlation between latency and payload_scan_instructions: 0.18
# Correlation between latency and bridge_branch-misses: 0.17
# Correlation between latency and bridge_branch-load-misses: 0.17
# Correlation between latency and payload_scan_branch-load-misses: 0.15
# Correlation between latency and payload_scan_branch-misses: 0.15
# Correlation between latency and ndpi_stats_cache-misses: 0.13
# Correlation between latency and firewall_LLC-load-misses: 0.11
# Correlation between latency and ndpi_stats_LLC-load-misses: 0.11
# Correlation between latency and firewall_cache-misses: 0.11
# Correlation between latency and bridge_branches: 0.11
# Correlation between latency and bridge_instructions: 0.11
# Correlation between latency and bridge_L1-dcache-loads: 0.10
# Correlation between latency and payload_scan_cycles: 0.10
# Correlation between latency and input_rate: 0.09
# Correlation between latency and bridge_LLC-load-misses: 0.03
# Correlation between latency and bridge_cache-misses: 0.01
# Correlation between latency and payload_scan_LLC-load-misses: 0.01
# Correlation between latency and payload_scan_cache-misses: 0.01
# Correlation between latency and nf_router_LLC-load-misses: 0.01
# Correlation between latency and nf_router_cache-misses: 0.00

# %%
data = data.reset_index(drop=True)
data
data.iloc[:, :3].plot(logy=True)
# Out:
# <Axes: >
