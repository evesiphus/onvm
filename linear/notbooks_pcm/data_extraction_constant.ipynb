# %%
import pandas as pd
import os, re
import csv
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rc('font', family='serif')
plt.rcParams.update({'font.size': 11})

plt.rcParams['figure.dpi'] = 200
plt.rcParams['savefig.dpi'] = 300

# %%
# Metadata for specific SFC configurations
exp_ls = "const-4"

# %%
def print_headers(exp_type, exp_num, file):
    file_path = os.path.join("..\\data\\pcm", exp_type, exp_num, file)

    with open(file_path, newline='') as csvfile:
        reader = csv.reader(csvfile)
        headers = next(reader)  
        print("header：", headers)
    return headers

print_headers("const_input", exp_ls, "bridge-pcm_processed.csv")
# Out:
# header： ['System-Date', 'System-Time', 'Socket 0-EXEC', 'Socket 0-IPC', 'Socket 0-FREQ', 'Socket 0-AFREQ', 'Socket 0-L3MISS', 'Socket 0-L2MISS', 'Socket 0-L3HIT', 'Socket 0-L2HIT', 'Socket 0-L3MPI', 'Socket 0-L2MPI', 'Socket 0-L3OCC', 'Socket 0-READ', 'Socket 0-WRITE', 'Socket 0-LOCAL', 'Socket 0-TEMP', 'Socket 0-INST', 'Socket 0-ACYC', 'Socket 0-TIME(ticks)', 'Socket 0-PhysIPC', 'Socket 0-PhysIPC%', 'Socket 0-INSTnom', 'Socket 0-INSTnom%', 'Socket 1-EXEC', 'Socket 1-IPC', 'Socket 1-FREQ', 'Socket 1-AFREQ', 'Socket 1-L3MISS', 'Socket 1-L2MISS', 'Socket 1-L3HIT', 'Socket 1-L2HIT', 'Socket 1-L3MPI', 'Socket 1-L2MPI', 'Socket 1-L3OCC', 'Socket 1-READ', 'Socket 1-WRITE', 'Socket 1-LOCAL', 'Socket 1-TEMP', 'Socket 1-INST', 'Socket 1-ACYC', 'Socket 1-TIME(ticks)', 'Socket 1-PhysIPC', 'Socket 1-PhysIPC%', 'Socket 1-INSTnom', 'Socket 1-INSTnom%', 'SKT0 Core C-State-C0res%', 'SKT0 Core C-State-C1res%', 'SKT0 Core C-State-C3res%', 'SKT0 Core C-State-C6res%', 'SKT0 Core C-State-C7res%', 'SKT0 Package C-State-C0res%', 'SKT0 Package C-State-C2res%', 'SKT0 Package C-State-C3res%', 'SKT0 Package C-State-C6res%', 'SKT0 Package C-State-C7res%', 'SKT1 Core C-State-C0res%', 'SKT1 Core C-State-C1res%', 'SKT1 Core C-State-C3res%', 'SKT1 Core C-State-C6res%', 'SKT1 Core C-State-C7res%', 'SKT1 Package C-State-C0res%', 'SKT1 Package C-State-C2res%', 'SKT1 Package C-State-C3res%', 'SKT1 Package C-State-C6res%', 'SKT1 Package C-State-C7res%', 'Proc Energy (Joules)-SKT0', 'Proc Energy (Joules)-SKT1', 'DRAM Energy (Joules)-SKT0', 'DRAM Energy (Joules)-SKT1', 'LLCRDMISSLAT (ns)-SKT0', 'LLCRDMISSLAT (ns)-SKT1', 'UncFREQ (Ghz)-SKT0', 'UncFREQ (Ghz)-SKT1', 'Core7 (Socket 0)-EXEC', 'Core7 (Socket 0)-IPC', 'Core7 (Socket 0)-FREQ', 'Core7 (Socket 0)-AFREQ', 'Core7 (Socket 0)-L3MISS', 'Core7 (Socket 0)-L2MISS', 'Core7 (Socket 0)-L3HIT', 'Core7 (Socket 0)-L2HIT', 'Core7 (Socket 0)-L3MPI', 'Core7 (Socket 0)-L2MPI', 'Core7 (Socket 0)-L3OCC', 'Core7 (Socket 0)-C0res%', 'Core7 (Socket 0)-C1res%', 'Core7 (Socket 0)-C3res%', 'Core7 (Socket 0)-C6res%', 'Core7 (Socket 0)-C7res%', 'Core7 (Socket 0)-TEMP', 'Core7 (Socket 0)-INST', 'Core7 (Socket 0)-ACYC', 'Core7 (Socket 0)-TIME(ticks)', 'Core7 (Socket 0)-PhysIPC', 'Core7 (Socket 0)-PhysIPC%', 'Core7 (Socket 0)-INSTnom', 'Core7 (Socket 0)-INSTnom%', '-']
# ['System-Date',
#  'System-Time',
#  'Socket 0-EXEC',
#  'Socket 0-IPC',
#  'Socket 0-FREQ',
#  'Socket 0-AFREQ',
#  'Socket 0-L3MISS',
#  'Socket 0-L2MISS',
#  'Socket 0-L3HIT',
#  'Socket 0-L2HIT',
#  'Socket 0-L3MPI',
#  'Socket 0-L2MPI',
#  'Socket 0-L3OCC',
#  'Socket 0-READ',
#  'Socket 0-WRITE',
#  'Socket 0-LOCAL',
#  'Socket 0-TEMP',
#  'Socket 0-INST',
#  'Socket 0-ACYC',
#  'Socket 0-TIME(ticks)',
#  'Socket 0-PhysIPC',
#  'Socket 0-PhysIPC%',
#  'Socket 0-INSTnom',
#  'Socket 0-INSTnom%',
#  'Socket 1-EXEC',
#  'Socket 1-IPC',
#  'Socket 1-FREQ',
#  'Socket 1-AFREQ',
#  'Socket 1-L3MISS',
#  'Socket 1-L2MISS',
#  'Socket 1-L3HIT',
#  'Socket 1-L2HIT',
#  'Socket 1-L3MPI',
#  'Socket 1-L2MPI',
#  'Socket 1-L3OCC',
#  'Socket 1-READ',
#  'Socket 1-WRITE',
#  'Socket 1-LOCAL',
#  'Socket 1-TEMP',
#  'Socket 1-INST',
#  'Socket 1-ACYC',
#  'Socket 1-TIME(ticks)',
#  'Socket 1-PhysIPC',
#  'Socket 1-PhysIPC%',
#  'Socket 1-INSTnom',
#  'Socket 1-INSTnom%',
#  'SKT0 Core C-State-C0res%',
#  'SKT0 Core C-State-C1res%',
#  'SKT0 Core C-State-C3res%',
#  'SKT0 Core C-State-C6res%',
#  'SKT0 Core C-State-C7res%',
#  'SKT0 Package C-State-C0res%',
#  'SKT0 Package C-State-C2res%',
#  'SKT0 Package C-State-C3res%',
#  'SKT0 Package C-State-C6res%',
#  'SKT0 Package C-State-C7res%',
#  'SKT1 Core C-State-C0res%',
#  'SKT1 Core C-State-C1res%',
#  'SKT1 Core C-State-C3res%',
#  'SKT1 Core C-State-C6res%',
#  'SKT1 Core C-State-C7res%',
#  'SKT1 Package C-State-C0res%',
#  'SKT1 Package C-State-C2res%',
#  'SKT1 Package C-State-C3res%',
#  'SKT1 Package C-State-C6res%',
#  'SKT1 Package C-State-C7res%',
#  'Proc Energy (Joules)-SKT0',
#  'Proc Energy (Joules)-SKT1',
#  'DRAM Energy (Joules)-SKT0',
#  'DRAM Energy (Joules)-SKT1',
#  'LLCRDMISSLAT (ns)-SKT0',
#  'LLCRDMISSLAT (ns)-SKT1',
#  'UncFREQ (Ghz)-SKT0',
#  'UncFREQ (Ghz)-SKT1',
#  'Core7 (Socket 0)-EXEC',
#  'Core7 (Socket 0)-IPC',
#  'Core7 (Socket 0)-FREQ',
#  'Core7 (Socket 0)-AFREQ',
#  'Core7 (Socket 0)-L3MISS',
#  'Core7 (Socket 0)-L2MISS',
#  'Core7 (Socket 0)-L3HIT',
#  'Core7 (Socket 0)-L2HIT',
#  'Core7 (Socket 0)-L3MPI',
#  'Core7 (Socket 0)-L2MPI',
#  'Core7 (Socket 0)-L3OCC',
#  'Core7 (Socket 0)-C0res%',
#  'Core7 (Socket 0)-C1res%',
#  'Core7 (Socket 0)-C3res%',
#  'Core7 (Socket 0)-C6res%',
#  'Core7 (Socket 0)-C7res%',
#  'Core7 (Socket 0)-TEMP',
#  'Core7 (Socket 0)-INST',
#  'Core7 (Socket 0)-ACYC',
#  'Core7 (Socket 0)-TIME(ticks)',
#  'Core7 (Socket 0)-PhysIPC',
#  'Core7 (Socket 0)-PhysIPC%',
#  'Core7 (Socket 0)-INSTnom',
#  'Core7 (Socket 0)-INSTnom%',
#  '-']

# %%
def parse_seq(exp_type, exp_num, file, index=5):
    "Parse sequential data, specialized for the TX/RX/Latency experiments"
    tmp = []
    
    if file.startswith("latency_processed.csv"):
        with open(os.path.join("..\\data\\pcm", exp_type, exp_num, file)) as f:
            lines = f.readlines()[5:]# if exp_type == "ndpi-stats-random" else f.readlines()
            for i in range(len(lines)):
                try:
                    value = float(lines[i].strip()) / 1000
                except ValueError:
                    value= np.nan
                tmp.append(value)
    else:
        with open(os.path.join("..\\data\\pcm", exp_type, exp_num, file)) as f:
            next(f)
            for l in f:
                try:
                    value = float(l.strip().split(",")[index])
                except ValueError:
                    value = np.nan
                tmp.append(value)
                
    return tmp

# %%
def parse_reg(exp_type, exp_num, file, stat_name):
    stat = []
    file_path = os.path.join("..\\data\\pcm", exp_type, exp_num, file)

    with open(file_path, newline='') as csvfile:
        reader = csv.reader(csvfile)
        headers = next(reader)
        try:
            index = headers.index(stat_name)
        except ValueError:
            print(f"Column {stat_name} not found")
            return stat
        for row in reader:
            if len(row) <= index: 
                continue  

            raw_value = row[index]
            try:
                value = float(raw_value)
            except ValueError:
                value = raw_value
            stat.append(value)


    return stat

# %%
tx_stats = parse_seq("const_input", exp_ls,  "tx_stats.csv")
len(tx_stats)
# Out:
# 1988

# %%
rx_stats = parse_seq("const_input", exp_ls,  "rx_stats.csv")
len(rx_stats)
# Out:
# 1988

# %%
latency = parse_seq("const_input", exp_ls,  "latency_processed.csv")
len(latency)
# Out:
# 1989

# %%
bridge_L3MISS = parse_reg("const_input", exp_ls,  "ndpi_stats-pcm_processed.csv", "Socket 0-L3HIT")
print(len(bridge_L3MISS))
# Out:
# 1984

# %%
features = print_headers("const_input", exp_ls,  "ndpi_stats-pcm_processed.csv")
# Out:
# header： ['System-Date', 'System-Time', 'Socket 0-EXEC', 'Socket 0-IPC', 'Socket 0-FREQ', 'Socket 0-AFREQ', 'Socket 0-L3MISS', 'Socket 0-L2MISS', 'Socket 0-L3HIT', 'Socket 0-L2HIT', 'Socket 0-L3MPI', 'Socket 0-L2MPI', 'Socket 0-L3OCC', 'Socket 0-READ', 'Socket 0-WRITE', 'Socket 0-LOCAL', 'Socket 0-TEMP', 'Socket 0-INST', 'Socket 0-ACYC', 'Socket 0-TIME(ticks)', 'Socket 0-PhysIPC', 'Socket 0-PhysIPC%', 'Socket 0-INSTnom', 'Socket 0-INSTnom%', 'Socket 1-EXEC', 'Socket 1-IPC', 'Socket 1-FREQ', 'Socket 1-AFREQ', 'Socket 1-L3MISS', 'Socket 1-L2MISS', 'Socket 1-L3HIT', 'Socket 1-L2HIT', 'Socket 1-L3MPI', 'Socket 1-L2MPI', 'Socket 1-L3OCC', 'Socket 1-READ', 'Socket 1-WRITE', 'Socket 1-LOCAL', 'Socket 1-TEMP', 'Socket 1-INST', 'Socket 1-ACYC', 'Socket 1-TIME(ticks)', 'Socket 1-PhysIPC', 'Socket 1-PhysIPC%', 'Socket 1-INSTnom', 'Socket 1-INSTnom%', 'SKT0 Core C-State-C0res%', 'SKT0 Core C-State-C1res%', 'SKT0 Core C-State-C3res%', 'SKT0 Core C-State-C6res%', 'SKT0 Core C-State-C7res%', 'SKT0 Package C-State-C0res%', 'SKT0 Package C-State-C2res%', 'SKT0 Package C-State-C3res%', 'SKT0 Package C-State-C6res%', 'SKT0 Package C-State-C7res%', 'SKT1 Core C-State-C0res%', 'SKT1 Core C-State-C1res%', 'SKT1 Core C-State-C3res%', 'SKT1 Core C-State-C6res%', 'SKT1 Core C-State-C7res%', 'SKT1 Package C-State-C0res%', 'SKT1 Package C-State-C2res%', 'SKT1 Package C-State-C3res%', 'SKT1 Package C-State-C6res%', 'SKT1 Package C-State-C7res%', 'Proc Energy (Joules)-SKT0', 'Proc Energy (Joules)-SKT1', 'DRAM Energy (Joules)-SKT0', 'DRAM Energy (Joules)-SKT1', 'LLCRDMISSLAT (ns)-SKT0', 'LLCRDMISSLAT (ns)-SKT1', 'UncFREQ (Ghz)-SKT0', 'UncFREQ (Ghz)-SKT1', 'Core5 (Socket 0)-EXEC', 'Core5 (Socket 0)-IPC', 'Core5 (Socket 0)-FREQ', 'Core5 (Socket 0)-AFREQ', 'Core5 (Socket 0)-L3MISS', 'Core5 (Socket 0)-L2MISS', 'Core5 (Socket 0)-L3HIT', 'Core5 (Socket 0)-L2HIT', 'Core5 (Socket 0)-L3MPI', 'Core5 (Socket 0)-L2MPI', 'Core5 (Socket 0)-L3OCC', 'Core5 (Socket 0)-C0res%', 'Core5 (Socket 0)-C1res%', 'Core5 (Socket 0)-C3res%', 'Core5 (Socket 0)-C6res%', 'Core5 (Socket 0)-C7res%', 'Core5 (Socket 0)-TEMP', 'Core5 (Socket 0)-INST', 'Core5 (Socket 0)-ACYC', 'Core5 (Socket 0)-TIME(ticks)', 'Core5 (Socket 0)-PhysIPC', 'Core5 (Socket 0)-PhysIPC%', 'Core5 (Socket 0)-INSTnom', 'Core5 (Socket 0)-INSTnom%', '-']

# %%
features_pcie = print_headers("const_input", exp_ls,   "pcm-pcie_processed.csv")
# Out:
# header： ['skt-0_PCIRdCur-total', 'skt-0_RFO-total', 'skt-0_CRd-total', 'skt-0_DRd-total', 'skt-0_ItoM-total', 'skt-0_PRd-total', 'skt-0_WiL-total', 'skt-0_PCIRdCur-miss', 'skt-0_RFO-miss', 'skt-0_CRd-miss', 'skt-0_DRd-miss', 'skt-0_ItoM-miss', 'skt-0_PRd-miss', 'skt-0_WiL-miss', 'skt-0_PCIRdCur-hit', 'skt-0_RFO-hit', 'skt-0_CRd-hit', 'skt-0_DRd-hit', 'skt-0_ItoM-hit', 'skt-0_PRd-hit', 'skt-0_WiL-hit', 'skt-1_PCIRdCur-total', 'skt-1_RFO-total', 'skt-1_CRd-total', 'skt-1_DRd-total', 'skt-1_ItoM-total', 'skt-1_PRd-total', 'skt-1_WiL-total', 'skt-1_PCIRdCur-miss', 'skt-1_RFO-miss', 'skt-1_CRd-miss', 'skt-1_DRd-miss', 'skt-1_ItoM-miss', 'skt-1_PRd-miss', 'skt-1_WiL-miss', 'skt-1_PCIRdCur-hit', 'skt-1_RFO-hit', 'skt-1_CRd-hit', 'skt-1_DRd-hit', 'skt-1_ItoM-hit', 'skt-1_PRd-hit', 'skt-1_WiL-hit']

# %%
features_memory = print_headers("const_input", exp_ls, "pcm-memory_processed.csv")
# Out:
# header： ['SKT0-Ch0Read', 'SKT0-Ch0Write', 'SKT0-Ch1Read', 'SKT0-Ch1Write', 'SKT0-Mem Read (MB/s)', 'SKT0-Mem Write (MB/s)', 'SKT0-P. Write (T/s)', 'SKT0-Memory (MB/s)', 'SKT1-Ch0Read', 'SKT1-Ch0Write', 'SKT1-Ch1Read', 'SKT1-Ch1Write', 'SKT1-Mem Read (MB/s)', 'SKT1-Mem Write (MB/s)', 'SKT1-P. Write (T/s)', 'SKT1-Memory (MB/s)', 'System-Read', 'System-Write', 'System-Memory']

# %%
features_latency= print_headers("const_input", exp_ls, "latency_processed.csv")
# Out:
# header： ['latency']

# %%
features_pktsize=  [ 'PacketRate', 'Mbit', 'MbitWithFraming', 'TotalPackets', 'TotalBytes']
#print_headers("ndpi-stats-random", exp_ls, "tx_stats.csv")

# %%
Infos=["ndpi_stats-pcm_processed.csv"]
Infos_pcie = ["pcm-pcie_processed.csv"]
Infos_memory =["pcm-memory_processed.csv"]
Infos_pktsize = ["tx_stats.csv"]
def make_df():
    tmp = []
    dic = dict()
    tx_stats = parse_seq("const_input", exp_ls, "tx_stats.csv")
    rx_stats = parse_seq("const_input", exp_ls, "rx_stats.csv")
    latency = parse_seq("const_input", exp_ls,  "latency_processed.csv")
    
    seq_length = min(len(tx_stats), len(rx_stats),
                     len(parse_reg("const_input", exp_ls, "ndpi_stats-pcm_processed.csv", 'System-Date')), 
                     len(parse_reg("const_input", exp_ls, "pcm-pcie_processed.csv", 'skt-0_PCIRdCur-total')),
                     len(parse_seq("const_input", exp_ls,  "rx_stats.csv")))
    dic["input_rate"] = tx_stats[:seq_length]
    dic["output_rate"] = rx_stats[:seq_length]
    dic["latency"] = latency[:seq_length]
    for f in features:
        for v in Infos:
            tmp =parse_reg("const_input", exp_ls, "ndpi_stats-pcm_processed.csv", f)
            tmp = tmp[:seq_length]
            if len(tmp) < seq_length:
                tmp = np.pad(tmp, (0, seq_length - len(tmp)), mode='constant')
            dic[v.split(".")[0] + "_" + f.replace(",", "")] = tmp
            
    for f in features_pcie:
        for v in Infos_pcie:
            tmp =parse_reg("const_input", exp_ls, "pcm-pcie_processed.csv", f)
            tmp = tmp[:seq_length]
            if len(tmp) < seq_length:
                tmp = np.pad(tmp, (0, seq_length - len(tmp)), mode='constant')
            dic[v.split(".")[0] + "_" + f.replace(",", "")] = tmp 
    for f in features_memory:
        for v in Infos_memory:
            tmp =parse_reg("const_input", exp_ls, "pcm-memory_processed.csv", f)
            tmp = tmp[:seq_length]
            if len(tmp) < seq_length:
                tmp = np.pad(tmp, (0, seq_length - len(tmp)), mode='constant')
                
            dic[v.split(".")[0] + "_" + f.replace(",", "")] = tmp 
    for f in features_pktsize:
        for v in Infos_pktsize:
            tmp =parse_reg("const_input", exp_ls, "tx_stats.csv", f)
            tmp = tmp[:seq_length]
            if len(tmp) < seq_length:
                tmp = np.pad(tmp, (0, seq_length - len(tmp)), mode='constant')
            dic[v.split(".")[0] + "_" + f.replace(",", "")] = tmp 
    
    return pd.DataFrame(dic)

#bridge_L3MISS = parse_reg("fixed_rate", exp_ls,  "bridge-pcm.csv", "Socket 0-L3HIT")
#print(len(bridge_L3MISS))

# %%
df = make_df()

# %%
print(df)
# Out:
#        input_rate  output_rate    latency  \
# 0     1210.340836   423.245989  15000.000
# 1      891.042309   594.462377     46.135
# 2     1115.249190   757.908486  15000.000
# 3     1269.029041  1108.609257     70.154
# 4     6032.808376  6864.282352      8.179
# ...           ...          ...        ...
# 1967  9919.959632  9910.845853    400.784
# 1968  9919.759602  9907.885556    390.890
# 1969  9922.372291  9911.348009    397.466
# 1970  9917.841129  9907.800836    398.608
# 1971  9914.638108  9905.527596    392.771
#
#      ndpi_stats-pcm_processed_System-Date  \
# 0                              2024-02-26
# 1                              2024-02-26
# 2                              2024-02-26
# 3                              2024-02-26
# 4                              2024-02-26
# ...                                   ...
# 1967                           2024-02-26
# 1968                           2024-02-26
# 1969                           2024-02-26
# 1970                           2024-02-26
# 1971                           2024-02-26
#
#      ndpi_stats-pcm_processed_System-Time  \
# 0                            20:20:04.868
# 1                            20:20:05.868
# 2                            20:20:06.868
# 3                            20:20:07.874
# 4                            20:20:08.868
# ...                                   ...
# 1967                         20:52:52.087
# 1968                         20:52:53.087
# 1969                         20:52:54.087
# 1970                         20:52:55.087
# 1971                         20:52:56.087
#
#       ndpi_stats-pcm_processed_Socket 0-EXEC  \
# 0                                       0.38
# 1                                       0.16
# 2                                       0.15
# 3                                       0.15
# 4                                       0.15
# ...                                      ...
# 1967                                    0.14
# 1968                                    0.14
# 1969                                    0.14
# 1970                                    0.14
# 1971                                    0.14
#
#       ndpi_stats-pcm_processed_Socket 0-IPC  \
# 0                                      3.19
# 1                                      2.42
# 2                                      2.37
# 3                                      2.35
# 4                                      2.31
# ...                                     ...
# 1967                                   2.27
# 1968                                   2.24
# 1969                                   2.26
# 1970                                   2.21
# 1971                                   2.26
#
#       ndpi_stats-pcm_processed_Socket 0-FREQ  \
# 0                                       0.12
# 1                                       0.06
# 2                                       0.06
# 3                                       0.06
# 4                                       0.06
# ...                                      ...
# 1967                                    0.06
# 1968                                    0.06
# 1969                                    0.06
# 1970                                    0.06
# 1971                                    0.06
#
#       ndpi_stats-pcm_processed_Socket 0-AFREQ  \
# 0                                        1.12
# 1                                        1.12
# 2                                        1.12
# 3                                        1.12
# 4                                        1.12
# ...                                       ...
# 1967                                     1.12
# 1968                                     1.12
# 1969                                     1.12
# 1970                                     1.12
# 1971                                     1.12
#
#       ndpi_stats-pcm_processed_Socket 0-L3MISS  ...  \
# 0                                         0.07  ...
# 1                                         0.05  ...
# 2                                         0.04  ...
# 3                                         0.07  ...
# 4                                         0.04  ...
# ...                                        ...  ...
# 1967                                      0.04  ...
# 1968                                      0.03  ...
# 1969                                      0.03  ...
# 1970                                      0.09  ...
# 1971                                      0.03  ...
#
#       pcm-memory_processed_SKT1-P. Write (T/s)  \
# 0                                 1.969660e+09
# 1                                 2.132894e+09
# 2                                 2.132428e+09
# 3                                 2.134514e+09
# 4                                 2.132441e+09
# ...                                        ...
# 1967                              2.132480e+09
# 1968                              2.134720e+09
# 1969                              2.132768e+09
# 1970                              2.132654e+09
# 1971                              2.134740e+09
#
#       pcm-memory_processed_SKT1-Memory (MB/s)  \
# 0                                      786.74
# 1                                      798.91
# 2                                      785.84
# 3                                      930.90
# 4                                      824.21
# ...                                       ...
# 1967                                   766.28
# 1968                                   764.32
# 1969                                   861.65
# 1970                                   857.95
# 1971                                   811.16
#
#       pcm-memory_processed_System-Read  pcm-memory_processed_System-Write  \
# 0                              1286.44                             798.18
# 1                              1302.32                             806.67
# 2                              1259.89                             767.56
# 3                              1373.78                             846.14
# 4                              1228.59                             729.50
# ...                                ...                                ...
# 1967                           1038.49                             645.81
# 1968                           1033.82                             642.32
# 1969                           1129.13                             701.32
# 1970                           1139.65                             702.54
# 1971                           1079.14                             649.58
#
#       pcm-memory_processed_System-Memory  tx_stats_PacketRate  tx_stats_Mbit  \
# 0                                2084.62             0.404746    1145.581458
# 1                                2108.99             0.297947     843.370856
# 2                                2027.46             0.372860    1055.591535
# 3                                2219.91             0.425186    1200.999355
# 4                                1958.10             2.020376    5709.548190
# ...                                  ...                  ...            ...
# 1967                             1684.30             3.324200    9388.087629
# 1968                             1676.14             3.322621    9388.140171
# 1969                             1830.46             3.318427    9391.424044
# 1970                             1842.18             3.319089    9386.786865
# 1971                             1728.73             3.316772    9383.954574
#
#       tx_stats_MbitWithFraming  tx_stats_TotalPackets  tx_stats_TotalBytes
# 0                  1210.340836           4.086230e+05         1.445686e+08
# 1                   891.042309           7.138590e+05         2.525691e+08
# 2                  1115.249190           1.089529e+06         3.855124e+08
# 3                  1269.029041           1.525238e+06         5.393529e+08
# 4                  6032.808376           3.545643e+06         1.253057e+09
# ...                        ...                    ...                  ...
# 1967               9919.959632           6.520091e+09         2.304914e+12
# 1968               9919.759602           6.523414e+09         2.306087e+12
# 1969               9922.372291           6.526732e+09         2.307261e+12
# 1970               9917.841129           6.530052e+09         2.308435e+12
# 1971               9914.638108           6.533368e+09         2.309608e+12
#
# [1972 rows x 168 columns]

# %%
def classify_packetrate(rate):
    if rate > 10.5:
        return 64
    elif 7 <= rate <= 10.5:
        return 128
    elif 3 <= rate < 7:
        return 256
    elif 1.8 <= rate < 3:
        return 512
    elif 1 <= rate < 1.8:
        return 1024
    else: # rate < 1
        return 1514

# Apply the function to create a new column
df['packetsize'] = df['tx_stats_PacketRate'].apply(classify_packetrate)

# %%
abs_path = os.path.join("..\\datasets_pcm", "const_input_"+ exp_ls +".csv")
df.to_csv(abs_path, sep=',')

# %%
df.columns
# Out:
# Index(['input_rate', 'output_rate', 'latency',
#        'ndpi_stats-pcm_processed_System-Date',
#        'ndpi_stats-pcm_processed_System-Time',
#        'ndpi_stats-pcm_processed_Socket 0-EXEC',
#        'ndpi_stats-pcm_processed_Socket 0-IPC',
#        'ndpi_stats-pcm_processed_Socket 0-FREQ',
#        'ndpi_stats-pcm_processed_Socket 0-AFREQ',
#        'ndpi_stats-pcm_processed_Socket 0-L3MISS',
#        ...
#        'pcm-memory_processed_SKT1-Memory (MB/s)',
#        'pcm-memory_processed_System-Read', 'pcm-memory_processed_System-Write',
#        'pcm-memory_processed_System-Memory', 'tx_stats_PacketRate',
#        'tx_stats_Mbit', 'tx_stats_MbitWithFraming', 'tx_stats_TotalPackets',
#        'tx_stats_TotalBytes', 'packetsize'],
#       dtype='object', length=169)

# %%
plt.figure(figsize=(10, 6)) 
plt.plot(df['input_rate'][5::], label='Input Rate')
#plt.plot(df['output_rate'][5::], label='Input Rate')
plt.ylabel('Input Rate')  
plt.legend() 
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6)) 
plt.plot(df['output_rate'][5::], label='Input Rate')
plt.ylabel('Input Rate')  
plt.legend() 
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6)) 
#plt.plot(df['input_rate'][5::], label='Input Rate')
plt.plot(df['latency'][5::], label='Input Rate')
plt.ylabel('latency')  
plt.legend() 
plt.grid(True)
plt.show()
