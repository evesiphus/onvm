# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib.colors import Normalize
import matplotlib as mp
import sys, re, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
try:
    if chdir:
        pass
except:
    current_dir = os.getcwd()
    os.chdir(current_dir +"/..")
    os.path.abspath(os.curdir)
    
chdir = True
current_dir = os.getcwd()

# %%
file_path = os.path.abspath('../linear/datasets/random_rates.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
df = data.dropna()

# input rate distribution
a = list(df['input_rate']/1000)
plt.plot(a[0:2000], c='b', label='Rate')
plt.xlabel('time')
plt.ylabel('Rate')
plt.legend()
plt.grid()
plt.show()
print(sum(a)/len(a))
print(min(a))
print(max(a))
# Out:
# 4.557533720258471
# 0.64956534194572
# 7.123542516256499

# %%
# random
accuracy_dct_random=[0.0, 48.551933282789996, 57.8316906747536, 64.50341167551174, 70.26535253980288, 
              75.23881728582259, 79.37831690674754, 82.91129643669447, 86.61106899166035, 
              89.24943138741472, 89.99241849886278]
accuracy_linear_regression_random=[0.0, 32.752084912812734, 58.195602729340415, 66.67172100075815, 73.2827899924185, 
                                   78.30174374526156,82.60803639120546, 84.92797573919636, 86.01971190295679,
                                   86.9294920394238, 88.11220621683094]
accuracy_linear_ForestRegressor = [0.0, 40.48521607278241, 59.7573919636088, 70.26535253980288, 77.16451857467779,
                                   81.84988627748294, 84.80667172100075, 86.82335102350265, 88.26383623957543,
                                   89.44655041698256, 90.18953752843063]

# nural network

accuracy_nural = [0.0, 9.731543624161073, 20.693512304250557, 28.97091722595078, 36.91275167785235, 44.63087248322148, 49.44071588366891, 53.355704697986575, 57.71812080536913, 61.85682326621924, 65.32438478747203]

#plot
plt.plot([num/10 for num in range(11)],accuracy_dct_random, marker='x',markersize = 4, c='k',linestyle='-',linewidth=1, dashes=(5, 3),label='Decision tree')  
plt.plot([num/10 for num in range(11)],accuracy_linear_regression_random, marker='o',markersize = 4, c='b',linestyle='-',linewidth=1, dashes=(5, 3),label = 'Linear regression')  
plt.plot([num/10 for num in range(11)],accuracy_linear_ForestRegressor , marker='o',markersize = 4, c='r',linestyle='-',linewidth=1, dashes=(5, 3),label = 'Forest regressor ')  
plt.plot([num/10 for num in range(11)],accuracy_nural, marker='x',markersize = 4, c='g',linestyle='-',linewidth=1, dashes=(5, 3),label = 'DNN')  

plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])
plt.xlabel('Threshold (random rate)',size=16)
plt.ylabel('Accuracy',size=16)
plt.legend(loc='lower right',fontsize=14)
plt.grid()

#save figure
abs_path = os.path.join("..\\linear\\figure\\rate_prediction", "rate_prediction_"+ "random" +'.pdf')
plt.savefig(abs_path)
plt.show()
# Out:
# C:\Users\Qiong\AppData\Local\Temp\ipykernel_6408\850729098.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])

# %%
# combined

file_path = os.path.abspath('../linear/datasets/combined.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
df = data.dropna()

# input rate distribution
a = list(df['input_rate']/1000)
plt.plot(a[0:2000], c='b', label='Rate')
plt.legend(loc='lower right')
plt.grid()
plt.show()
print(sum(a)/len(a))
print(min(a))
print(max(a))
# Out:
# 4.461117028172448
# 0.17473317378476
# 9.9540057916325

# %%
# fixed rate (combined)

accuracy_dct_random=[0.0, 81.56424581005587, 86.40595903165735, 91.06145251396647, 93.85474860335195, 96.2756052141527, 
                     96.2756052141527, 96.46182495344506, 96.46182495344506, 96.46182495344506, 98.62756052141528]
accuracy_linear_regression_random=[0.0, 85.1024208566108, 90.5027932960894, 95.53072625698324, 96.8342644320298, 
                                   98.32402234636871, 98.51024208566108, 98.51024208566108, 98.69646182495345, 99.25512104283054, 99.62756052141528]
accuracy_linear_ForestRegressor = [0.0, 82.86778398510242, 91.06145251396647, 94.41340782122904, 97.02048417132217, 98.88268156424581, 
                                   99.06890130353817, 99.4413407821229, 99.4413407821229, 99.4413407821229, 99.81378026070763]

# nural network

accuracy_nural =  [0.0, 72.62569832402235, 83.79888268156425, 91.34078212290503, 96.08938547486034, 97.76536312849163, 97.76536312849163, 97.76536312849163, 98.04469273743017, 98.04469273743017, 98.04469273743017]

accuracy_nural1 =[0.0, 98.32402234636871, 98.69646182495345, 99.25512104283054, 99.62756052141528, 99.62756052141528, 99.62756052141528, 99.62756052141528, 
                  99.62756052141528, 99.81378026070763, 99.81378026070763]

#plot
plt.plot([num/10 for num in range(11)],accuracy_dct_random, marker='x',markersize = 4, c='k',linestyle='-',linewidth=1, dashes=(5, 3),label='Decision tree')  
plt.plot([num/10 for num in range(11)],accuracy_linear_regression_random, marker='o',markersize = 4, c='b',linestyle='-',linewidth=1, dashes=(5, 3),label = 'Linear regression')  
plt.plot([num/10 for num in range(11)],accuracy_linear_ForestRegressor , marker='o',markersize = 4, c='r',linestyle='-',linewidth=1, dashes=(5, 3),label = 'Forest regresson ')  
plt.plot([num/10 for num in range(11)],accuracy_nural, marker='>',markersize = 4, c='g',linewidth=1, dashes=(5, 3),label = 'DNN')  
#plt.plot([num/10 for num in range(11)],accuracy_nural1, marker='>',markersize = 4, c='orange',linestyle='-',linewidth=2, dashes=(5, 3),label = 'nural network')  

plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])
plt.xlabel('Threshold (fixed rate)',size=16)
plt.ylabel('Accuracy',size=16)
plt.legend(loc='lower right',fontsize=16)
plt.grid()
#save figure
abs_path = os.path.join("..\\linear\\figure\\rate_prediction", "rate_prediction_"+ "combined" +'.pdf')
plt.savefig(abs_path)
plt.show()
# Out:
# C:\Users\Qiong\AppData\Local\Temp\ipykernel_6408\3393702078.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])

# %%
# fixed rate (combined)--20%

accuracy_dct_random=[0.0, 80.44692737430168, 80.63314711359403, 81.56424581005587, 81.56424581005587, 81.56424581005587, 
                     81.56424581005587, 81.56424581005587, 81.56424581005587, 81.56424581005587, 81.56424581005587]
accuracy_linear_ForestRegressor =[0.0, 62.01117318435754, 73.3705772811918, 78.02607076350093, 81.75046554934823, 82.86778398510242, 
                                   84.91620111731844, 86.77839851024208, 89.19925512104282, 89.75791433891993, 91.06145251396647]
accuracy_linear_regression_random = [0.0, 53.072625698324025, 72.99813780260708, 80.26070763500931, 83.05400372439479, 85.1024208566108, 86.03351955307262, 
                                     87.33705772811918, 88.64059590316573, 89.94413407821229, 90.5027932960894]
# nural network

accuracy_nural = [0.0, 32.122905027932966, 50.0, 62.290502793296085, 68.71508379888269, 72.62569832402235, 77.09497206703911, 79.60893854748603, 81.00558659217877, 82.40223463687151, 83.79888268156425]

accuracy_nural1 =[0.0, 13.40782122905028, 27.37430167597765, 38.26815642458101, 48.324022346368714, 
                  51.117318435754186, 55.02793296089386, 59.217877094972074, 64.24581005586593, 67.59776536312849, 
                  69.27374301675978]


#plot
plt.plot([num/50 for num in range(11)],accuracy_dct_random, marker='x',markersize = 4, c='k',linestyle='-',linewidth=1, dashes=(5, 3),label='Decision tree')  
plt.plot([num/50 for num in range(11)],accuracy_linear_regression_random, marker='o',markersize = 4, c='b',linestyle='-',linewidth=1, dashes=(5, 3),label = 'Linear regression')  
plt.plot([num/50 for num in range(11)],accuracy_linear_ForestRegressor , marker='o',markersize = 4, c='r',linestyle='-',linewidth=1, dashes=(5, 3),label = 'Forest regresson ')  
#plt.plot([num/50 for num in range(11)],accuracy_nural, marker='x',markersize = 4, c='y',linestyle='-',linewidth=1, dashes=(5, 3),label = 'nural network (random)')  
plt.plot([num/50 for num in range(11)],accuracy_nural, marker='>',markersize = 4, c='orange',linestyle='-',linewidth=1, dashes=(5, 3),label = 'DNN')  

plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])
plt.xlabel('Threshold (fixed rate)',size=16)
plt.ylabel('Accuracy',size=16)
plt.legend(loc='lower right',fontsize=14)
plt.grid()
#save figure
abs_path = os.path.join("..\\linear\\figure\\rate_prediction", "rate_prediction_"+ "random_top20" +'.pdf')
plt.savefig(abs_path)
plt.show()
# Out:
# C:\Users\Qiong\AppData\Local\Temp\ipykernel_6408\313270138.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])

# %%
# combined all data

accuracy_dct_random=[37.17332401013898, 69.33834455030154, 75.11581155493401, 78.83926230224631, 82.14316930338256, 84.94012761122279, 87.466130582991, 89.76488069224719, 91.95874486495936, 93.48833143955947, 94.12638755353552]
accuracy_linear_regression_random  =[0.0, 51.87483611572416, 70.86793112490167, 77.20478979110219, 81.2254173586225, 84.00489467703872, 86.67948605891094, 88.7597238003671, 90.05331701774321, 90.70011362643126, 91.1895813303033]

accuracy_linear_ForestRegressor= [35.36404160475483, 63.53465606153308, 75.78882964775806, 81.78480902019054, 85.48203828336683, 88.58491390612708, 90.57774670046325, 91.75771348658334, 92.66672493663141, 93.56699589196748, 94.24875447950353]
# nural network

accuracy_nural = [0.0, 58.1279496591505, 73.59727320398531, 79.69323544834819, 83.98007341373885, 87.3885684320923, 89.78762454116413, 90.95437860513897, 91.80650235972732, 92.31777661248034, 92.69795490298898]

accuracy_nural1 =[0.0, 13.40782122905028, 27.37430167597765, 38.26815642458101, 48.324022346368714, 
                  51.117318435754186, 55.02793296089386, 59.217877094972074, 64.24581005586593, 67.59776536312849, 
                  69.27374301675978]


#plot
plt.plot([num/10 for num in range(11)],accuracy_dct_random, marker='x',markersize = 4, c='k',linestyle='-',linewidth=1, dashes=(5, 3),label='Decision tree')  
plt.plot([num/10 for num in range(11)],accuracy_linear_regression_random, marker='o',markersize = 4, c='b',linestyle='-',linewidth=1, dashes=(5, 3),label = 'Linear regression')  
plt.plot([num/10 for num in range(11)],accuracy_linear_ForestRegressor , marker='o',markersize = 4, c='r',linestyle='-',linewidth=1, dashes=(5, 3),label = 'Forest regresson ')  
#plt.plot([num/50 for num in range(11)],accuracy_nural, marker='x',markersize = 4, c='y',linestyle='-',linewidth=1, dashes=(5, 3),label = 'nural network (random)')  
plt.plot([num/10 for num in range(11)],accuracy_nural, marker='>',markersize = 4, c='orange',linestyle='-',linewidth=1, dashes=(5, 3),label = 'DNN')  

plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])
plt.xlabel('Threshold',size=16)
plt.ylabel('Accuracy',size=16)
plt.legend(loc='lower right',fontsize=14)
plt.grid()
#save figure
abs_path = os.path.join("..\\linear\\figure\\rate_prediction", "rate_prediction_"+ "combined_global" +'.pdf')
plt.savefig(abs_path)
plt.show()
# Out:
# C:\Users\Qiong\AppData\Local\Temp\ipykernel_6408\1355086628.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])

# %%
# combined all data
accuracy_dct_random=[37.17332401013898, 58.15051131894066, 63.04518835766104, 65.85088716021326, 67.66016956559741, 69.33834455030154, 70.71060222008566, 71.90804999562975, 73.13171925530985, 74.17183812603794, 75.11581155493401]
accuracy_linear_ForestRegressor =[35.36404160475483, 44.27060571628354, 49.90822480552399, 54.82912332838039, 59.557730967572766, 63.53465606153308, 67.00463246219735, 69.91521720129359, 72.39751769950179, 74.24176208373395, 75.78882964775806]
accuracy_linear_regression_random = [0.0, 13.705095708417097, 25.854383358098072, 35.91469277161087, 44.760073420155585, 51.87483611572416, 57.91451796171664, 62.42461323310899, 66.05191853858928, 68.68280744690149, 70.86793112490167]

accuracy_nural = [0.0, 25.70791819611956, 39.47299423177766, 47.45673833245936, 53.736234923964346, 58.66544310435239, 62.87362349239643, 66.37388568432092, 69.42842160461457, 71.9323544834819, 74.20031463030938]
accuracy_nural1 =[0.0, 13.40782122905028, 27.37430167597765, 38.26815642458101, 48.324022346368714, 
                  51.117318435754186, 55.02793296089386, 59.217877094972074, 64.24581005586593, 67.59776536312849, 
                  69.27374301675978]


#plot
plt.plot([num/50 for num in range(11)],accuracy_dct_random, marker='x',markersize = 4, c='k',linestyle='-',linewidth=1, dashes=(5, 3),label='Decision tree')  
plt.plot([num/50 for num in range(11)],accuracy_linear_regression_random, marker='o',markersize = 4, c='b',linestyle='-',linewidth=1, dashes=(5, 3),label = 'Linear regression')  
plt.plot([num/50 for num in range(11)],accuracy_linear_ForestRegressor , marker='o',markersize = 4, c='r',linestyle='-',linewidth=1, dashes=(5, 3),label = 'Forest regresson ')  
plt.plot([num/50 for num in range(11)],accuracy_nural, marker='>',markersize = 4, c='orange',linestyle='-',linewidth=1, dashes=(5, 3),label = 'DNN')  

plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])
plt.xlabel('Threshold',size=16)
plt.ylabel('Accuracy',size=16)
plt.legend(loc='lower right',fontsize=14)
plt.grid()
#save figure
abs_path = os.path.join("..\\linear\\figure\\rate_prediction", "rate_prediction_"+ "combined_global_top20" +'.pdf')
plt.savefig(abs_path)
plt.show()
# Out:
# C:\Users\Qiong\AppData\Local\Temp\ipykernel_6408\2258000848.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])
