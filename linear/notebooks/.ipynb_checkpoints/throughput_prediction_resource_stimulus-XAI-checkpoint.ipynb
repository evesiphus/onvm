# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys, re, os

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.ensemble import RandomForestRegressor

# %%
# %matplotlib inline

plt.rc('font', family='serif')
plt.rcParams.update({'font.size': 11})

plt.rcParams['figure.dpi'] = 200
plt.rcParams['savefig.dpi'] = 300

# %%
# Change the work directory to the parent
try:
    if chdir:
        pass
except:
    current_dir = os.getcwd()
    os.chdir(current_dir +"/..")
    os.path.abspath(os.curdir)

# %%
chdir = True

# %%
import itertools
marker = itertools.cycle(('x',',', '+', '.', 'o', '*'))
cycol = itertools.cycle('bgrcmk')

# %% [markdown]
# # Service chain configuration

# %%
from IPython.display import IFrame
IFrame("../assets/testbed.png", width=850, height=480)
# Out:
#         <iframe
#             width="850"
#             height="480"
#             src="../assets/testbed.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
current_dir = os.getcwd()
file_path = os.path.abspath('../linear/datasets/load_stimulus_global.csv')
#file_path = os.path.abspath('../linear/datasets/random_rates_exp-1.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
#data = data.drop('latency', axis=1)
df = data.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1780 entries, 0 to 177
# Data columns (total 63 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   input_rate                          1780 non-null   float64
#  1   output_rate                         1780 non-null   float64
#  2   latency                             1780 non-null   float64
#  3   firewall_instructions               1780 non-null   float64
#  4   nf_router_instructions              1780 non-null   float64
#  5   ndpi_stats_instructions             1780 non-null   float64
#  6   payload_scan_instructions           1780 non-null   float64
#  7   bridge_instructions                 1780 non-null   float64
#  8   firewall_branches                   1780 non-null   float64
#  9   nf_router_branches                  1780 non-null   float64
#  10  ndpi_stats_branches                 1780 non-null   float64
#  11  payload_scan_branches               1780 non-null   float64
#  12  bridge_branches                     1780 non-null   float64
#  13  firewall_branch-misses              1780 non-null   float64
#  14  nf_router_branch-misses             1780 non-null   float64
#  15  ndpi_stats_branch-misses            1780 non-null   float64
#  16  payload_scan_branch-misses          1780 non-null   float64
#  17  bridge_branch-misses                1780 non-null   float64
#  18  firewall_branch-load-misses         1780 non-null   float64
#  19  nf_router_branch-load-misses        1780 non-null   float64
#  20  ndpi_stats_branch-load-misses       1780 non-null   float64
#  21  payload_scan_branch-load-misses     1780 non-null   float64
#  22  bridge_branch-load-misses           1780 non-null   float64
#  23  firewall_cache-misses               1780 non-null   float64
#  24  nf_router_cache-misses              1780 non-null   float64
#  25  ndpi_stats_cache-misses             1780 non-null   float64
#  26  payload_scan_cache-misses           1780 non-null   float64
#  27  bridge_cache-misses                 1780 non-null   float64
#  28  firewall_cache-references           1780 non-null   float64
#  29  nf_router_cache-references          1780 non-null   float64
#  30  ndpi_stats_cache-references         1780 non-null   float64
#  31  payload_scan_cache-references       1780 non-null   float64
#  32  bridge_cache-references             1780 non-null   float64
#  33  firewall_cycles                     1780 non-null   float64
#  34  nf_router_cycles                    1780 non-null   float64
#  35  ndpi_stats_cycles                   1780 non-null   float64
#  36  payload_scan_cycles                 1780 non-null   float64
#  37  bridge_cycles                       1780 non-null   float64
#  38  firewall_L1-dcache-load-misses      1780 non-null   float64
#  39  nf_router_L1-dcache-load-misses     1780 non-null   float64
#  40  ndpi_stats_L1-dcache-load-misses    1780 non-null   float64
#  41  payload_scan_L1-dcache-load-misses  1780 non-null   float64
#  42  bridge_L1-dcache-load-misses        1780 non-null   float64
#  43  firewall_L1-dcache-loads            1780 non-null   float64
#  44  nf_router_L1-dcache-loads           1780 non-null   float64
#  45  ndpi_stats_L1-dcache-loads          1780 non-null   float64
#  46  payload_scan_L1-dcache-loads        1780 non-null   float64
#  47  bridge_L1-dcache-loads              1780 non-null   float64
#  48  firewall_LLC-load-misses            1780 non-null   float64
#  49  nf_router_LLC-load-misses           1780 non-null   float64
#  50  ndpi_stats_LLC-load-misses          1780 non-null   float64
#  51  payload_scan_LLC-load-misses        1780 non-null   float64
#  52  bridge_LLC-load-misses              1780 non-null   float64
#  53  firewall_LLC-stores                 1780 non-null   float64
#  54  nf_router_LLC-stores                1780 non-null   float64
#  55  ndpi_stats_LLC-stores               1780 non-null   float64
#  56  payload_scan_LLC-stores             1780 non-null   float64
#  57  bridge_LLC-stores                   1780 non-null   float64
#  58  firewall_LLC-loads                  1780 non-null   float64
#  59  nf_router_LLC-loads                 1780 non-null   float64
#  60  ndpi_stats_LLC-loads                1780 non-null   float64
#  61  payload_scan_LLC-loads              1780 non-null   float64
#  62  bridge_LLC-loads                    1780 non-null   float64
# dtypes: float64(63)
# memory usage: 890.0 KB

# %%
corr = data.corr()
correlation_list = []
for i in range(1, 2):
    for j in range(i+1, len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between output_rate and ndpi_stats_LLC-loads: 0.98
# Correlation between output_rate and ndpi_stats_L1-dcache-load-misses: 0.98
# Correlation between output_rate and ndpi_stats_cache-references: 0.98
# Correlation between output_rate and payload_scan_LLC-loads: 0.98
# Correlation between output_rate and payload_scan_cache-references: 0.97
# Correlation between output_rate and nf_router_LLC-loads: 0.97
# Correlation between output_rate and payload_scan_L1-dcache-load-misses: 0.97
# Correlation between output_rate and firewall_LLC-stores: 0.97
# Correlation between output_rate and nf_router_cache-references: 0.97
# Correlation between output_rate and nf_router_L1-dcache-load-misses: 0.97
# Correlation between output_rate and firewall_cache-references: 0.97
# Correlation between output_rate and bridge_LLC-stores: 0.97
# Correlation between output_rate and ndpi_stats_LLC-stores: 0.97
# Correlation between output_rate and firewall_L1-dcache-load-misses: 0.97
# Correlation between output_rate and firewall_LLC-loads: 0.96
# Correlation between output_rate and payload_scan_LLC-stores: 0.96
# Correlation between output_rate and nf_router_LLC-stores: 0.96
# Correlation between output_rate and bridge_L1-dcache-load-misses: 0.95
# Correlation between output_rate and bridge_cache-references: 0.95
# Correlation between output_rate and bridge_LLC-loads: 0.94
# Correlation between output_rate and payload_scan_L1-dcache-loads: 0.92
# Correlation between output_rate and payload_scan_instructions: 0.92
# Correlation between output_rate and payload_scan_branches: 0.92
# Correlation between output_rate and firewall_L1-dcache-loads: 0.89
# Correlation between output_rate and firewall_instructions: 0.89
# Correlation between output_rate and firewall_branches: 0.89
# Correlation between output_rate and nf_router_L1-dcache-loads: 0.86
# Correlation between output_rate and nf_router_instructions: 0.86
# Correlation between output_rate and nf_router_branches: 0.86
# Correlation between output_rate and bridge_L1-dcache-loads: 0.79
# Correlation between output_rate and bridge_branches: 0.79
# Correlation between output_rate and bridge_instructions: 0.79
# Correlation between output_rate and ndpi_stats_branches: 0.78
# Correlation between output_rate and ndpi_stats_L1-dcache-loads: 0.78
# Correlation between output_rate and ndpi_stats_instructions: 0.78
# Correlation between output_rate and latency: 0.67
# Correlation between output_rate and firewall_branch-load-misses: 0.65
# Correlation between output_rate and firewall_branch-misses: 0.65
# Correlation between output_rate and ndpi_stats_cache-misses: 0.65
# Correlation between output_rate and bridge_branch-load-misses: 0.52
# Correlation between output_rate and bridge_branch-misses: 0.52
# Correlation between output_rate and payload_scan_branch-misses: 0.50
# Correlation between output_rate and payload_scan_branch-load-misses: 0.50
# Correlation between output_rate and nf_router_branch-misses: 0.40
# Correlation between output_rate and nf_router_branch-load-misses: 0.40
# Correlation between output_rate and ndpi_stats_LLC-load-misses: 0.40
# Correlation between output_rate and nf_router_LLC-load-misses: 0.37
# Correlation between output_rate and firewall_cache-misses: 0.36
# Correlation between output_rate and nf_router_cache-misses: 0.35
# Correlation between output_rate and firewall_LLC-load-misses: 0.33
# Correlation between output_rate and bridge_cache-misses: 0.32
# Correlation between output_rate and bridge_LLC-load-misses: 0.28
# Correlation between output_rate and payload_scan_cache-misses: 0.18
# Correlation between output_rate and payload_scan_LLC-load-misses: 0.16
# Correlation between output_rate and nf_router_cycles: 0.14
# Correlation between output_rate and bridge_cycles: 0.14
# Correlation between output_rate and ndpi_stats_cycles: 0.14
# Correlation between output_rate and ndpi_stats_branch-misses: 0.10
# Correlation between output_rate and ndpi_stats_branch-load-misses: 0.10
# Correlation between output_rate and payload_scan_cycles: 0.08
# Correlation between output_rate and firewall_cycles: 0.06

# %%
corr = data.corr()
correlation_list = []
for i in range(2,3):
    for j in range(i+1, len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between latency and ndpi_stats_LLC-loads: 0.59
# Correlation between latency and ndpi_stats_cache-references: 0.58
# Correlation between latency and ndpi_stats_L1-dcache-load-misses: 0.57
# Correlation between latency and payload_scan_LLC-loads: 0.57
# Correlation between latency and firewall_LLC-loads: 0.56
# Correlation between latency and firewall_cache-references: 0.56
# Correlation between latency and firewall_L1-dcache-load-misses: 0.56
# Correlation between latency and payload_scan_cache-references: 0.56
# Correlation between latency and nf_router_LLC-loads: 0.56
# Correlation between latency and payload_scan_L1-dcache-load-misses: 0.56
# Correlation between latency and firewall_LLC-stores: 0.56
# Correlation between latency and nf_router_L1-dcache-loads: 0.56
# Correlation between latency and nf_router_instructions: 0.55
# Correlation between latency and nf_router_branches: 0.55
# Correlation between latency and nf_router_cache-references: 0.55
# Correlation between latency and nf_router_L1-dcache-load-misses: 0.55
# Correlation between latency and ndpi_stats_LLC-stores: 0.54
# Correlation between latency and bridge_LLC-stores: 0.54
# Correlation between latency and nf_router_LLC-stores: 0.53
# Correlation between latency and payload_scan_LLC-stores: 0.53
# Correlation between latency and bridge_L1-dcache-load-misses: 0.50
# Correlation between latency and bridge_cache-references: 0.50
# Correlation between latency and payload_scan_L1-dcache-loads: 0.48
# Correlation between latency and firewall_L1-dcache-loads: 0.48
# Correlation between latency and payload_scan_instructions: 0.48
# Correlation between latency and bridge_LLC-loads: 0.48
# Correlation between latency and firewall_instructions: 0.48
# Correlation between latency and firewall_branches: 0.48
# Correlation between latency and payload_scan_branches: 0.48
# Correlation between latency and ndpi_stats_branches: 0.47
# Correlation between latency and ndpi_stats_L1-dcache-loads: 0.47
# Correlation between latency and ndpi_stats_instructions: 0.47
# Correlation between latency and bridge_branches: 0.41
# Correlation between latency and bridge_L1-dcache-loads: 0.41
# Correlation between latency and bridge_instructions: 0.41
# Correlation between latency and ndpi_stats_cache-misses: 0.33
# Correlation between latency and nf_router_branch-misses: 0.33
# Correlation between latency and nf_router_branch-load-misses: 0.33
# Correlation between latency and firewall_branch-load-misses: 0.30
# Correlation between latency and firewall_branch-misses: 0.29
# Correlation between latency and bridge_branch-load-misses: 0.27
# Correlation between latency and bridge_branch-misses: 0.27
# Correlation between latency and nf_router_cycles: 0.25
# Correlation between latency and ndpi_stats_LLC-load-misses: 0.24
# Correlation between latency and bridge_LLC-load-misses: 0.16
# Correlation between latency and nf_router_LLC-load-misses: 0.14
# Correlation between latency and ndpi_stats_cycles: 0.14
# Correlation between latency and ndpi_stats_branch-misses: 0.14
# Correlation between latency and ndpi_stats_branch-load-misses: 0.14
# Correlation between latency and firewall_LLC-load-misses: 0.13
# Correlation between latency and nf_router_cache-misses: 0.13
# Correlation between latency and bridge_cache-misses: 0.12
# Correlation between latency and payload_scan_branch-misses: 0.10
# Correlation between latency and payload_scan_branch-load-misses: 0.10
# Correlation between latency and firewall_cache-misses: 0.09
# Correlation between latency and bridge_cycles: 0.05
# Correlation between latency and payload_scan_LLC-load-misses: 0.05
# Correlation between latency and payload_scan_cache-misses: 0.05
# Correlation between latency and firewall_cycles: 0.04
# Correlation between latency and payload_scan_cycles: 0.02

# %% [markdown]
# # DNN to predict rate (training set: global)

# %%
current_dir = os.getcwd()
file_path = os.path.abspath('../linear/datasets/load_stimulus_global.csv')
#file_path = os.path.abspath('../linear/datasets/random_rates_exp-1.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
#data = data.drop('latency', axis=1)
df = data.dropna()

# %%
# data set
# load_stimulus_global.csv: exp1_exp10
# load_stimulus_global_1.csv:exp1_exp10+fixed_5000+fixed_7500
# load_stimulus_global_2.csv:exp1_exp10+fixed_5000+fixed_7500+random
# load_stimulus_global_3.csv:exp1_exp10+random
#load_stimulus_global_4.csv:exp1_exp10+stage_random
# performance: global>3>2>1

# %%
# training 
X = df.drop(['input_rate','output_rate', 'latency'], axis=1)
X = df.drop(['input_rate','output_rate', 'latency','firewall_cycles','payload_scan_cycles','ndpi_stats_branch-load-misses',
             'nf_router_cycles','bridge_cycles','payload_scan_LLC-load-misses','payload_scan_LLC-load-misses','bridge_LLC-load-misses',
             'bridge_cache-misses','bridge_cache-misses','nf_router_cache-misses','firewall_cache-misses','nf_router_LLC-load-misses',
             'ndpi_stats_LLC-load-misses','nf_router_branch-load-misses','nf_router_branch-misses','payload_scan_branch-load-misses',
             'payload_scan_branch-misses','bridge_branch-misses','ndpi_stats_branch-load-misses','ndpi_stats_cache-misses','firewall_branch-misses'], axis=1)

y = df['output_rate']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

column_order = X_train.columns
X_test = X_test[column_order]


# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print(len(y))
# Out:
# 1780

# %%
# model
model = Sequential()

# Add input layer and hidden layers
model.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(16, activation='relu'))

# Add output layer
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=8, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 156/156 [==============================] - 2s 3ms/step - loss: 13458887.0000
# Epoch 2/100
# 156/156 [==============================] - 1s 4ms/step - loss: 2084341.7500
# Epoch 3/100
# 156/156 [==============================] - 0s 2ms/step - loss: 784394.4375
# Epoch 4/100
# 156/156 [==============================] - 0s 3ms/step - loss: 426876.2188
# Epoch 5/100
# 156/156 [==============================] - 0s 2ms/step - loss: 305196.3125
# Epoch 6/100
# 156/156 [==============================] - 0s 3ms/step - loss: 270914.7812
# Epoch 7/100
# 156/156 [==============================] - 0s 2ms/step - loss: 251587.3594
# Epoch 8/100
# 156/156 [==============================] - 0s 2ms/step - loss: 240342.9844
# Epoch 9/100
# 156/156 [==============================] - 0s 2ms/step - loss: 233142.9062
# Epoch 10/100
# 156/156 [==============================] - 0s 1ms/step - loss: 221656.9688
# Epoch 11/100
# 156/156 [==============================] - 0s 1ms/step - loss: 219256.5312
# Epoch 12/100
# 156/156 [==============================] - 0s 1ms/step - loss: 216016.7656
# Epoch 13/100
# 156/156 [==============================] - 0s 1ms/step - loss: 208493.2969
# Epoch 14/100
# 156/156 [==============================] - 0s 2ms/step - loss: 208511.8125
# Epoch 15/100
# 156/156 [==============================] - 0s 2ms/step - loss: 199922.6562
# Epoch 16/100
# 156/156 [==============================] - 0s 2ms/step - loss: 197938.0625
# Epoch 17/100
# 156/156 [==============================] - 0s 2ms/step - loss: 201518.6719
# Epoch 18/100
# 156/156 [==============================] - 0s 2ms/step - loss: 204372.0781
# Epoch 19/100
# 156/156 [==============================] - 0s 1ms/step - loss: 212387.8594
# Epoch 20/100
# 156/156 [==============================] - 0s 1ms/step - loss: 198867.4062
# Epoch 21/100
# 156/156 [==============================] - 0s 2ms/step - loss: 202322.2031
# Epoch 22/100
# 156/156 [==============================] - 0s 3ms/step - loss: 203042.9844
# Epoch 23/100
# 156/156 [==============================] - 0s 2ms/step - loss: 187923.1406
# Epoch 24/100
# 156/156 [==============================] - 0s 2ms/step - loss: 189866.7031
# Epoch 25/100
# 156/156 [==============================] - 0s 2ms/step - loss: 181932.9531
# Epoch 26/100
# 156/156 [==============================] - 0s 2ms/step - loss: 187860.7188
# Epoch 27/100
# 156/156 [==============================] - 0s 2ms/step - loss: 173859.4375
# Epoch 28/100
# 156/156 [==============================] - 0s 2ms/step - loss: 168072.7656
# Epoch 29/100
# 156/156 [==============================] - 0s 2ms/step - loss: 186971.5625
# Epoch 30/100
# 156/156 [==============================] - 0s 2ms/step - loss: 177264.0000
# Epoch 31/100
# 156/156 [==============================] - 0s 1ms/step - loss: 177235.8438
# Epoch 32/100
# 156/156 [==============================] - 0s 1ms/step - loss: 177416.0312
# Epoch 33/100
# 156/156 [==============================] - 0s 1ms/step - loss: 180963.7188
# Epoch 34/100
# 156/156 [==============================] - 0s 2ms/step - loss: 182658.1250
# Epoch 35/100
# 156/156 [==============================] - 0s 1ms/step - loss: 170562.5156
# Epoch 36/100
# 156/156 [==============================] - 0s 1ms/step - loss: 174004.2188
# Epoch 37/100
# 156/156 [==============================] - 0s 2ms/step - loss: 158222.5469
# Epoch 38/100
# 156/156 [==============================] - 0s 2ms/step - loss: 161444.7344
# Epoch 39/100
# 156/156 [==============================] - 0s 2ms/step - loss: 165128.9219
# Epoch 40/100
# 156/156 [==============================] - 0s 2ms/step - loss: 169606.3281
# Epoch 41/100
# 156/156 [==============================] - 0s 1ms/step - loss: 166479.0312
# Epoch 42/100
# 156/156 [==============================] - 0s 1ms/step - loss: 158175.7500
# Epoch 43/100
# 156/156 [==============================] - 0s 2ms/step - loss: 169624.6875
# Epoch 44/100
# 156/156 [==============================] - 0s 2ms/step - loss: 169973.0156
# Epoch 45/100
# 156/156 [==============================] - 0s 2ms/step - loss: 171286.6562
# Epoch 46/100
# 156/156 [==============================] - 0s 2ms/step - loss: 158175.1562
# Epoch 47/100
# 156/156 [==============================] - 0s 2ms/step - loss: 154664.3281
# Epoch 48/100
# 156/156 [==============================] - 0s 2ms/step - loss: 153977.1562
# Epoch 49/100
# 156/156 [==============================] - 0s 2ms/step - loss: 166523.3125
# Epoch 50/100
# 156/156 [==============================] - 0s 2ms/step - loss: 156506.4844
# Epoch 51/100
# 156/156 [==============================] - 0s 2ms/step - loss: 148242.4219
# Epoch 52/100
# 156/156 [==============================] - 0s 2ms/step - loss: 160194.4062
# Epoch 53/100
# 156/156 [==============================] - 0s 905us/step - loss: 161024.9688
# Epoch 54/100
# 156/156 [==============================] - 0s 1ms/step - loss: 160628.9844
# Epoch 55/100
# 156/156 [==============================] - 0s 1ms/step - loss: 162912.9219
# Epoch 56/100
# 156/156 [==============================] - 0s 1ms/step - loss: 153729.6875
# Epoch 57/100
# 156/156 [==============================] - 0s 1ms/step - loss: 158755.4219
# Epoch 58/100
# 156/156 [==============================] - 0s 2ms/step - loss: 155321.5000
# Epoch 59/100
# 156/156 [==============================] - 0s 1ms/step - loss: 154449.1406
# Epoch 60/100
# 156/156 [==============================] - 0s 1ms/step - loss: 149957.5625
# Epoch 61/100
# 156/156 [==============================] - 0s 2ms/step - loss: 161281.1250
# Epoch 62/100
# 156/156 [==============================] - 0s 1ms/step - loss: 150719.0938
# Epoch 63/100
# 156/156 [==============================] - 0s 2ms/step - loss: 149728.9688
# Epoch 64/100
# 156/156 [==============================] - 0s 1ms/step - loss: 152770.0625
# Epoch 65/100
# 156/156 [==============================] - 0s 1ms/step - loss: 152600.7969
# Epoch 66/100
# 156/156 [==============================] - 0s 3ms/step - loss: 157735.0312
# Epoch 67/100
# 156/156 [==============================] - 0s 2ms/step - loss: 150768.3906
# Epoch 68/100
# 156/156 [==============================] - 0s 2ms/step - loss: 146514.9844
# Epoch 69/100
# 156/156 [==============================] - 0s 2ms/step - loss: 148576.3125
# Epoch 70/100
# 156/156 [==============================] - 0s 2ms/step - loss: 157131.6562
# Epoch 71/100
# 156/156 [==============================] - 0s 2ms/step - loss: 155213.0156
# Epoch 72/100
# 156/156 [==============================] - 0s 2ms/step - loss: 147152.4375
# Epoch 73/100
# 156/156 [==============================] - 0s 2ms/step - loss: 155482.4844
# Epoch 74/100
# 156/156 [==============================] - 0s 2ms/step - loss: 148137.0000
# Epoch 75/100
# 156/156 [==============================] - 0s 2ms/step - loss: 154178.3906
# Epoch 76/100
# 156/156 [==============================] - 0s 2ms/step - loss: 145065.0469
# Epoch 77/100
# 156/156 [==============================] - 0s 2ms/step - loss: 148531.9219
# Epoch 78/100
# 156/156 [==============================] - 0s 2ms/step - loss: 156566.9531
# Epoch 79/100
# 156/156 [==============================] - 0s 994us/step - loss: 150507.5469
# Epoch 80/100
# 156/156 [==============================] - 0s 1ms/step - loss: 145292.3906
# Epoch 81/100
# 156/156 [==============================] - 0s 2ms/step - loss: 152635.8594
# Epoch 82/100
# 156/156 [==============================] - 0s 1ms/step - loss: 168077.9531
# Epoch 83/100
# 156/156 [==============================] - 0s 2ms/step - loss: 149824.5781
# Epoch 84/100
# 156/156 [==============================] - 0s 2ms/step - loss: 143316.4844
# Epoch 85/100
# 156/156 [==============================] - 0s 2ms/step - loss: 143127.3906
# Epoch 86/100
# 156/156 [==============================] - 0s 2ms/step - loss: 150415.3750
# Epoch 87/100
# 156/156 [==============================] - 0s 2ms/step - loss: 156485.0156
# Epoch 88/100
# 156/156 [==============================] - 0s 2ms/step - loss: 139849.5938
# Epoch 89/100
# 156/156 [==============================] - 0s 2ms/step - loss: 148424.7344
# Epoch 90/100
# 156/156 [==============================] - 0s 2ms/step - loss: 142312.5469
# Epoch 91/100
# 156/156 [==============================] - 0s 3ms/step - loss: 147225.9062
# Epoch 92/100
# 156/156 [==============================] - 0s 2ms/step - loss: 144425.9844
# Epoch 93/100
# 156/156 [==============================] - 0s 2ms/step - loss: 152207.2188
# Epoch 94/100
# 156/156 [==============================] - 0s 2ms/step - loss: 153245.3125
# Epoch 95/100
# 156/156 [==============================] - 0s 2ms/step - loss: 159142.2344
# Epoch 96/100
# 156/156 [==============================] - 0s 2ms/step - loss: 143838.2344
# Epoch 97/100
# 156/156 [==============================] - 0s 1ms/step - loss: 155016.6406
# Epoch 98/100
# 156/156 [==============================] - 0s 2ms/step - loss: 156129.2656
# Epoch 99/100
# 156/156 [==============================] - 0s 2ms/step - loss: 149603.7812
# Epoch 100/100
# 156/156 [==============================] - 0s 2ms/step - loss: 141953.9844

# %%
# Make predictions on the test set
import matplotlib.ticker as mticker

y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# accuracy
threshold = 0.05  
y_pred=np.array(y_pred)
y_pred = [item for subset in y_pred for item in subset]
y_test=np.array(y_test)
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot

fig, ax = plt.subplots(facecolor='white', figsize=(8,6))
#ax.set_facecolor('white')
plt.style.use('classic')

plt.plot(y_pred[0:100], marker='o',c='r',markersize = 2, linewidth = 0.8, linestyle='-', markeredgecolor='red', dashes=(5, 3),label='Prediction')
plt.plot(y_test.tolist()[0:100], c='b',linestyle='-',linewidth = 0.8,label='Real data')


plt.legend(loc="upper right", fontsize=8)
fig.text(0.5, 0.01, 'Series', size='12', ha='center')
fig.text(0.01, 0.5, 'Values', size='12', va='center', rotation='vertical')
plt.subplots_adjust(left=0.12, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.4)
#plt.grid()
ax.set_facecolor('white')

# Set y-axis tick format
formatter = mticker.FuncFormatter(lambda x, pos: f"{int(x/1000)}")
ax.yaxis.set_major_formatter(formatter)
# Set text in the upper left corner of the figure
fig.text(0.12, 0.98, '1e3', size='12', ha='left', va='top')


plt.show()
# Out:
# 17/17 [==============================] - 0s 2ms/step
# [0.0, 80.71161048689139, 91.57303370786516, 94.7565543071161, 96.06741573033707, 97.37827715355806, 98.68913857677903, 98.87640449438202, 99.06367041198502, 99.25093632958801, 99.25093632958801]

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
# Out:
# R-squared: 0.983955496981133

# %% [markdown]
# # XAI: Analyze Sensitivity

# %%
import numpy as np
import tensorflow as tf

# Get the predictions for X_test
y_pred = model.predict(X_test)

# Calculate gradients with respect to each feature
gradients = []
for i in range(X_test.shape[0]):
    input_instance = tf.convert_to_tensor(X_test[i].reshape(1, -1))
    with tf.GradientTape() as tape:
        tape.watch(input_instance)
        output_instance = model(input_instance)
    gradient = tape.gradient(output_instance, input_instance)
    gradients.append(gradient.numpy())

# Calculate the absolute average gradient for each feature
avg_gradients = np.abs(np.mean(np.array(gradients), axis=0))

# Perform min-max normalization on the gradients
min_gradient = np.min(avg_gradients)
max_gradient = np.max(avg_gradients)
normalized_gradients = (avg_gradients - min_gradient) / (max_gradient - min_gradient)
normalized_gradients =normalized_gradients[0]
print(normalized_gradients)
# Convert the normalized_gradients vector to a pandas Series with feature names as index
sensitivity_series = pd.Series(normalized_gradients, index=column_order)

# Convert the Series to a dictionary
sensitivity_dict = sensitivity_series.to_dict()

print(sensitivity_dict)
# Out:
# 17/17 [==============================] - 0s 1ms/step
# [0.1056914  0.01909204 0.31633156 0.12943225 0.12070003 0.19805374
#  0.04175622 0.21351671 0.1175517  0.1300417  0.2576929  0.04072998
#  0.06438732 0.03040166 0.09020447 0.10004671 0.54476478 0.27228621
#  0.65660924 1.         0.36464919 0.18168539 0.74072779 0.4877169
#  0.48958308 0.23476727 0.10797591 0.57725181 0.09901299 0.1896209
#  0.         0.13930789 0.11849625 0.16060414 0.0180653  0.00759793
#  0.29654407 0.50772088 0.72544467 0.69084425 0.7648525 ]
# {'firewall_instructions': 0.10569140074127968, 'nf_router_instructions': 0.019092038936799866, 'ndpi_stats_instructions': 0.3163315616948414, 'payload_scan_instructions': 0.12943224793004726, 'bridge_instructions': 0.12070002870317786, 'firewall_branches': 0.19805374285688795, 'nf_router_branches': 0.04175622479995975, 'ndpi_stats_branches': 0.21351670785191704, 'payload_scan_branches': 0.11755170313687674, 'bridge_branches': 0.1300416970194971, 'ndpi_stats_branch-misses': 0.2576929047098144, 'firewall_branch-load-misses': 0.040729981420261144, 'bridge_branch-load-misses': 0.06438731721638523, 'payload_scan_cache-misses': 0.030401656204231672, 'firewall_cache-references': 0.09020447123460554, 'nf_router_cache-references': 0.1000467135158671, 'ndpi_stats_cache-references': 0.544764776088396, 'payload_scan_cache-references': 0.2722862085686402, 'bridge_cache-references': 0.6566092428147889, 'ndpi_stats_cycles': 1.0, 'firewall_L1-dcache-load-misses': 0.3646491894142968, 'nf_router_L1-dcache-load-misses': 0.18168539462876165, 'ndpi_stats_L1-dcache-load-misses': 0.7407277902839563, 'payload_scan_L1-dcache-load-misses': 0.4877169002813122, 'bridge_L1-dcache-load-misses': 0.48958307654646055, 'firewall_L1-dcache-loads': 0.2347672735645582, 'nf_router_L1-dcache-loads': 0.10797591191819662, 'ndpi_stats_L1-dcache-loads': 0.5772518061858712, 'payload_scan_L1-dcache-loads': 0.09901299182310304, 'bridge_L1-dcache-loads': 0.18962090416747823, 'firewall_LLC-load-misses': 0.0, 'firewall_LLC-stores': 0.1393078879185234, 'nf_router_LLC-stores': 0.11849624621371016, 'ndpi_stats_LLC-stores': 0.16060414356426816, 'payload_scan_LLC-stores': 0.018065301671810013, 'bridge_LLC-stores': 0.007597933796168051, 'firewall_LLC-loads': 0.2965440692513713, 'nf_router_LLC-loads': 0.5077208847729157, 'ndpi_stats_LLC-loads': 0.725444667993037, 'payload_scan_LLC-loads': 0.6908442544345973, 'bridge_LLC-loads': 0.7648525007596465}

# %% [markdown]
# # shap

# %%
#LIME (Local Interpretable Model-agnostic Explanations)

# %%
import shap

# Create a function to predict the output of the model
predict_fn = lambda x: model.predict(x)

# Create a SHAP explainer with the permutation method
explainer = shap.Explainer(predict_fn, X_train, algorithm="permutation")

# Calculate SHAP values for a subset of the test data
num_samples = 100  # You can adjust this value to make it smaller
shap_values = explainer.shap_values(X_test[:num_samples])
# Out:
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:   3%|██▏                                                                    | 3/100 [00:00<?, ?it/s]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:   5%|███▏                                                           | 5/100 [00:13<01:29,  1.06it/s]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:   6%|███▊                                                           | 6/100 [00:16<03:02,  1.94s/it]
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:   7%|████▍                                                          | 7/100 [00:19<03:30,  2.27s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:   8%|█████                                                          | 8/100 [00:21<03:16,  2.14s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:   9%|█████▋                                                         | 9/100 [00:23<03:26,  2.27s/it]
# 260/260 [==============================] - 1s 4ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 2s 4ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  10%|██████▏                                                       | 10/100 [00:29<05:00,  3.34s/it]
# 260/260 [==============================] - 1s 4ms/step
# 260/260 [==============================] - 2s 5ms/step
# 260/260 [==============================] - 2s 6ms/step
# 260/260 [==============================] - 1s 3ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  11%|██████▊                                                       | 11/100 [00:36<06:44,  4.54s/it]
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 4ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 4ms/step
# 132/132 [==============================] - 0s 772us/step
# Permutation explainer:  12%|███████▍                                                      | 12/100 [00:41<06:49,  4.65s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  13%|████████                                                      | 13/100 [00:44<05:51,  4.04s/it]
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  14%|████████▋                                                     | 14/100 [00:47<05:42,  3.98s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  15%|█████████▎                                                    | 15/100 [00:50<05:11,  3.67s/it]
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 4ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 3ms/step
# 132/132 [==============================] - 1s 4ms/step
# Permutation explainer:  16%|█████████▉                                                    | 16/100 [00:56<05:49,  4.16s/it]
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  17%|██████████▌                                                   | 17/100 [01:00<05:48,  4.20s/it]
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  18%|███████████▏                                                  | 18/100 [01:04<05:29,  4.01s/it]
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  19%|███████████▊                                                  | 19/100 [01:07<05:02,  3.73s/it]
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 964us/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  20%|████████████▍                                                 | 20/100 [01:09<04:32,  3.41s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  21%|█████████████                                                 | 21/100 [01:12<04:25,  3.36s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  22%|█████████████▋                                                | 22/100 [01:15<04:13,  3.25s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  23%|██████████████▎                                               | 23/100 [01:19<04:25,  3.45s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  24%|██████████████▉                                               | 24/100 [01:23<04:15,  3.37s/it]
# 260/260 [==============================] - 0s 886us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  25%|███████████████▌                                              | 25/100 [01:25<03:42,  2.96s/it]
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  26%|████████████████                                              | 26/100 [01:28<03:38,  2.95s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  27%|████████████████▋                                             | 27/100 [01:31<03:51,  3.17s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 987us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  28%|█████████████████▎                                            | 28/100 [01:34<03:40,  3.07s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  29%|█████████████████▉                                            | 29/100 [01:37<03:37,  3.06s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 998us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  30%|██████████████████▌                                           | 30/100 [01:39<03:14,  2.78s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 791us/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  31%|███████████████████▏                                          | 31/100 [01:42<03:18,  2.87s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 0s 777us/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  32%|███████████████████▊                                          | 32/100 [01:45<03:17,  2.91s/it]
# 260/260 [==============================] - 0s 987us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  33%|████████████████████▍                                         | 33/100 [01:47<02:53,  2.59s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  34%|█████████████████████                                         | 34/100 [01:50<03:04,  2.79s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  35%|█████████████████████▋                                        | 35/100 [01:55<03:37,  3.35s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  36%|██████████████████████▎                                       | 36/100 [01:58<03:24,  3.20s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 881us/step
# Permutation explainer:  37%|██████████████████████▉                                       | 37/100 [02:00<03:06,  2.97s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  38%|███████████████████████▌                                      | 38/100 [02:03<03:03,  2.95s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 910us/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  39%|████████████████████████▏                                     | 39/100 [02:06<02:49,  2.78s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  40%|████████████████████████▊                                     | 40/100 [02:08<02:37,  2.62s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  41%|█████████████████████████▍                                    | 41/100 [02:11<02:43,  2.78s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 4ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  42%|██████████████████████████                                    | 42/100 [02:15<03:08,  3.25s/it]
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  43%|██████████████████████████▋                                   | 43/100 [02:19<03:04,  3.23s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 782us/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  44%|███████████████████████████▎                                  | 44/100 [02:21<02:45,  2.96s/it]
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 827us/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  45%|███████████████████████████▉                                  | 45/100 [02:24<02:38,  2.88s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  46%|████████████████████████████▌                                 | 46/100 [02:27<02:40,  2.97s/it]
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 0s 846us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  47%|█████████████████████████████▏                                | 47/100 [02:29<02:26,  2.76s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  48%|█████████████████████████████▊                                | 48/100 [02:32<02:21,  2.72s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 837us/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 649us/step
# Permutation explainer:  49%|██████████████████████████████▍                               | 49/100 [02:35<02:21,  2.77s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  50%|███████████████████████████████                               | 50/100 [02:37<02:09,  2.59s/it]
# 260/260 [==============================] - 0s 904us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 953us/step
# Permutation explainer:  51%|███████████████████████████████▌                              | 51/100 [02:39<02:03,  2.53s/it]
# 260/260 [==============================] - 0s 903us/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  52%|████████████████████████████████▏                             | 52/100 [02:42<02:06,  2.63s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 798us/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  53%|████████████████████████████████▊                             | 53/100 [02:45<02:03,  2.62s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 0s 795us/step
# 260/260 [==============================] - 0s 944us/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  54%|█████████████████████████████████▍                            | 54/100 [02:47<01:56,  2.53s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  55%|██████████████████████████████████                            | 55/100 [02:50<02:02,  2.71s/it]
# 260/260 [==============================] - 0s 988us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  56%|██████████████████████████████████▋                           | 56/100 [02:52<01:53,  2.59s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 720us/step
# Permutation explainer:  57%|███████████████████████████████████▎                          | 57/100 [02:56<01:59,  2.79s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  58%|███████████████████████████████████▉                          | 58/100 [02:58<01:49,  2.61s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 0s 925us/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  59%|████████████████████████████████████▌                         | 59/100 [03:01<01:49,  2.66s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 898us/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  60%|█████████████████████████████████████▏                        | 60/100 [03:03<01:40,  2.52s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  61%|█████████████████████████████████████▊                        | 61/100 [03:06<01:42,  2.62s/it]
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 841us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 994us/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  62%|██████████████████████████████████████▍                       | 62/100 [03:08<01:33,  2.46s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 953us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 980us/step
# Permutation explainer:  63%|███████████████████████████████████████                       | 63/100 [03:10<01:25,  2.31s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  64%|███████████████████████████████████████▋                      | 64/100 [03:12<01:28,  2.47s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 787us/step
# 260/260 [==============================] - 0s 959us/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  65%|████████████████████████████████████████▎                     | 65/100 [03:15<01:25,  2.45s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 952us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  66%|████████████████████████████████████████▉                     | 66/100 [03:17<01:19,  2.33s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 799us/step
# Permutation explainer:  67%|█████████████████████████████████████████▌                    | 67/100 [03:20<01:21,  2.47s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 901us/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  68%|██████████████████████████████████████████▏                   | 68/100 [03:22<01:17,  2.41s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  69%|██████████████████████████████████████████▊                   | 69/100 [03:24<01:13,  2.36s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 917us/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  70%|███████████████████████████████████████████▍                  | 70/100 [03:27<01:11,  2.38s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 799us/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  71%|████████████████████████████████████████████                  | 71/100 [03:29<01:10,  2.43s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 994us/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 698us/step
# Permutation explainer:  72%|████████████████████████████████████████████▋                 | 72/100 [03:32<01:09,  2.46s/it]
# 260/260 [==============================] - 0s 988us/step
# 260/260 [==============================] - 0s 989us/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  73%|█████████████████████████████████████████████▎                | 73/100 [03:34<01:06,  2.48s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  74%|█████████████████████████████████████████████▉                | 74/100 [03:36<00:59,  2.28s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 931us/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  75%|██████████████████████████████████████████████▌               | 75/100 [03:38<00:57,  2.30s/it]
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 812us/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  76%|███████████████████████████████████████████████               | 76/100 [03:41<00:57,  2.41s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  77%|███████████████████████████████████████████████▋              | 77/100 [03:44<00:58,  2.54s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 922us/step
# Permutation explainer:  78%|████████████████████████████████████████████████▎             | 78/100 [03:47<00:57,  2.60s/it]
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  79%|████████████████████████████████████████████████▉             | 79/100 [03:50<00:57,  2.74s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  80%|█████████████████████████████████████████████████▌            | 80/100 [03:52<00:51,  2.56s/it]
# 260/260 [==============================] - 0s 878us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  81%|██████████████████████████████████████████████████▏           | 81/100 [03:54<00:48,  2.56s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 886us/step
# Permutation explainer:  82%|██████████████████████████████████████████████████▊           | 82/100 [03:57<00:48,  2.69s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  83%|███████████████████████████████████████████████████▍          | 83/100 [03:59<00:41,  2.43s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  84%|████████████████████████████████████████████████████          | 84/100 [04:02<00:40,  2.55s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 3ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  85%|████████████████████████████████████████████████████▋         | 85/100 [04:06<00:44,  3.00s/it]
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 0s 750us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  86%|█████████████████████████████████████████████████████▎        | 86/100 [04:08<00:39,  2.79s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  87%|█████████████████████████████████████████████████████▉        | 87/100 [04:11<00:33,  2.60s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 0s 971us/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  88%|██████████████████████████████████████████████████████▌       | 88/100 [04:13<00:31,  2.64s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 3ms/step
# 132/132 [==============================] - 0s 812us/step
# Permutation explainer:  89%|███████████████████████████████████████████████████████▏      | 89/100 [04:16<00:27,  2.51s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  90%|███████████████████████████████████████████████████████▊      | 90/100 [04:18<00:26,  2.62s/it]
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 3ms/step
# 260/260 [==============================] - 0s 879us/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 3ms/step
# Permutation explainer:  91%|████████████████████████████████████████████████████████▍     | 91/100 [04:21<00:24,  2.69s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 986us/step
# 260/260 [==============================] - 0s 984us/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  92%|█████████████████████████████████████████████████████████     | 92/100 [04:23<00:19,  2.46s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  93%|█████████████████████████████████████████████████████████▋    | 93/100 [04:26<00:18,  2.65s/it]
# 260/260 [==============================] - 0s 847us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  94%|██████████████████████████████████████████████████████████▎   | 94/100 [04:28<00:14,  2.38s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  95%|██████████████████████████████████████████████████████████▉   | 95/100 [04:31<00:12,  2.43s/it]
# 260/260 [==============================] - 0s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 957us/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer:  96%|███████████████████████████████████████████████████████████▌  | 96/100 [04:33<00:10,  2.51s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 3ms/step
# 132/132 [==============================] - 0s 636us/step
# Permutation explainer:  97%|████████████████████████████████████████████████████████████▏ | 97/100 [04:36<00:07,  2.44s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer:  98%|████████████████████████████████████████████████████████████▊ | 98/100 [04:38<00:04,  2.46s/it]
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 0s 739us/step
# 132/132 [==============================] - 0s 953us/step
# Permutation explainer:  99%|█████████████████████████████████████████████████████████████▍| 99/100 [04:41<00:02,  2.53s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 1ms/step
# Permutation explainer: 100%|█████████████████████████████████████████████████████████████| 100/100 [04:43<00:00,  2.31s/it]
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 1s 2ms/step
# 260/260 [==============================] - 1s 2ms/step
# 132/132 [==============================] - 0s 2ms/step
# Permutation explainer: 101it [04:45,  2.92s/it]

# %%
# Assuming you want to plot the SHAP values for the first data point in X_test
shap.force_plot(explainer.expected_value[0], shap_values[0], X_test.iloc[0])

# %%
# Summarize the SHAP values (optional, helps to visualize the overall impact of features)
shap.summary_plot(shap_values, X_test, plot_type="bar")
fig, ax = plt.subplots(facecolor='white', figsize=(4,10))
#ax.set_facecolor('white')
plt.style.use('classic')

# Assuming you want to plot the SHAP values for the first data point in X_test
shap.force_plot(explainer.expected_value[0], shap_values[0], X_test.iloc[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 8
#       5 plt.style.use('classic')
#       7 # Assuming you want to plot the SHAP values for the first data point in X_test
# ----> 8 shap.force_plot(explainer.expected_value[0], shap_values[0], X_test.iloc[0])
#
# AttributeError: 'Permutation' object has no attribute 'expected_value'

# %%
shap_values_normalized = (shap_values - shap_values.min()) / (shap_values.max() - shap_values.min())

# Get the feature names
feature_names = column_order

# Create a bar plot of the normalized SHAP values
plt.figure(figsize=(10, 6))
plt.barh(range(len(feature_names)), shap_values_normalized.mean(0))
plt.yticks(range(len(feature_names)), feature_names)
plt.xlabel('Normalized SHAP Value')
plt.ylabel('Feature Name')
plt.title('Feature Sensitivity Analysis using SHAP')
plt.show()

# %%
import shap
import matplotlib.pyplot as plt
import numpy as np

# Create a function to predict the output of the model
predict_fn = lambda x: model.predict(x)

# Create a SHAP explainer with the permutation method
explainer = shap.Explainer(predict_fn, X_train, algorithm="permutation")

# Calculate SHAP values for a subset of the test data
num_samples = 1  # You can adjust this value to make it smaller
shap_values = explainer.shap_values(X_test[:num_samples])
# Out:
# 260/260 [==============================] - 0s 792us/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# 260/260 [==============================] - 0s 1ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 19
#      16 shap_values_normalized = (shap_values - shap_values.min()) / (shap_values.max() - shap_values.min())
#      18 # Get the feature names
# ---> 19 feature_names = X_train.columns
#      21 # Sort the features based on their sensitivity (SHAP values) for the specific data point
#      22 sorted_indices = np.argsort(shap_values_normalized[0])[::-1]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
# Normalize the SHAP values to [0, 1]
shap_values_normalized = (shap_values - shap_values.min()) / (shap_values.max() - shap_values.min())

# Create a new DataFrame from the numpy array with the original column names
X_train_df = pd.DataFrame(X_train, columns=feature_names)

# Sort the features based on their sensitivity (SHAP values) for the specific data point
sorted_indices = np.argsort(shap_values_normalized[0])[::-1]

# Create a horizontal bar plot of the normalized SHAP values for the specific data point
plt.figure(figsize=(8, 12))  # Adjust the figsize as needed
plt.barh(range(len(feature_names)), shap_values_normalized[0][sorted_indices], height=0.8, color='white')  # Set color to white
plt.yticks(range(len(feature_names)), np.array(feature_names)[sorted_indices])
plt.xlabel('Normalized SHAP Value')
plt.title('Feature Sensitivity for Data Point 0')  # Change the title accordingly

# Adjust the x-axis limits to reduce empty space on both ends
plt.xlim(0, 1)  # Set the limits according to your preference

plt.tight_layout()
plt.show()

# %%
# Normalize the SHAP values to [0, 1]
shap_values_normalized = (shap_values - shap_values.min()) / (shap_values.max() - shap_values.min())

# Create a new DataFrame from the numpy array with the original column names
X_train_df = pd.DataFrame(X_train, columns=feature_names)

# Sort the features based on their sensitivity (SHAP values) for the specific data point
sorted_indices = np.argsort(shap_values_normalized[0])[::-1]

# Set the background color of the plot to white
plt.rcParams['figure.facecolor'] = 'white'

# Create a horizontal bar plot of the normalized SHAP values for the specific data point
plt.figure(figsize=(8, 8))  # Adjust the figsize as needed
plt.barh(range(len(feature_names)), shap_values_normalized[0][sorted_indices], height=0.6, color='grey')  # Set color to grey
plt.yticks(range(len(feature_names)), np.array(feature_names)[sorted_indices])
plt.xlabel('Normalized SHAP Value')
#plt.title('Feature Sensitivity for Data Point 0')  # Change the title accordingly

# Adjust the x-axis limits to reduce empty space on both ends
plt.xlim(0, 1)  # Set the limits according to your preference

# Adjust the y-axis limits and margins to reduce the distance to the boundary
plt.ylim(0.5, len(feature_names)-0.5)  # Set the limits to remove the gap at the top and bottom
plt.margins(y=0.02)  # Set the margin on the y-axis to reduce the gap between the bars and the boundary

plt.tight_layout()
plt.show()

# %%
# Normalize the SHAP values to [0, 1]
shap_values_normalized = (shap_values - shap_values.min()) / (shap_values.max() - shap_values.min())

# Create a new DataFrame from the numpy array with the original column names
X_train_df = pd.DataFrame(X_train, columns=feature_names)

# Sort the features based on their sensitivity (SHAP values) for the specific data point
sorted_indices = np.argsort(shap_values_normalized[0])[::-1]

# Set the background color of the plot to white
plt.rcParams['figure.facecolor'] = 'white'

# Create a vertical bar plot of the normalized SHAP values for the specific data point
plt.figure(figsize=(8, 12))  # Adjust the figsize as needed
plt.bar(range(len(feature_names)), shap_values_normalized[0][sorted_indices], color='grey')  # Set color to grey
plt.xticks(range(len(feature_names)), np.array(feature_names)[sorted_indices], rotation=90)
plt.ylabel('Normalized SHAP Value')
plt.title('Feature Sensitivity for Data Point 0')  # Change the title accordingly

# Adjust the y-axis limits to reduce empty space on both ends
plt.ylim(0, 1)  # Set the limits according to your preference

# Adjust the x-axis limits and margins to reduce the distance to the boundary
plt.xlim(-0.5, len(feature_names)-0.5)  # Set the limits to remove the gap at the left and right
plt.margins(x=0.02)  # Set the margin on the x-axis to reduce the gap between the bars and the boundary

plt.tight_layout()
plt.show()
