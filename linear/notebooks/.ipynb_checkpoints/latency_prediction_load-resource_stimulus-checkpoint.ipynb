# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys, re, os

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.ensemble import RandomForestRegressor

# %%
# %matplotlib inline

plt.rc('font', family='serif')
plt.rcParams.update({'font.size': 11})

plt.rcParams['figure.dpi'] = 200
plt.rcParams['savefig.dpi'] = 300

# %%
# Change the work directory to the parent
try:
    if chdir:
        pass
except:
    current_dir = os.getcwd()
    os.chdir(current_dir +"/..")
    os.path.abspath(os.curdir)

# %%
chdir = True

# %%
import itertools
marker = itertools.cycle(('x',',', '+', '.', 'o', '*'))
cycol = itertools.cycle('bgrcmk')

# %% [markdown]
# # Service chain configuration

# %%
from IPython.display import IFrame
IFrame("../assets/testbed.png", width=900, height=600)
# Out:
#         <iframe
#             width="900"
#             height="600"
#             src="../assets/testbed.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # load stimulus

# %%
current_dir = os.getcwd()
file_path = os.path.abspath('../linear/datasets/load_stimulus_global.csv')
#file_path = os.path.abspath('../linear/datasets/random_rates_exp-1.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
#data = data.drop('latency', axis=1)
df = data.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1780 entries, 0 to 177
# Data columns (total 63 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   input_rate                          1780 non-null   float64
#  1   output_rate                         1780 non-null   float64
#  2   latency                             1780 non-null   float64
#  3   firewall_instructions               1780 non-null   float64
#  4   nf_router_instructions              1780 non-null   float64
#  5   ndpi_stats_instructions             1780 non-null   float64
#  6   payload_scan_instructions           1780 non-null   float64
#  7   bridge_instructions                 1780 non-null   float64
#  8   firewall_branches                   1780 non-null   float64
#  9   nf_router_branches                  1780 non-null   float64
#  10  ndpi_stats_branches                 1780 non-null   float64
#  11  payload_scan_branches               1780 non-null   float64
#  12  bridge_branches                     1780 non-null   float64
#  13  firewall_branch-misses              1780 non-null   float64
#  14  nf_router_branch-misses             1780 non-null   float64
#  15  ndpi_stats_branch-misses            1780 non-null   float64
#  16  payload_scan_branch-misses          1780 non-null   float64
#  17  bridge_branch-misses                1780 non-null   float64
#  18  firewall_branch-load-misses         1780 non-null   float64
#  19  nf_router_branch-load-misses        1780 non-null   float64
#  20  ndpi_stats_branch-load-misses       1780 non-null   float64
#  21  payload_scan_branch-load-misses     1780 non-null   float64
#  22  bridge_branch-load-misses           1780 non-null   float64
#  23  firewall_cache-misses               1780 non-null   float64
#  24  nf_router_cache-misses              1780 non-null   float64
#  25  ndpi_stats_cache-misses             1780 non-null   float64
#  26  payload_scan_cache-misses           1780 non-null   float64
#  27  bridge_cache-misses                 1780 non-null   float64
#  28  firewall_cache-references           1780 non-null   float64
#  29  nf_router_cache-references          1780 non-null   float64
#  30  ndpi_stats_cache-references         1780 non-null   float64
#  31  payload_scan_cache-references       1780 non-null   float64
#  32  bridge_cache-references             1780 non-null   float64
#  33  firewall_cycles                     1780 non-null   float64
#  34  nf_router_cycles                    1780 non-null   float64
#  35  ndpi_stats_cycles                   1780 non-null   float64
#  36  payload_scan_cycles                 1780 non-null   float64
#  37  bridge_cycles                       1780 non-null   float64
#  38  firewall_L1-dcache-load-misses      1780 non-null   float64
#  39  nf_router_L1-dcache-load-misses     1780 non-null   float64
#  40  ndpi_stats_L1-dcache-load-misses    1780 non-null   float64
#  41  payload_scan_L1-dcache-load-misses  1780 non-null   float64
#  42  bridge_L1-dcache-load-misses        1780 non-null   float64
#  43  firewall_L1-dcache-loads            1780 non-null   float64
#  44  nf_router_L1-dcache-loads           1780 non-null   float64
#  45  ndpi_stats_L1-dcache-loads          1780 non-null   float64
#  46  payload_scan_L1-dcache-loads        1780 non-null   float64
#  47  bridge_L1-dcache-loads              1780 non-null   float64
#  48  firewall_LLC-load-misses            1780 non-null   float64
#  49  nf_router_LLC-load-misses           1780 non-null   float64
#  50  ndpi_stats_LLC-load-misses          1780 non-null   float64
#  51  payload_scan_LLC-load-misses        1780 non-null   float64
#  52  bridge_LLC-load-misses              1780 non-null   float64
#  53  firewall_LLC-stores                 1780 non-null   float64
#  54  nf_router_LLC-stores                1780 non-null   float64
#  55  ndpi_stats_LLC-stores               1780 non-null   float64
#  56  payload_scan_LLC-stores             1780 non-null   float64
#  57  bridge_LLC-stores                   1780 non-null   float64
#  58  firewall_LLC-loads                  1780 non-null   float64
#  59  nf_router_LLC-loads                 1780 non-null   float64
#  60  ndpi_stats_LLC-loads                1780 non-null   float64
#  61  payload_scan_LLC-loads              1780 non-null   float64
#  62  bridge_LLC-loads                    1780 non-null   float64
# dtypes: float64(63)
# memory usage: 890.0 KB

# %% [markdown]
# # DNN to predict rate (training set: global)

# %%
current_dir = os.getcwd()
file_path = os.path.abspath('../linear/datasets/load_stimulus_global.csv')
#file_path = os.path.abspath('../linear/datasets/load_stimulus_global_4.csv')
#file_path = os.path.abspath('../linear/datasets/random_rates_exp-1.csv')
#file_path = os.path.abspath('../Dag/dag-2/datasets/load_stimulus_global.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
df = data.dropna()

# %%
# data set
# load_stimulus_global.csv: exp1_exp10
# load_stimulus_global_1.csv:exp1_exp10+fixed_5000+fixed_7500
# load_stimulus_global_2.csv:exp1_exp10+fixed_5000+fixed_7500+random
# load_stimulus_global_3.csv:exp1_exp10+random
#load_stimulus_global_4.csv:exp1_exp10+stage_random
# performance: global>3>2>1

# %%
# training 
X = df.drop(['input_rate','output_rate', 'latency'], axis=1)
X = df.drop(['input_rate','output_rate', 'latency','firewall_cycles','payload_scan_cycles','ndpi_stats_branch-load-misses',
             'nf_router_cycles','bridge_cycles','payload_scan_LLC-load-misses','payload_scan_LLC-load-misses','bridge_LLC-load-misses',
             'bridge_cache-misses','bridge_cache-misses','nf_router_cache-misses','firewall_cache-misses','nf_router_LLC-load-misses',
             'ndpi_stats_LLC-load-misses','nf_router_branch-load-misses','nf_router_branch-misses','payload_scan_branch-load-misses',
             'payload_scan_branch-misses','bridge_branch-misses','ndpi_stats_branch-load-misses','ndpi_stats_cache-misses','firewall_branch-misses'], axis=1)

y = df['latency']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

column_order = X_train.columns
X_test = X_test[column_order]


# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print(len(y))
# Out:
# 1780

# %%
# model
model = Sequential()

# Add input layer and hidden layers
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(32, activation='relu'))

# Add output layer
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=8, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 156/156 [==============================] - 1s 3ms/step - loss: 3265.9827
# Epoch 2/100
# 156/156 [==============================] - 1s 4ms/step - loss: 2349.5823
# Epoch 3/100
# 156/156 [==============================] - 1s 3ms/step - loss: 1932.7942
# Epoch 4/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1589.3256
# Epoch 5/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1236.4493
# Epoch 6/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1239.0503
# Epoch 7/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1191.3286
# Epoch 8/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1029.9960
# Epoch 9/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1157.1315
# Epoch 10/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1051.9536
# Epoch 11/100
# 156/156 [==============================] - 0s 3ms/step - loss: 956.1492
# Epoch 12/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1162.1656
# Epoch 13/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1078.7180
# Epoch 14/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1124.5375
# Epoch 15/100
# 156/156 [==============================] - 0s 3ms/step - loss: 994.4871
# Epoch 16/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1022.7791
# Epoch 17/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1053.2322
# Epoch 18/100
# 156/156 [==============================] - 0s 3ms/step - loss: 982.4969
# Epoch 19/100
# 156/156 [==============================] - 0s 3ms/step - loss: 928.1379
# Epoch 20/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1033.2134
# Epoch 21/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1001.3400
# Epoch 22/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1262.7251
# Epoch 23/100
# 156/156 [==============================] - 0s 3ms/step - loss: 994.6668
# Epoch 24/100
# 156/156 [==============================] - 0s 3ms/step - loss: 911.1260
# Epoch 25/100
# 156/156 [==============================] - 0s 3ms/step - loss: 990.9255
# Epoch 26/100
# 156/156 [==============================] - 0s 3ms/step - loss: 959.2988
# Epoch 27/100
# 156/156 [==============================] - 0s 3ms/step - loss: 920.0786
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# accuracy
threshold = 0.05  
y_pred=np.array(y_pred)
y_pred = [item for subset in y_pred for item in subset]
y_test=np.array(y_test)
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot

fig, ax = plt.subplots(facecolor='white', figsize=(4,3))
#ax.set_facecolor('white')
plt.style.use('classic')

plt.plot(y_pred[0:100], marker='o',c='r',markersize = 2, linewidth = 0.8, linestyle='-', markeredgecolor='red', dashes=(5, 3),label='Prediction')
plt.plot(y_test.tolist()[0:100], c='b',linestyle='-',linewidth = 0.8,label='Real')


plt.legend(loc="upper right", fontsize=10)
fig.text(0.5, 0.01, 'Series', size='12', ha='center')
fig.text(0.01, 0.5, 'Values', size='12', va='center', rotation='vertical')
plt.subplots_adjust(left=0.12, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.4)
#plt.grid()
ax.set_facecolor('white')

# Set y-axis tick format
formatter = mticker.FuncFormatter(lambda x, pos: f"{int(x/1000)}")
ax.yaxis.set_major_formatter(formatter)
# Set text in the upper left corner of the figure
fig.text(0.12, 0.98, '1e3', size='12', ha='left', va='top')

#save figure
folder_path = 'figure/latency_prediction'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
file_path = os.path.join(folder_path, 'accuracy-linear-testset.pdf' )
plt.savefig(file_path)

plt.show()
# Out:
# 17/17 [==============================] - 0s 1ms/step
# [0.0, 29.40074906367041, 53.37078651685393, 68.72659176029963, 79.5880149812734, 84.6441947565543, 87.64044943820225, 88.95131086142321, 89.51310861423221, 90.2621722846442, 90.63670411985018]

# %%
# predict dataset 'linear'

# read the CSV file
path = '../linear/datasets/load_stimulus_exp1.csv'

df = pd.read_csv(path)
df = df.replace(['<not counted>'], np.nan)
df = df.dropna()

# separate the features and target variable
X_test = df.drop(['Unnamed: 0','input_rate', 'output_rate', 'latency'], axis=1)
X_test = df.drop(['Unnamed: 0','input_rate','output_rate', 'latency','firewall_cycles','payload_scan_cycles','ndpi_stats_branch-load-misses',
             'nf_router_cycles','bridge_cycles','payload_scan_LLC-load-misses','payload_scan_LLC-load-misses','bridge_LLC-load-misses',
             'bridge_cache-misses','bridge_cache-misses','nf_router_cache-misses','firewall_cache-misses','nf_router_LLC-load-misses',
             'ndpi_stats_LLC-load-misses','nf_router_branch-load-misses','nf_router_branch-misses','payload_scan_branch-load-misses',
             'payload_scan_branch-misses','bridge_branch-misses','ndpi_stats_branch-load-misses','ndpi_stats_cache-misses','firewall_branch-misses'], axis=1)
y_test =df['latency'].values

# standardize the features
scaler = StandardScaler()
X_test = scaler.fit_transform(X_test)

# evaluate
y_pred = model.predict(X_test)
y_pred = np.array(y_pred)
mse = mean_squared_error(y_test, y_pred)

# accuracy
threshold = 0.05
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print(f'accurancy with thoreshold 5%:{accuracy_within_threshold}')

accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot

fig, ax = plt.subplots(facecolor='white', figsize=(4,3))
#ax.set_facecolor('white')
plt.style.use('classic')

plt.plot(y_pred, marker='o', c='r',markersize = 2,linewidth = 0.8,  markeredgecolor='red', linestyle='-', dashes=(5, 3),label='Prediction')
plt.plot(y_test.tolist(), c='b',linestyle='-',linewidth = 0.8, label='Real')

plt.legend(loc="upper right", fontsize=10)
fig.text(0.5, 0.01, 'Series', size='12', ha='center')
fig.text(0.01, 0.5, 'Values', size='12', va='center', rotation='vertical')
plt.subplots_adjust(left=0.12, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.4)
#plt.grid()
ax.set_facecolor('white')

# Set x-axis and y-axis limits
plt.xlim(0, 180)
plt.ylim(0, 350)

# Set y-axis tick format
formatter = mticker.FuncFormatter(lambda x, pos: f"{x/100:.1f}")
ax.yaxis.set_major_formatter(formatter)
# Set text in the upper left corner of the figure
fig.text(0.12, 0.98, '1e2', size='12', ha='left', va='top')



#save figure
folder_path = 'figure/latency_prediction'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
file_path = os.path.join(folder_path, 'accuracy-latency-linear.pdf' )
plt.savefig(file_path)
plt.show()
# Out:
# 6/6 [==============================] - 0s 2ms/step
# accurancy with thoreshold 5%:[11.23595506]
# [array([0.]), array([31.46067416]), array([49.43820225]), array([63.48314607]), array([76.96629213]), array([83.14606742]), array([89.3258427]), array([90.4494382]), array([91.57303371]), array([91.57303371]), array([91.57303371])]

# %% [markdown]
# # resource stimulus

# %%
corr = data.corr()
correlation_list = []
for i in range(62,63):
    for j in range(len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between latency and latency: 1.00
# Correlation between latency and bridge_L1-dcache-load-misses: 0.66
# Correlation between latency and bridge_LLC-loads: 0.66
# Correlation between latency and bridge_LLC-stores: 0.65
# Correlation between latency and bridge_cache-references: 0.65
# Correlation between latency and payload_scan_LLC-stores: 0.61
# Correlation between latency and payload_scan_cache-references: 0.60
# Correlation between latency and payload_scan_L1-dcache-load-misses: 0.60
# Correlation between latency and payload_scan_LLC-loads: 0.57
# Correlation between latency and output_rate: 0.54
# Correlation between latency and nf_router_LLC-stores: 0.50
# Correlation between latency and nf_router_L1-dcache-load-misses: 0.47
# Correlation between latency and nf_router_cache-references: 0.47
# Correlation between latency and nf_router_LLC-loads: 0.45
# Correlation between latency and firewall_LLC-loads: 0.45
# Correlation between latency and firewall_L1-dcache-load-misses: 0.38
# Correlation between latency and ndpi_stats_L1-dcache-load-misses: 0.38
# Correlation between latency and ndpi_stats_LLC-loads: 0.37
# Correlation between latency and firewall_cache-references: 0.37
# Correlation between latency and ndpi_stats_cache-references: 0.37
# Correlation between latency and ndpi_stats_LLC-stores: 0.37
# Correlation between latency and payload_scan_cycles: 0.29
# Correlation between latency and payload_scan_branch-misses: 0.27
# Correlation between latency and firewall_LLC-stores: 0.27
# Correlation between latency and payload_scan_branch-load-misses: 0.27
# Correlation between latency and bridge_cycles: 0.24
# Correlation between latency and payload_scan_branches: 0.21
# Correlation between latency and payload_scan_instructions: 0.21
# Correlation between latency and bridge_branch-misses: 0.21
# Correlation between latency and payload_scan_L1-dcache-loads: 0.21
# Correlation between latency and bridge_branch-load-misses: 0.21
# Correlation between latency and nf_router_branch-misses: 0.21
# Correlation between latency and nf_router_branch-load-misses: 0.21
# Correlation between latency and ndpi_stats_cycles: 0.20
# Correlation between latency and nf_router_cycles: 0.20
# Correlation between latency and firewall_cycles: 0.19
# Correlation between latency and ndpi_stats_branch-load-misses: 0.19
# Correlation between latency and ndpi_stats_branch-misses: 0.19
# Correlation between latency and firewall_L1-dcache-loads: 0.17
# Correlation between latency and firewall_branches: 0.17
# Correlation between latency and firewall_branch-load-misses: 0.17
# Correlation between latency and ndpi_stats_branches: 0.17
# Correlation between latency and firewall_branch-misses: 0.17
# Correlation between latency and ndpi_stats_L1-dcache-loads: 0.17
# Correlation between latency and firewall_instructions: 0.17
# Correlation between latency and ndpi_stats_instructions: 0.17
# Correlation between latency and nf_router_branches: 0.16
# Correlation between latency and nf_router_instructions: 0.16
# Correlation between latency and nf_router_L1-dcache-loads: 0.16
# Correlation between latency and bridge_L1-dcache-loads: 0.13
# Correlation between latency and bridge_branches: 0.13
# Correlation between latency and bridge_instructions: 0.13
# Correlation between latency and input_rate: 0.10
# Correlation between latency and bridge_cache-misses: 0.06
# Correlation between latency and payload_scan_cache-misses: 0.05
# Correlation between latency and payload_scan_LLC-load-misses: 0.05
# Correlation between latency and ndpi_stats_LLC-load-misses: 0.05
# Correlation between latency and firewall_cache-misses: 0.04
# Correlation between latency and bridge_LLC-load-misses: 0.04
# Correlation between latency and ndpi_stats_cache-misses: 0.03
# Correlation between latency and firewall_LLC-load-misses: 0.02
# Correlation between latency and nf_router_cache-misses: 0.02
# Correlation between latency and nf_router_LLC-load-misses: 0.01

# %%
current_dir = os.getcwd()
file_path = os.path.abspath('../linear/datasets/resource_stimulus_global_A-B-C.csv')

data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
df = data.dropna()

# %%
# training 
#X = df.drop(['input_rate','output_rate', 'latency', 'nf_router_LLC-load-misses','nf_router_cache-misses',\
 #            'firewall_LLC-load-misses','ndpi_stats_cache-misses','ndpi_stats_LLC-load-misses','bridge_cache-misses',\
 #            'bridge_instructions','bridge_branches','firewall_instructions' ], axis=1)
X=df.drop(['input_rate','output_rate', 'latency'], axis=1)
y = df['latency']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

column_order = X_train.columns
X_test = X_test[column_order]


# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print(len(y))
# Out:
# 2239

# %%
# model
model = Sequential()

# Add input layer and hidden layers
model.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(8, activation='relu'))

# Add output layer
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=8, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 196/196 [==============================] - 1s 3ms/step - loss: 37911848.0000
# Epoch 2/10
# 196/196 [==============================] - 1s 3ms/step - loss: 22764836.0000
# Epoch 3/10
# 196/196 [==============================] - 1s 3ms/step - loss: 22473092.0000
# Epoch 4/10
# 196/196 [==============================] - 1s 3ms/step - loss: 22061552.0000
# Epoch 5/10
# 196/196 [==============================] - 1s 3ms/step - loss: 21975838.0000
# Epoch 6/10
# 196/196 [==============================] - 1s 3ms/step - loss: 21893892.0000
# Epoch 7/10
# 196/196 [==============================] - 1s 3ms/step - loss: 21753730.0000
# Epoch 8/10
# 196/196 [==============================] - 1s 3ms/step - loss: 21756586.0000
# Epoch 9/10
# 196/196 [==============================] - 1s 3ms/step - loss: 21784454.0000
# Epoch 10/10
# 196/196 [==============================] - 1s 3ms/step - loss: 21660264.0000

# %%
# Make predictions on the test set
import matplotlib.ticker as mticker

y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# accuracy
threshold = 0.05  
y_pred=np.array(y_pred)
y_pred = [item for subset in y_pred for item in subset]
y_test=np.array(y_test)
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot

fig, ax = plt.subplots(facecolor='white', figsize=(4,3))
#ax.set_facecolor('white')
plt.style.use('classic')

plt.plot(y_pred[0:100], marker='o',c='r',markersize = 2, linewidth = 0.8, linestyle='-', markeredgecolor='red', dashes=(5, 3),label='Prediction')
plt.plot(y_test.tolist()[0:100], c='b',linestyle='-',linewidth = 0.8,label='Real')


plt.legend(loc="upper right", fontsize=10)
fig.text(0.5, 0.01, 'Series', size='12', ha='center')
fig.text(0.01, 0.5, 'Values', size='12', va='center', rotation='vertical')
plt.subplots_adjust(left=0.12, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.4)
#plt.grid()
ax.set_facecolor('white')

# Set y-axis tick format
formatter = mticker.FuncFormatter(lambda x, pos: f"{int(x/1000)}")
ax.yaxis.set_major_formatter(formatter)
# Set text in the upper left corner of the figure
fig.text(0.12, 0.98, '1e3', size='12', ha='left', va='top')

#save figure
folder_path = 'figure/latency_prediction'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
file_path = os.path.join(folder_path, 'accuracy-linear-testset-resource.pdf' )
plt.savefig(file_path)

plt.show()
# Out:
# 21/21 [==============================] - 0s 1ms/step
# [0.0, 2.380952380952381, 5.357142857142857, 10.267857142857142, 15.178571428571427, 20.089285714285715, 24.404761904761905, 27.827380952380953, 27.976190476190478, 28.273809523809522, 29.315476190476193]

# %%
# predict dataset 'linear'

# read the CSV file
path = '../linear/datasets/resource_stimulus_exp-4-1-1.csv'

df = pd.read_csv(path)
df = df.replace(['<not counted>'], np.nan)
df = df.dropna()

# separate the features and target variable


X_test = df.drop(['input_rate','output_rate', 'latency' ], axis=1)

y_test =df['latency'].values

# standardize the features
scaler = StandardScaler()
X_test = scaler.fit_transform(X_test)

# evaluate
y_pred = model.predict(X_test)
y_pred = np.array(y_pred)
mse = mean_squared_error(y_test, y_pred)

# accuracy
threshold = 0.05
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print(f'accurancy with thoreshold 5%:{accuracy_within_threshold}')

accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot

fig, ax = plt.subplots(facecolor='white', figsize=(4,3))
#ax.set_facecolor('white')
plt.style.use('classic')

plt.plot(y_pred, marker='o', c='r',markersize = 2,linewidth = 0.8,  markeredgecolor='red', linestyle='-', dashes=(5, 3),label='Prediction')
plt.plot(y_test.tolist(), c='b',linestyle='-',linewidth = 0.8, label='Real')

plt.legend(loc="upper right", fontsize=10)
fig.text(0.5, 0.01, 'Series', size='12', ha='center')
fig.text(0.01, 0.5, 'Values', size='12', va='center', rotation='vertical')
plt.subplots_adjust(left=0.12, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.4)
#plt.grid()
ax.set_facecolor('white')

# Set x-axis and y-axis limits
plt.xlim(0, 45)


# Set y-axis tick format
#formatter = mticker.FuncFormatter(lambda x, pos: f"{x/10000:.1f}")
#ax.yaxis.set_major_formatter(formatter)
# Set text in the upper left corner of the figure
#fig.text(0.12, 0.98, '1e4', size='12', ha='left', va='top')



#save figure
folder_path = 'figure/latency_prediction'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
file_path = os.path.join(folder_path, 'accuracy-latency-linear-resource.pdf' )
plt.savefig(file_path)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[220], line 22
#      19 X_test = scaler.fit_transform(X_test)
#      21 # evaluate
# ---> 22 y_pred = model.predict(X_test)
#      23 y_pred = np.array(y_pred)
#      24 mse = mean_squared_error(y_test, y_pred)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sequential_19/dense_56/Relu' defined at (most recent call last):
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#       app.start()
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#       self.io_loop.start()
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 603, in run_forever
#       self._run_once()
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1906, in _run_once
#       handle._run()
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py", line 2961, in run_cell
#       result = self._run_cell(
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py", line 3016, in _run_cell
#       result = runner(coro)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py", line 3221, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py", line 3400, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\Qiong\AppData\Local\Temp\ipykernel_29256\2005580816.py", line 22, in <module>
#       y_pred = model.predict(X_test)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 2382, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 2169, in predict_function
#       return step_function(self, iterator)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 2155, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 2143, in run_step
#       outputs = model.predict_step(data)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 2111, in predict_step
#       return self(x, training=False)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 558, in __call__
#       return super().__call__(*args, **kwargs)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\base_layer.py", line 1145, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\sequential.py", line 412, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\functional.py", line 512, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\functional.py", line 669, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\base_layer.py", line 1145, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\layers\core\dense.py", line 255, in call
#       outputs = self.activation(outputs)
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\activations.py", line 317, in relu
#       return backend.relu(
#     File "C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\backend.py", line 5396, in relu
#       x = tf.nn.relu(x)
# Node: 'sequential_19/dense_56/Relu'
# Matrix size-incompatible: In[0]: [32,61], In[1]: [60,32]
# 	 [[{{node sequential_19/dense_56/Relu}}]] [Op:__inference_predict_function_507792]
