# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys, re, os

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.ensemble import RandomForestRegressor

# %%
# %matplotlib inline

plt.rc('font', family='serif')
plt.rcParams.update({'font.size': 11})

plt.rcParams['figure.dpi'] = 200
plt.rcParams['savefig.dpi'] = 300

# %%
# Change the work directory to the parent
try:
    if chdir:
        pass
except:
    current_dir = os.getcwd()
    os.chdir(current_dir +"/..")
    os.path.abspath(os.curdir)

# %%
chdir = True

# %%
import itertools
marker = itertools.cycle(('x',',', '+', '.', 'o', '*'))
cycol = itertools.cycle('bgrcmk')

# %% [markdown]
# # Service chain configuration

# %%
from IPython.display import IFrame
IFrame("..//linear//assets//testbed.png", width=600, height=420)
# Out:
#         <iframe
#             width="600"
#             height="420"
#             src="..//linear//assets//testbed.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
current_dir = os.getcwd()
file_path = os.path.abspath('../linear/datasets/load_stimulus_global.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
#data = data.drop('latency', axis=1)
df = data.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1780 entries, 0 to 177
# Data columns (total 63 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   input_rate                          1780 non-null   float64
#  1   output_rate                         1780 non-null   float64
#  2   latency                             1780 non-null   float64
#  3   firewall_instructions               1780 non-null   float64
#  4   nf_router_instructions              1780 non-null   float64
#  5   ndpi_stats_instructions             1780 non-null   float64
#  6   payload_scan_instructions           1780 non-null   float64
#  7   bridge_instructions                 1780 non-null   float64
#  8   firewall_branches                   1780 non-null   float64
#  9   nf_router_branches                  1780 non-null   float64
#  10  ndpi_stats_branches                 1780 non-null   float64
#  11  payload_scan_branches               1780 non-null   float64
#  12  bridge_branches                     1780 non-null   float64
#  13  firewall_branch-misses              1780 non-null   float64
#  14  nf_router_branch-misses             1780 non-null   float64
#  15  ndpi_stats_branch-misses            1780 non-null   float64
#  16  payload_scan_branch-misses          1780 non-null   float64
#  17  bridge_branch-misses                1780 non-null   float64
#  18  firewall_branch-load-misses         1780 non-null   float64
#  19  nf_router_branch-load-misses        1780 non-null   float64
#  20  ndpi_stats_branch-load-misses       1780 non-null   float64
#  21  payload_scan_branch-load-misses     1780 non-null   float64
#  22  bridge_branch-load-misses           1780 non-null   float64
#  23  firewall_cache-misses               1780 non-null   float64
#  24  nf_router_cache-misses              1780 non-null   float64
#  25  ndpi_stats_cache-misses             1780 non-null   float64
#  26  payload_scan_cache-misses           1780 non-null   float64
#  27  bridge_cache-misses                 1780 non-null   float64
#  28  firewall_cache-references           1780 non-null   float64
#  29  nf_router_cache-references          1780 non-null   float64
#  30  ndpi_stats_cache-references         1780 non-null   float64
#  31  payload_scan_cache-references       1780 non-null   float64
#  32  bridge_cache-references             1780 non-null   float64
#  33  firewall_cycles                     1780 non-null   float64
#  34  nf_router_cycles                    1780 non-null   float64
#  35  ndpi_stats_cycles                   1780 non-null   float64
#  36  payload_scan_cycles                 1780 non-null   float64
#  37  bridge_cycles                       1780 non-null   float64
#  38  firewall_L1-dcache-load-misses      1780 non-null   float64
#  39  nf_router_L1-dcache-load-misses     1780 non-null   float64
#  40  ndpi_stats_L1-dcache-load-misses    1780 non-null   float64
#  41  payload_scan_L1-dcache-load-misses  1780 non-null   float64
#  42  bridge_L1-dcache-load-misses        1780 non-null   float64
#  43  firewall_L1-dcache-loads            1780 non-null   float64
#  44  nf_router_L1-dcache-loads           1780 non-null   float64
#  45  ndpi_stats_L1-dcache-loads          1780 non-null   float64
#  46  payload_scan_L1-dcache-loads        1780 non-null   float64
#  47  bridge_L1-dcache-loads              1780 non-null   float64
#  48  firewall_LLC-load-misses            1780 non-null   float64
#  49  nf_router_LLC-load-misses           1780 non-null   float64
#  50  ndpi_stats_LLC-load-misses          1780 non-null   float64
#  51  payload_scan_LLC-load-misses        1780 non-null   float64
#  52  bridge_LLC-load-misses              1780 non-null   float64
#  53  firewall_LLC-stores                 1780 non-null   float64
#  54  nf_router_LLC-stores                1780 non-null   float64
#  55  ndpi_stats_LLC-stores               1780 non-null   float64
#  56  payload_scan_LLC-stores             1780 non-null   float64
#  57  bridge_LLC-stores                   1780 non-null   float64
#  58  firewall_LLC-loads                  1780 non-null   float64
#  59  nf_router_LLC-loads                 1780 non-null   float64
#  60  ndpi_stats_LLC-loads                1780 non-null   float64
#  61  payload_scan_LLC-loads              1780 non-null   float64
#  62  bridge_LLC-loads                    1780 non-null   float64
# dtypes: float64(63)
# memory usage: 890.0 KB

# %%
corr = data.corr()
correlation_list = []
for i in range(1,2):
    for j in range(i+1, len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between output_rate and ndpi_stats_LLC-loads: 0.98
# Correlation between output_rate and ndpi_stats_L1-dcache-load-misses: 0.98
# Correlation between output_rate and ndpi_stats_cache-references: 0.98
# Correlation between output_rate and payload_scan_LLC-loads: 0.98
# Correlation between output_rate and payload_scan_cache-references: 0.97
# Correlation between output_rate and nf_router_LLC-loads: 0.97
# Correlation between output_rate and payload_scan_L1-dcache-load-misses: 0.97
# Correlation between output_rate and firewall_LLC-stores: 0.97
# Correlation between output_rate and nf_router_cache-references: 0.97
# Correlation between output_rate and nf_router_L1-dcache-load-misses: 0.97
# Correlation between output_rate and firewall_cache-references: 0.97
# Correlation between output_rate and bridge_LLC-stores: 0.97
# Correlation between output_rate and ndpi_stats_LLC-stores: 0.97
# Correlation between output_rate and firewall_L1-dcache-load-misses: 0.97
# Correlation between output_rate and firewall_LLC-loads: 0.96
# Correlation between output_rate and payload_scan_LLC-stores: 0.96
# Correlation between output_rate and nf_router_LLC-stores: 0.96
# Correlation between output_rate and bridge_L1-dcache-load-misses: 0.95
# Correlation between output_rate and bridge_cache-references: 0.95
# Correlation between output_rate and bridge_LLC-loads: 0.94
# Correlation between output_rate and payload_scan_L1-dcache-loads: 0.92
# Correlation between output_rate and payload_scan_instructions: 0.92
# Correlation between output_rate and payload_scan_branches: 0.92
# Correlation between output_rate and firewall_L1-dcache-loads: 0.89
# Correlation between output_rate and firewall_instructions: 0.89
# Correlation between output_rate and firewall_branches: 0.89
# Correlation between output_rate and nf_router_L1-dcache-loads: 0.86
# Correlation between output_rate and nf_router_instructions: 0.86
# Correlation between output_rate and nf_router_branches: 0.86
# Correlation between output_rate and bridge_L1-dcache-loads: 0.79
# Correlation between output_rate and bridge_branches: 0.79
# Correlation between output_rate and bridge_instructions: 0.79
# Correlation between output_rate and ndpi_stats_branches: 0.78
# Correlation between output_rate and ndpi_stats_L1-dcache-loads: 0.78
# Correlation between output_rate and ndpi_stats_instructions: 0.78
# Correlation between output_rate and latency: 0.67
# Correlation between output_rate and firewall_branch-load-misses: 0.65
# Correlation between output_rate and firewall_branch-misses: 0.65
# Correlation between output_rate and ndpi_stats_cache-misses: 0.65
# Correlation between output_rate and bridge_branch-load-misses: 0.52
# Correlation between output_rate and bridge_branch-misses: 0.52
# Correlation between output_rate and payload_scan_branch-misses: 0.50
# Correlation between output_rate and payload_scan_branch-load-misses: 0.50
# Correlation between output_rate and nf_router_branch-misses: 0.40
# Correlation between output_rate and nf_router_branch-load-misses: 0.40
# Correlation between output_rate and ndpi_stats_LLC-load-misses: 0.40
# Correlation between output_rate and nf_router_LLC-load-misses: 0.37
# Correlation between output_rate and firewall_cache-misses: 0.36
# Correlation between output_rate and nf_router_cache-misses: 0.35
# Correlation between output_rate and firewall_LLC-load-misses: 0.33
# Correlation between output_rate and bridge_cache-misses: 0.32
# Correlation between output_rate and bridge_LLC-load-misses: 0.28
# Correlation between output_rate and payload_scan_cache-misses: 0.18
# Correlation between output_rate and payload_scan_LLC-load-misses: 0.16
# Correlation between output_rate and nf_router_cycles: 0.14
# Correlation between output_rate and bridge_cycles: 0.14
# Correlation between output_rate and ndpi_stats_cycles: 0.14
# Correlation between output_rate and ndpi_stats_branch-misses: 0.10
# Correlation between output_rate and ndpi_stats_branch-load-misses: 0.10
# Correlation between output_rate and payload_scan_cycles: 0.08
# Correlation between output_rate and firewall_cycles: 0.06

# %%
corr = data.corr()
correlation_list = []
for i in range(2,3):
    for j in range(i+1, len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between latency and ndpi_stats_LLC-loads: 0.59
# Correlation between latency and ndpi_stats_cache-references: 0.58
# Correlation between latency and ndpi_stats_L1-dcache-load-misses: 0.57
# Correlation between latency and payload_scan_LLC-loads: 0.57
# Correlation between latency and firewall_LLC-loads: 0.56
# Correlation between latency and firewall_cache-references: 0.56
# Correlation between latency and firewall_L1-dcache-load-misses: 0.56
# Correlation between latency and payload_scan_cache-references: 0.56
# Correlation between latency and nf_router_LLC-loads: 0.56
# Correlation between latency and payload_scan_L1-dcache-load-misses: 0.56
# Correlation between latency and firewall_LLC-stores: 0.56
# Correlation between latency and nf_router_L1-dcache-loads: 0.56
# Correlation between latency and nf_router_instructions: 0.55
# Correlation between latency and nf_router_branches: 0.55
# Correlation between latency and nf_router_cache-references: 0.55
# Correlation between latency and nf_router_L1-dcache-load-misses: 0.55
# Correlation between latency and ndpi_stats_LLC-stores: 0.54
# Correlation between latency and bridge_LLC-stores: 0.54
# Correlation between latency and nf_router_LLC-stores: 0.53
# Correlation between latency and payload_scan_LLC-stores: 0.53
# Correlation between latency and bridge_L1-dcache-load-misses: 0.50
# Correlation between latency and bridge_cache-references: 0.50
# Correlation between latency and payload_scan_L1-dcache-loads: 0.48
# Correlation between latency and firewall_L1-dcache-loads: 0.48
# Correlation between latency and payload_scan_instructions: 0.48
# Correlation between latency and bridge_LLC-loads: 0.48
# Correlation between latency and firewall_instructions: 0.48
# Correlation between latency and firewall_branches: 0.48
# Correlation between latency and payload_scan_branches: 0.48
# Correlation between latency and ndpi_stats_branches: 0.47
# Correlation between latency and ndpi_stats_L1-dcache-loads: 0.47
# Correlation between latency and ndpi_stats_instructions: 0.47
# Correlation between latency and bridge_branches: 0.41
# Correlation between latency and bridge_L1-dcache-loads: 0.41
# Correlation between latency and bridge_instructions: 0.41
# Correlation between latency and ndpi_stats_cache-misses: 0.33
# Correlation between latency and nf_router_branch-misses: 0.33
# Correlation between latency and nf_router_branch-load-misses: 0.33
# Correlation between latency and firewall_branch-load-misses: 0.30
# Correlation between latency and firewall_branch-misses: 0.29
# Correlation between latency and bridge_branch-load-misses: 0.27
# Correlation between latency and bridge_branch-misses: 0.27
# Correlation between latency and nf_router_cycles: 0.25
# Correlation between latency and ndpi_stats_LLC-load-misses: 0.24
# Correlation between latency and bridge_LLC-load-misses: 0.16
# Correlation between latency and nf_router_LLC-load-misses: 0.14
# Correlation between latency and ndpi_stats_cycles: 0.14
# Correlation between latency and ndpi_stats_branch-misses: 0.14
# Correlation between latency and ndpi_stats_branch-load-misses: 0.14
# Correlation between latency and firewall_LLC-load-misses: 0.13
# Correlation between latency and nf_router_cache-misses: 0.13
# Correlation between latency and bridge_cache-misses: 0.12
# Correlation between latency and payload_scan_branch-misses: 0.10
# Correlation between latency and payload_scan_branch-load-misses: 0.10
# Correlation between latency and firewall_cache-misses: 0.09
# Correlation between latency and bridge_cycles: 0.05
# Correlation between latency and payload_scan_LLC-load-misses: 0.05
# Correlation between latency and payload_scan_cache-misses: 0.05
# Correlation between latency and firewall_cycles: 0.04
# Correlation between latency and payload_scan_cycles: 0.02

# %% [markdown]
# # Several ML algorithm to predict rate

# %%
# training 
X = df.drop(['input_rate','output_rate', 'latency'], axis=1)
y = df['input_rate']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# ML model
model = DecisionTreeRegressor(random_state=0)
model = LinearRegression()
model = RandomForestRegressor(n_estimators=100, random_state=42)

# train the regressor
model.fit(X_train, y_train)
y_pred = model.predict(X_test)


# Evaluate
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

#accuracy
threshold = 0.05 
distances = [abs(real - pred) / real for real, pred in zip(y_test.values.tolist(), y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print("Accuracy within 5% threshold:", accuracy_within_threshold)


accuracy_cdf=[]
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test.values.tolist(), y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 10
#       8 model = DecisionTreeRegressor(random_state=0)
#       9 model = LinearRegression()
# ---> 10 model = RandomForestRegressor(n_estimators=100, random_state=42)
#      12 # train the regressor
#      13 model.fit(X_train, y_train)
#
# NameError: name 'RandomForestRegressor' is not defined

# %%
# predict dataset 'dag'/ 'resource_stimulus'

# Read the CSV file
path = '../Dag/dag-1/datasets/load_stimulus_exp4.csv'
path = '../linear/datasets/resource_stimulus_exp10.csv'

df = pd.read_csv(path)
df = df.replace(['<not counted>'], np.nan)
df = df.dropna()

# Separate the features and target variable
X_test = df.drop(['Unnamed: 0','input_rate', 'output_rate', 'latency'], axis=1)
y_test =df['input_rate'].values


# Standardize the features
scaler = StandardScaler()
X_test = scaler.fit_transform(X_test)

# Evaluate
y_pred = model.predict(X_test)
y_pred = np.array(y_pred)
mse = mean_squared_error(y_test, y_pred)

# accuracy
threshold = 0.05
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print(f'accurancy with thoreshold 5%:{accuracy_within_threshold}')

accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)
# Out:
# accurancy with thoreshold 5%:11.1731843575419
# [0.5586592178770949, 11.1731843575419, 11.1731843575419, 11.1731843575419, 11.1731843575419, 11.1731843575419, 22.3463687150838, 33.5195530726257, 44.6927374301676, 89.3854748603352, 98.88268156424581]
# C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
fig, ax = plt.subplots(figsize=(4,3))
plt.plot(y_pred, marker='o',c='r',markersize = 1, linestyle='-', dashes=(5, 3),label='predicted data')
plt.plot(y_test.tolist(), c='b',linestyle='-',linewidth = 1,label='real data')

plt.xlabel('Series',fontsize=8)
plt.ylabel('Values',fontsize=8)

plt.legend(loc="upper right", fontsize=6)
plt.grid()

# %% [markdown]
# # DNN to predict rate (training set: combined_global)

# %%
current_dir = os.getcwd()
file_path = os.path.abspath('../linear/datasets/combined_global.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
df = data.dropna()

# %%
# training 
X = df.drop(['input_rate','output_rate', 'latency'], axis=1)
y = df['input_rate']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

column_order = X_train.columns
X_test = X_test[column_order]


# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print(len(y))
# Out:
# 38136

# %%
# model
model = Sequential()

# Add input layer and hidden layers
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(32, activation='relu'))

# Add output layer
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=16, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 6671914.0000
# Epoch 2/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 2122934.5000
# Epoch 3/100
# 1669/1669 [==============================] - 5s 3ms/step - loss: 1808243.3750
# Epoch 4/100
# 1669/1669 [==============================] - 5s 3ms/step - loss: 1696932.6250
# Epoch 5/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1648259.5000
# Epoch 6/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1611341.2500
# Epoch 7/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1582351.0000
# Epoch 8/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1557541.7500
# Epoch 9/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1537576.8750
# Epoch 10/100
# 1669/1669 [==============================] - 7s 4ms/step - loss: 1520366.2500
# Epoch 11/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1504799.6250
# Epoch 12/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1490938.3750
# Epoch 13/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1479835.8750
# Epoch 14/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1469201.0000
# Epoch 15/100
# 1669/1669 [==============================] - 6s 4ms/step - loss: 1461356.7500
# Epoch 16/100
# 1669/1669 [==============================] - 4s 3ms/step - loss: 1453882.8750
# Epoch 17/100
# 1669/1669 [==============================] - 5s 3ms/step - loss: 1448399.2500
# Epoch 18/100
# 1669/1669 [==============================] - 5s 3ms/step - loss: 1440117.3750
# Epoch 19/100
# 1669/1669 [==============================] - 5s 3ms/step - loss: 1433943.8750
# Epoch 20/100
# 1669/1669 [==============================] - 5s 3ms/step - loss: 1426815.7500
# Epoch 21/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1419266.2500
# Epoch 22/100
# 1669/1669 [==============================] - 6s 3ms/step - loss: 1411341.5000
# Epoch 23/100
# 1669/1669 [==============================] - 5s 3ms/step - loss: 1405765.0000
# Epoch 24/100
# 1669/1669 [==============================] - 5s 3ms/step - loss: 1397687.8750
# Epoch 25/100
# 1669/1669 [==============================] - 7s 4ms/step - loss: 1394040.7500
# Epoch 26/100
# 1669/1669 [==============================] - 5s 3ms/step - loss: 1389240.6250
# Epoch 27/100
# 1669/1669 [==============================] - 5s 3ms/step - loss: 1385360.5000
# Epoch 28/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1384047.6250
# Epoch 29/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1379660.6250
# Epoch 30/100
# 1669/1669 [==============================] - 4s 3ms/step - loss: 1377426.8750
# Epoch 31/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1373907.6250
# Epoch 32/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1371584.2500
# Epoch 33/100
# 1669/1669 [==============================] - 4s 3ms/step - loss: 1368761.5000
# Epoch 34/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1365873.2500
# Epoch 35/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1363556.7500
# Epoch 36/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1362788.3750
# Epoch 37/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1360401.8750
# Epoch 38/100
# 1669/1669 [==============================] - 6s 3ms/step - loss: 1359573.8750
# Epoch 39/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1357088.5000
# Epoch 40/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1357210.0000
# Epoch 41/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1355378.6250
# Epoch 42/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1353295.8750
# Epoch 43/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1352745.1250
# Epoch 44/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1351687.3750
# Epoch 45/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1349030.5000
# Epoch 46/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1350224.0000
# Epoch 47/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1347173.7500
# Epoch 48/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1346658.6250
# Epoch 49/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1345094.7500
# Epoch 50/100
# 1669/1669 [==============================] - 2s 1ms/step - loss: 1345075.7500
# Epoch 51/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1344519.5000
# Epoch 52/100
# 1669/1669 [==============================] - 2s 1ms/step - loss: 1343556.2500
# Epoch 53/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1340970.3750
# Epoch 54/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1341814.6250
# Epoch 55/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1339871.5000
# Epoch 56/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1339135.6250
# Epoch 57/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1340000.1250
# Epoch 58/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1337829.5000
# Epoch 59/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1335662.8750
# Epoch 60/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1336265.7500
# Epoch 61/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1335977.1250
# Epoch 62/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1336218.1250
# Epoch 63/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1333163.8750
# Epoch 64/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1332672.1250
# Epoch 65/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1332612.5000
# Epoch 66/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1332487.1250
# Epoch 67/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1330709.5000
# Epoch 68/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1330796.7500
# Epoch 69/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1328964.6250
# Epoch 70/100
# 1669/1669 [==============================] - 2s 1ms/step - loss: 1328858.7500
# Epoch 71/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1327549.8750
# Epoch 72/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1327047.1250
# Epoch 73/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1327187.7500
# Epoch 74/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1324532.3750
# Epoch 75/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1324434.0000
# Epoch 76/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1324772.3750
# Epoch 77/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1322950.2500
# Epoch 78/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1322651.7500
# Epoch 79/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1320434.5000
# Epoch 80/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1320977.8750
# Epoch 81/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1318424.6250
# Epoch 82/100
# 1669/1669 [==============================] - 4s 3ms/step - loss: 1316637.0000
# Epoch 83/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1319584.2500
# Epoch 84/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1317571.8750
# Epoch 85/100
# 1669/1669 [==============================] - 2s 1ms/step - loss: 1316799.1250
# Epoch 86/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1317044.8750
# Epoch 87/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1316726.8750
# Epoch 88/100
# 1669/1669 [==============================] - 2s 1ms/step - loss: 1314182.1250
# Epoch 89/100
# 1669/1669 [==============================] - 4s 2ms/step - loss: 1312999.5000
# Epoch 90/100
# 1669/1669 [==============================] - 2s 1ms/step - loss: 1313052.5000
# Epoch 91/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1312708.8750
# Epoch 92/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1311663.0000
# Epoch 93/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1311916.6250
# Epoch 94/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1308969.5000
# Epoch 95/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1308282.6250
# Epoch 96/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1307651.7500
# Epoch 97/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1308165.8750
# Epoch 98/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1308363.2500
# Epoch 99/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1307713.2500
# Epoch 100/100
# 1669/1669 [==============================] - 3s 2ms/step - loss: 1307173.0000

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# accuracy
threshold = 0.05  
y_pred=np.array(y_pred)
y_pred = [item for subset in y_pred for item in subset]
y_test=np.array(y_test)
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot
fig, ax = plt.subplots(figsize=(4,3))
plt.plot(y_pred[0:100], marker='o',c='r',markersize = 2, linewidth = 0.8, linestyle='-', dashes=(5, 3),label='predicted data')
plt.plot(y_test.tolist()[0:100], c='b',linestyle='-',linewidth = 0.8,label='real data')

plt.xlabel('Series',fontsize=10)
plt.ylabel('Values',fontsize=10)

plt.legend(loc="lower right", fontsize=8)
plt.grid()
# Out:
# 358/358 [==============================] - 0s 1ms/step
# [0.0, 61.04361506861289, 73.45511755965389, 79.38991346910235, 83.6552748885587, 86.75815051131895, 89.03941963115112, 90.51656323747925, 91.35565072983131, 92.04614981207936, 92.72790839961542]

# %%
# predict dataset 'dag'

# read the CSV file
path = '../Dag/dag-1/datasets/load_stimulus_exp4.csv'

df = pd.read_csv(path)
df = df.replace(['<not counted>'], np.nan)
df = df.dropna()

# separate the features and target variable
X_test = df.drop(['Unnamed: 0','input_rate', 'output_rate', 'latency'], axis=1)
y_test =df['input_rate'].values

# standardize the features
scaler = StandardScaler()
X_test = scaler.fit_transform(X_test)

# evaluate
y_pred = model.predict(X_test)
y_pred = np.array(y_pred)
mse = mean_squared_error(y_test, y_pred)

# accuracy
threshold = 0.05
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print(f'accurancy with thoreshold 5%:{accuracy_within_threshold}')

accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot
fig, ax = plt.subplots(figsize=(4,3))
plt.plot(y_pred, marker='o',c='r',markersize = 2,linewidth = 0.8,  linestyle='-', dashes=(5, 3),label='Prediction(DNN)')
plt.plot(y_test.tolist(), c='b',linestyle='-',linewidth = 0.8, label='Real')

plt.xlabel('Series ',fontsize=10)
plt.ylabel('Values (Dag)',fontsize=10)

plt.legend(loc="upper right",fontsize=6)
plt.grid()
# Out:
# 6/6 [==============================] - 0s 1ms/step
# accurancy with thoreshold 5%:[2.24719101]
# [array([0.]), array([6.17977528]), array([10.11235955]), array([18.53932584]), array([43.82022472]), array([60.11235955]), array([64.60674157]), array([66.85393258]), array([67.97752809]), array([68.53932584]), array([68.53932584])]

# %%
# predict dataset 'resource_stimulus'

# read the CSV file
path = '../linear/datasets/resource_stimulus_exp10.csv'

df = pd.read_csv(path)
df = df.replace(['<not counted>'], np.nan)
df = df.dropna()

# separate the features and target variable
X_test = df.drop(['Unnamed: 0','input_rate', 'output_rate', 'latency'], axis=1)
y_test =df['input_rate'].values

# standardize the features
scaler = StandardScaler()
X_test = scaler.fit_transform(X_test)

# evaluate
y_pred = model.predict(X_test)
y_pred = np.array(y_pred)
mse = mean_squared_error(y_test, y_pred)

# accuracy
threshold = 0.05
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print(f'accurancy with thoreshold 5%:{accuracy_within_threshold}')

accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot
fig, ax = plt.subplots(figsize=(4,3))
plt.plot(y_pred, marker='o',c='r',markersize = 2,linewidth = 0.8,  linestyle='-', dashes=(5, 3),label='Prediction(DNN)')
plt.plot(y_test.tolist(), c='b',linestyle='-',linewidth = 0.8, label='Real')

plt.xlabel('Series ',fontsize=10)
plt.ylabel('Values (Dag)',fontsize=10)

plt.legend(loc="upper right",fontsize=6)
plt.grid()
# Out:
# 6/6 [==============================] - 0s 1ms/step
# accurancy with thoreshold 5%:[2.79329609]
# [array([0.]), array([5.58659218]), array([13.96648045]), array([25.1396648]), array([34.07821229]), array([55.30726257]), array([67.03910615]), array([68.15642458]), array([68.7150838]), array([69.27374302]), array([70.39106145])]

# %% [markdown]
# # DNN to predict rate (training set: combined_peride rate)

# %%
current_dir = os.getcwd()
file_path = os.path.abspath('../linear/datasets/combined.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
df = data.dropna()

# %%
# training 
X = df.drop(['input_rate','output_rate', 'latency'], axis=1)
y = df['input_rate']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

column_order = X_train.columns
X_test = X_test[column_order]


# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print(len(y))
# Out:
# 1788

# %%
# model
model = Sequential()

# Add input layer and hidden layers
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(32, activation='relu'))

# Add output layer
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=16, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 79/79 [==============================] - 1s 1ms/step - loss: 27787982.0000
# Epoch 2/100
# 79/79 [==============================] - 0s 1ms/step - loss: 26207842.0000
# Epoch 3/100
# 79/79 [==============================] - 0s 1ms/step - loss: 20532490.0000
# Epoch 4/100
# 79/79 [==============================] - 0s 1ms/step - loss: 11433149.0000
# Epoch 5/100
# 79/79 [==============================] - 0s 2ms/step - loss: 4808665.0000
# Epoch 6/100
# 79/79 [==============================] - 0s 1ms/step - loss: 3110695.2500
# Epoch 7/100
# 79/79 [==============================] - 0s 1ms/step - loss: 2884804.7500
# Epoch 8/100
# 79/79 [==============================] - 0s 1ms/step - loss: 2738101.0000
# Epoch 9/100
# 79/79 [==============================] - 0s 1ms/step - loss: 2575015.0000
# Epoch 10/100
# 79/79 [==============================] - 0s 2ms/step - loss: 2399222.5000
# Epoch 11/100
# 79/79 [==============================] - 0s 1ms/step - loss: 2216241.7500
# Epoch 12/100
# 79/79 [==============================] - 0s 1ms/step - loss: 2032443.3750
# Epoch 13/100
# 79/79 [==============================] - 0s 1ms/step - loss: 1840455.2500
# Epoch 14/100
# 79/79 [==============================] - 0s 2ms/step - loss: 1653936.3750
# Epoch 15/100
# 79/79 [==============================] - 0s 2ms/step - loss: 1477497.7500
# Epoch 16/100
# 79/79 [==============================] - 0s 1ms/step - loss: 1312529.1250
# Epoch 17/100
# 79/79 [==============================] - 0s 2ms/step - loss: 1163732.6250
# Epoch 18/100
# 79/79 [==============================] - 0s 2ms/step - loss: 1020387.4375
# Epoch 19/100
# 79/79 [==============================] - 0s 1ms/step - loss: 901091.7500
# Epoch 20/100
# 79/79 [==============================] - 0s 2ms/step - loss: 794212.6250
# Epoch 21/100
# 79/79 [==============================] - 0s 1ms/step - loss: 707231.8750
# Epoch 22/100
# 79/79 [==============================] - 0s 2ms/step - loss: 634479.8125
# Epoch 23/100
# 79/79 [==============================] - 0s 2ms/step - loss: 577229.6875
# Epoch 24/100
# 79/79 [==============================] - 0s 2ms/step - loss: 533636.3750
# Epoch 25/100
# 79/79 [==============================] - 0s 2ms/step - loss: 497251.0312
# Epoch 26/100
# 79/79 [==============================] - 0s 2ms/step - loss: 468858.0000
# Epoch 27/100
# 79/79 [==============================] - 0s 1ms/step - loss: 448343.1250
# Epoch 28/100
# 79/79 [==============================] - 0s 1ms/step - loss: 433295.7500
# Epoch 29/100
# 79/79 [==============================] - 0s 1ms/step - loss: 418213.0625
# Epoch 30/100
# 79/79 [==============================] - 0s 1ms/step - loss: 409427.0938
# Epoch 31/100
# 79/79 [==============================] - 0s 2ms/step - loss: 397226.0000
# Epoch 32/100
# 79/79 [==============================] - 0s 1ms/step - loss: 390876.0938
# Epoch 33/100
# 79/79 [==============================] - 0s 1ms/step - loss: 383074.0312
# Epoch 34/100
# 79/79 [==============================] - 0s 1ms/step - loss: 377022.0312
# Epoch 35/100
# 79/79 [==============================] - 0s 1ms/step - loss: 370938.7500
# Epoch 36/100
# 79/79 [==============================] - 0s 2ms/step - loss: 366257.5312
# Epoch 37/100
# 79/79 [==============================] - 0s 3ms/step - loss: 359243.3125
# Epoch 38/100
# 79/79 [==============================] - 0s 3ms/step - loss: 356308.0000
# Epoch 39/100
# 79/79 [==============================] - 0s 3ms/step - loss: 354949.2812
# Epoch 40/100
# 79/79 [==============================] - 0s 3ms/step - loss: 348206.3750
# Epoch 41/100
# 79/79 [==============================] - 0s 4ms/step - loss: 342407.2812
# Epoch 42/100
# 79/79 [==============================] - 0s 3ms/step - loss: 338165.3438
# Epoch 43/100
# 79/79 [==============================] - 0s 3ms/step - loss: 333483.3125
# Epoch 44/100
# 79/79 [==============================] - 0s 3ms/step - loss: 331253.4375
# Epoch 45/100
# 79/79 [==============================] - 0s 2ms/step - loss: 326425.5938
# Epoch 46/100
# 79/79 [==============================] - 0s 1ms/step - loss: 322961.3750
# Epoch 47/100
# 79/79 [==============================] - 0s 1ms/step - loss: 316799.5312
# Epoch 48/100
# 79/79 [==============================] - 0s 1ms/step - loss: 315178.1250
# Epoch 49/100
# 79/79 [==============================] - 0s 1ms/step - loss: 312420.0312
# Epoch 50/100
# 79/79 [==============================] - 0s 1ms/step - loss: 308273.8750
# Epoch 51/100
# 79/79 [==============================] - 0s 1ms/step - loss: 303681.2812
# Epoch 52/100
# 79/79 [==============================] - 0s 1ms/step - loss: 301858.5938
# Epoch 53/100
# 79/79 [==============================] - 0s 1ms/step - loss: 299459.7500
# Epoch 54/100
# 79/79 [==============================] - 0s 2ms/step - loss: 295340.9375
# Epoch 55/100
# 79/79 [==============================] - 0s 1ms/step - loss: 290831.7188
# Epoch 56/100
# 79/79 [==============================] - 0s 2ms/step - loss: 287594.8750
# Epoch 57/100
# 79/79 [==============================] - 0s 1ms/step - loss: 287083.9688
# Epoch 58/100
# 79/79 [==============================] - 0s 2ms/step - loss: 283481.0312
# Epoch 59/100
# 79/79 [==============================] - 0s 2ms/step - loss: 279978.3750
# Epoch 60/100
# 79/79 [==============================] - 0s 1ms/step - loss: 277266.2812
# Epoch 61/100
# 79/79 [==============================] - 0s 1ms/step - loss: 275218.3750
# Epoch 62/100
# 79/79 [==============================] - 0s 1ms/step - loss: 272006.1562
# Epoch 63/100
# 79/79 [==============================] - 0s 1ms/step - loss: 272623.9062
# Epoch 64/100
# 79/79 [==============================] - 0s 2ms/step - loss: 266930.0312
# Epoch 65/100
# 79/79 [==============================] - 0s 2ms/step - loss: 265636.4375
# Epoch 66/100
# 79/79 [==============================] - 0s 2ms/step - loss: 266755.3125
# Epoch 67/100
# 79/79 [==============================] - 0s 2ms/step - loss: 259427.5000
# Epoch 68/100
# 79/79 [==============================] - 0s 1ms/step - loss: 257735.3438
# Epoch 69/100
# 79/79 [==============================] - 0s 1ms/step - loss: 254821.7500
# Epoch 70/100
# 79/79 [==============================] - 0s 1ms/step - loss: 251953.6562
# Epoch 71/100
# 79/79 [==============================] - 0s 1ms/step - loss: 251324.5781
# Epoch 72/100
# 79/79 [==============================] - 0s 1ms/step - loss: 248375.7812
# Epoch 73/100
# 79/79 [==============================] - 0s 1ms/step - loss: 247961.7031
# Epoch 74/100
# 79/79 [==============================] - 0s 1ms/step - loss: 243572.2656
# Epoch 75/100
# 79/79 [==============================] - 0s 1ms/step - loss: 241719.4375
# Epoch 76/100
# 79/79 [==============================] - 0s 2ms/step - loss: 239776.7344
# Epoch 77/100
# 79/79 [==============================] - 0s 2ms/step - loss: 238644.9688
# Epoch 78/100
# 79/79 [==============================] - 0s 3ms/step - loss: 235564.7969
# Epoch 79/100
# 79/79 [==============================] - 0s 2ms/step - loss: 233248.1094
# Epoch 80/100
# 79/79 [==============================] - 0s 3ms/step - loss: 233755.9844
# Epoch 81/100
# 79/79 [==============================] - 0s 2ms/step - loss: 230267.5000
# Epoch 82/100
# 79/79 [==============================] - 0s 2ms/step - loss: 228871.8594
# Epoch 83/100
# 79/79 [==============================] - 0s 2ms/step - loss: 226241.3281
# Epoch 84/100
# 79/79 [==============================] - 0s 2ms/step - loss: 225279.3281
# Epoch 85/100
# 79/79 [==============================] - 0s 2ms/step - loss: 224455.9844
# Epoch 86/100
# 79/79 [==============================] - 0s 2ms/step - loss: 222321.3750
# Epoch 87/100
# 79/79 [==============================] - 0s 2ms/step - loss: 219263.3594
# Epoch 88/100
# 79/79 [==============================] - 0s 2ms/step - loss: 218342.5156
# Epoch 89/100
# 79/79 [==============================] - 0s 2ms/step - loss: 221143.2031
# Epoch 90/100
# 79/79 [==============================] - 0s 2ms/step - loss: 216485.6094
# Epoch 91/100
# 79/79 [==============================] - 0s 2ms/step - loss: 215812.2969
# Epoch 92/100
# 79/79 [==============================] - 0s 2ms/step - loss: 214286.7969
# Epoch 93/100
# 79/79 [==============================] - 0s 2ms/step - loss: 211018.8125
# Epoch 94/100
# 79/79 [==============================] - 0s 2ms/step - loss: 210316.2812
# Epoch 95/100
# 79/79 [==============================] - 0s 765us/step - loss: 208967.8281
# Epoch 96/100
# 79/79 [==============================] - 0s 1ms/step - loss: 208530.0156
# Epoch 97/100
# 79/79 [==============================] - 0s 1ms/step - loss: 205491.4375
# Epoch 98/100
# 79/79 [==============================] - 0s 1ms/step - loss: 204183.3906
# Epoch 99/100
# 79/79 [==============================] - 0s 1ms/step - loss: 201966.0156
# Epoch 100/100
# 79/79 [==============================] - 0s 1ms/step - loss: 202112.4531

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# accuracy
threshold = 0.05  
y_pred=np.array(y_pred)
y_pred = [item for subset in y_pred for item in subset]
y_test=np.array(y_test)
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot
fig, ax = plt.subplots(figsize=(4,3))
plt.plot(y_pred[0:100], marker='o',c='r',markersize = 2, linewidth = 0.8, linestyle='-', dashes=(5, 3),label='predicted data')
plt.plot(y_test.tolist()[0:100], c='b',linestyle='-',linewidth = 0.8,label='real data')

plt.xlabel('Series (Dag)',fontsize=10)
plt.ylabel('Values',fontsize=10)

plt.legend(loc="lower right", fontsize=8)
plt.grid()
# Out:
# 17/17 [==============================] - 0s 2ms/step
# [0.0, 62.01117318435754, 81.19180633147114, 89.01303538175046, 92.73743016759776, 95.53072625698324, 97.02048417132217, 97.57914338919925, 97.57914338919925, 98.13780260707635, 98.69646182495345]

# %%
# predict dataset 'dag'

# read the CSV file
path = '../Dag/dag-1/datasets/load_stimulus_exp4.csv'


df = pd.read_csv(path)
df = df.replace(['<not counted>'], np.nan)
df = df.dropna()

# separate the features and target variable
X_test = df.drop(['Unnamed: 0','input_rate', 'output_rate', 'latency'], axis=1)
y_test =df['input_rate'].values

# standardize the features
scaler = StandardScaler()
X_test = scaler.fit_transform(X_test)

# evaluate
y_pred = model.predict(X_test)
y_pred = np.array(y_pred)
mse = mean_squared_error(y_test, y_pred)

# accuracy
threshold = 0.05
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print(f'accurancy with thoreshold 5%:{accuracy_within_threshold}')

accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot
fig, ax = plt.subplots(figsize=(4,3))
plt.plot(y_pred, marker='o',c='r',markersize = 2,linewidth = 0.8,  linestyle='-', dashes=(5, 3),label='Prediction(DNN)')
plt.plot(y_test.tolist(), c='b',linestyle='-',linewidth = 0.8, label='Real')

plt.xlabel('Series (resource stimulus)',fontsize=10)
plt.ylabel('Values',fontsize=10)

plt.legend(loc="upper right",fontsize=6)
plt.grid()
# Out:
# 6/6 [==============================] - 0s 2ms/step
# accurancy with thoreshold 5%:[24.71910112]
# [array([0.]), array([43.82022472]), array([62.35955056]), array([72.47191011]), array([76.96629213]), array([80.33707865]), array([84.83146067]), array([85.39325843]), array([87.07865169]), array([87.64044944]), array([89.88764045])]

# %%
# predict dataset 'resource_stimulus'

# read the CSV file
path = '../Dag/dag-1/datasets/load_stimulus_exp4.csv'
path = '../linear/datasets/resource_stimulus_exp10.csv'

df = pd.read_csv(path)
df = df.replace(['<not counted>'], np.nan)
df = df.dropna()

# separate the features and target variable
X_test = df.drop(['Unnamed: 0','input_rate', 'output_rate', 'latency'], axis=1)
y_test =df['input_rate'].values

# standardize the features
scaler = StandardScaler()
X_test = scaler.fit_transform(X_test)

# evaluate
y_pred = model.predict(X_test)
y_pred = np.array(y_pred)
mse = mean_squared_error(y_test, y_pred)

# accuracy
threshold = 0.05
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print(f'accurancy with thoreshold 5%:{accuracy_within_threshold}')

accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot
fig, ax = plt.subplots(figsize=(4,3))
plt.plot(y_pred, marker='o',c='r',markersize = 2,linewidth = 0.8,  linestyle='-', dashes=(5, 3),label='Prediction(DNN)')
plt.plot(y_test.tolist(), c='b',linestyle='-',linewidth = 0.8, label='Real')

plt.xlabel('Series  (resource stimulus)',fontsize=10)
plt.ylabel('Values',fontsize=10)

plt.legend(loc="upper right",fontsize=6)
plt.grid()
# Out:
# 6/6 [==============================] - 0s 2ms/step
# accurancy with thoreshold 5%:[18.43575419]
# [array([0.]), array([40.78212291]), array([65.92178771]), array([76.53631285]), array([81.00558659]), array([84.3575419]), array([88.26815642]), array([92.17877095]), array([93.8547486]), array([95.53072626]), array([95.53072626])]
