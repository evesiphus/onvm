# %%
import sys, re, os
import numpy as np
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Change the work directory to the parent
try:
    if chdir:
        pass
except:
    current_dir = os.getcwd()
    os.chdir(current_dir +"/..")
    os.path.abspath(os.curdir)

# %%
chdir = True
import itertools
marker = itertools.cycle(('x',',', '+', '.', 'o', '*'))
cycol = itertools.cycle('bgrcmk')

# %%
from IPython.display import IFrame
IFrame("../assets/testbed.pdf", width=600, height=420)
# Out:
#         <iframe
#             width="600"
#             height="420"
#             src="../assets/testbed.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Metadata for specific SFC configurations

exp_ls='combined_intervention'
vnfs = ["firewall.csv", "nf_router.csv", "ndpi_stats.csv", "payload_scan.csv", "bridge.csv"]

# %%
current_dir = os.getcwd()
file_path = os.path.abspath('..\linear\datasets\combined_intervention.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
data = data.drop('latency', axis=1)
data.info()
df = data.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90791 entries, 0 to 1001
# Data columns (total 62 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   firewall_instructions               90706 non-null  float64
#  1   nf_router_instructions              90700 non-null  float64
#  2   ndpi_stats_instructions             90697 non-null  float64
#  3   payload_scan_instructions           90693 non-null  float64
#  4   bridge_instructions                 90684 non-null  float64
#  5   firewall_branches                   90747 non-null  float64
#  6   nf_router_branches                  90746 non-null  float64
#  7   ndpi_stats_branches                 90750 non-null  float64
#  8   payload_scan_branches               90756 non-null  float64
#  9   bridge_branches                     90751 non-null  float64
#  10  firewall_branch-misses              90778 non-null  float64
#  11  nf_router_branch-misses             90768 non-null  float64
#  12  ndpi_stats_branch-misses            90779 non-null  float64
#  13  payload_scan_branch-misses          90773 non-null  float64
#  14  bridge_branch-misses                90772 non-null  float64
#  15  firewall_branch-load-misses         90782 non-null  float64
#  16  nf_router_branch-load-misses        90774 non-null  float64
#  17  ndpi_stats_branch-load-misses       90776 non-null  float64
#  18  payload_scan_branch-load-misses     90777 non-null  float64
#  19  bridge_branch-load-misses           90774 non-null  float64
#  20  firewall_cache-misses               90781 non-null  float64
#  21  nf_router_cache-misses              90773 non-null  float64
#  22  ndpi_stats_cache-misses             90775 non-null  float64
#  23  payload_scan_cache-misses           90770 non-null  float64
#  24  bridge_cache-misses                 90775 non-null  float64
#  25  firewall_cache-references           90683 non-null  float64
#  26  nf_router_cache-references          90718 non-null  float64
#  27  ndpi_stats_cache-references         90735 non-null  float64
#  28  payload_scan_cache-references       90716 non-null  float64
#  29  bridge_cache-references             90711 non-null  float64
#  30  firewall_cycles                     90667 non-null  float64
#  31  nf_router_cycles                    90718 non-null  float64
#  32  ndpi_stats_cycles                   90723 non-null  float64
#  33  payload_scan_cycles                 90728 non-null  float64
#  34  bridge_cycles                       90726 non-null  float64
#  35  firewall_L1-dcache-load-misses      90688 non-null  float64
#  36  nf_router_L1-dcache-load-misses     90743 non-null  float64
#  37  ndpi_stats_L1-dcache-load-misses    90746 non-null  float64
#  38  payload_scan_L1-dcache-load-misses  90743 non-null  float64
#  39  bridge_L1-dcache-load-misses        90748 non-null  float64
#  40  firewall_L1-dcache-loads            90691 non-null  float64
#  41  nf_router_L1-dcache-loads           90738 non-null  float64
#  42  ndpi_stats_L1-dcache-loads          90747 non-null  float64
#  43  payload_scan_L1-dcache-loads        90746 non-null  float64
#  44  bridge_L1-dcache-loads              90737 non-null  float64
#  45  firewall_LLC-load-misses            90501 non-null  float64
#  46  nf_router_LLC-load-misses           90570 non-null  float64
#  47  ndpi_stats_LLC-load-misses          90573 non-null  float64
#  48  payload_scan_LLC-load-misses        90518 non-null  float64
#  49  bridge_LLC-load-misses              90520 non-null  float64
#  50  firewall_LLC-stores                 90514 non-null  float64
#  51  nf_router_LLC-stores                90576 non-null  float64
#  52  ndpi_stats_LLC-stores               90566 non-null  float64
#  53  payload_scan_LLC-stores             90530 non-null  float64
#  54  bridge_LLC-stores                   90529 non-null  float64
#  55  firewall_LLC-loads                  90522 non-null  float64
#  56  nf_router_LLC-loads                 90575 non-null  float64
#  57  ndpi_stats_LLC-loads                90553 non-null  float64
#  58  payload_scan_LLC-loads              90534 non-null  float64
#  59  bridge_LLC-loads                    90519 non-null  float64
#  60  input_rate                          90791 non-null  float64
#  61  output_rate                         90791 non-null  float64
# dtypes: float64(62)
# memory usage: 43.6 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87493 entries, 1 to 998
# Data columns (total 62 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   firewall_instructions               87493 non-null  float64
#  1   nf_router_instructions              87493 non-null  float64
#  2   ndpi_stats_instructions             87493 non-null  float64
#  3   payload_scan_instructions           87493 non-null  float64
#  4   bridge_instructions                 87493 non-null  float64
#  5   firewall_branches                   87493 non-null  float64
#  6   nf_router_branches                  87493 non-null  float64
#  7   ndpi_stats_branches                 87493 non-null  float64
#  8   payload_scan_branches               87493 non-null  float64
#  9   bridge_branches                     87493 non-null  float64
#  10  firewall_branch-misses              87493 non-null  float64
#  11  nf_router_branch-misses             87493 non-null  float64
#  12  ndpi_stats_branch-misses            87493 non-null  float64
#  13  payload_scan_branch-misses          87493 non-null  float64
#  14  bridge_branch-misses                87493 non-null  float64
#  15  firewall_branch-load-misses         87493 non-null  float64
#  16  nf_router_branch-load-misses        87493 non-null  float64
#  17  ndpi_stats_branch-load-misses       87493 non-null  float64
#  18  payload_scan_branch-load-misses     87493 non-null  float64
#  19  bridge_branch-load-misses           87493 non-null  float64
#  20  firewall_cache-misses               87493 non-null  float64
#  21  nf_router_cache-misses              87493 non-null  float64
#  22  ndpi_stats_cache-misses             87493 non-null  float64
#  23  payload_scan_cache-misses           87493 non-null  float64
#  24  bridge_cache-misses                 87493 non-null  float64
#  25  firewall_cache-references           87493 non-null  float64
#  26  nf_router_cache-references          87493 non-null  float64
#  27  ndpi_stats_cache-references         87493 non-null  float64
#  28  payload_scan_cache-references       87493 non-null  float64
#  29  bridge_cache-references             87493 non-null  float64
#  30  firewall_cycles                     87493 non-null  float64
#  31  nf_router_cycles                    87493 non-null  float64
#  32  ndpi_stats_cycles                   87493 non-null  float64
#  33  payload_scan_cycles                 87493 non-null  float64
#  34  bridge_cycles                       87493 non-null  float64
#  35  firewall_L1-dcache-load-misses      87493 non-null  float64
#  36  nf_router_L1-dcache-load-misses     87493 non-null  float64
#  37  ndpi_stats_L1-dcache-load-misses    87493 non-null  float64
#  38  payload_scan_L1-dcache-load-misses  87493 non-null  float64
#  39  bridge_L1-dcache-load-misses        87493 non-null  float64
#  40  firewall_L1-dcache-loads            87493 non-null  float64
#  41  nf_router_L1-dcache-loads           87493 non-null  float64
#  42  ndpi_stats_L1-dcache-loads          87493 non-null  float64
#  43  payload_scan_L1-dcache-loads        87493 non-null  float64
#  44  bridge_L1-dcache-loads              87493 non-null  float64
#  45  firewall_LLC-load-misses            87493 non-null  float64
#  46  nf_router_LLC-load-misses           87493 non-null  float64
#  47  ndpi_stats_LLC-load-misses          87493 non-null  float64
#  48  payload_scan_LLC-load-misses        87493 non-null  float64
#  49  bridge_LLC-load-misses              87493 non-null  float64
#  50  firewall_LLC-stores                 87493 non-null  float64
#  51  nf_router_LLC-stores                87493 non-null  float64
#  52  ndpi_stats_LLC-stores               87493 non-null  float64
#  53  payload_scan_LLC-stores             87493 non-null  float64
#  54  bridge_LLC-stores                   87493 non-null  float64
#  55  firewall_LLC-loads                  87493 non-null  float64
#  56  nf_router_LLC-loads                 87493 non-null  float64
#  57  ndpi_stats_LLC-loads                87493 non-null  float64
#  58  payload_scan_LLC-loads              87493 non-null  float64
#  59  bridge_LLC-loads                    87493 non-null  float64
#  60  input_rate                          87493 non-null  float64
#  61  output_rate                         87493 non-null  float64
# dtypes: float64(62)
# memory usage: 42.1 MB

# %%
# heatmap
import seaborn as sns   
corr = data.corr()
plt.figure()
sns.heatmap(corr, cmap="coolwarm", annot=False, fmt=".2f")
plt.show()

# %%
# input rate distribution
a = list(df['input_rate']/1000)
plt.plot(a[0:2000], c='b', label='rate')
plt.legend()
plt.grid()
plt.show()
print(sum(a)/len(a))
print(min(a))
print(max(a))
# Out:
# 5.009901014306538
# 0.017927750889602
# 9.9989283085817
