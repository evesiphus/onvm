# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_names = []
for i in range(1, 11):
    item = 'load_stimulus_exp{}.csv'.format(i)
    file_names.append(item)

folder_path = os.path.abspath(os.path.join("../datasets"))
load_stimulus_global = pd.DataFrame()

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_csv(file_path)
    load_stimulus_global = pd.concat([load_stimulus_global, df], ignore_index=True)

# Save the combined DataFrame as a new CSV file
abs_path = os.path.join("..\\datasets", 'load_stimulus_global.csv')
load_stimulus_global.to_csv(abs_path, index=False)

# %%
current_dir = os.getcwd()

exp_ls = "load_stimulus_global.csv"
#exp_ls="load_stimulus_exp1.csv"
file_path = os.path.abspath(os.path.join("..\\datasets", exp_ls))

data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1780 entries, 0 to 177
# Data columns (total 63 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   input_rate                          1780 non-null   float64
#  1   output_rate                         1780 non-null   float64
#  2   latency                             1780 non-null   float64
#  3   firewall_instructions               1780 non-null   float64
#  4   nf_router_instructions              1780 non-null   float64
#  5   ndpi_stats_instructions             1780 non-null   float64
#  6   payload_scan_instructions           1780 non-null   float64
#  7   bridge_instructions                 1780 non-null   float64
#  8   firewall_branches                   1780 non-null   float64
#  9   nf_router_branches                  1780 non-null   float64
#  10  ndpi_stats_branches                 1780 non-null   float64
#  11  payload_scan_branches               1780 non-null   float64
#  12  bridge_branches                     1780 non-null   float64
#  13  firewall_branch-misses              1780 non-null   float64
#  14  nf_router_branch-misses             1780 non-null   float64
#  15  ndpi_stats_branch-misses            1780 non-null   float64
#  16  payload_scan_branch-misses          1780 non-null   float64
#  17  bridge_branch-misses                1780 non-null   float64
#  18  firewall_branch-load-misses         1780 non-null   float64
#  19  nf_router_branch-load-misses        1780 non-null   float64
#  20  ndpi_stats_branch-load-misses       1780 non-null   float64
#  21  payload_scan_branch-load-misses     1780 non-null   float64
#  22  bridge_branch-load-misses           1780 non-null   float64
#  23  firewall_cache-misses               1780 non-null   float64
#  24  nf_router_cache-misses              1780 non-null   float64
#  25  ndpi_stats_cache-misses             1780 non-null   float64
#  26  payload_scan_cache-misses           1780 non-null   float64
#  27  bridge_cache-misses                 1780 non-null   float64
#  28  firewall_cache-references           1780 non-null   float64
#  29  nf_router_cache-references          1780 non-null   float64
#  30  ndpi_stats_cache-references         1780 non-null   float64
#  31  payload_scan_cache-references       1780 non-null   float64
#  32  bridge_cache-references             1780 non-null   float64
#  33  firewall_cycles                     1780 non-null   float64
#  34  nf_router_cycles                    1780 non-null   float64
#  35  ndpi_stats_cycles                   1780 non-null   float64
#  36  payload_scan_cycles                 1780 non-null   float64
#  37  bridge_cycles                       1780 non-null   float64
#  38  firewall_L1-dcache-load-misses      1780 non-null   float64
#  39  nf_router_L1-dcache-load-misses     1780 non-null   float64
#  40  ndpi_stats_L1-dcache-load-misses    1780 non-null   float64
#  41  payload_scan_L1-dcache-load-misses  1780 non-null   float64
#  42  bridge_L1-dcache-load-misses        1780 non-null   float64
#  43  firewall_L1-dcache-loads            1780 non-null   float64
#  44  nf_router_L1-dcache-loads           1780 non-null   float64
#  45  ndpi_stats_L1-dcache-loads          1780 non-null   float64
#  46  payload_scan_L1-dcache-loads        1780 non-null   float64
#  47  bridge_L1-dcache-loads              1780 non-null   float64
#  48  firewall_LLC-load-misses            1780 non-null   float64
#  49  nf_router_LLC-load-misses           1780 non-null   float64
#  50  ndpi_stats_LLC-load-misses          1780 non-null   float64
#  51  payload_scan_LLC-load-misses        1780 non-null   float64
#  52  bridge_LLC-load-misses              1780 non-null   float64
#  53  firewall_LLC-stores                 1780 non-null   float64
#  54  nf_router_LLC-stores                1780 non-null   float64
#  55  ndpi_stats_LLC-stores               1780 non-null   float64
#  56  payload_scan_LLC-stores             1780 non-null   float64
#  57  bridge_LLC-stores                   1780 non-null   float64
#  58  firewall_LLC-loads                  1780 non-null   float64
#  59  nf_router_LLC-loads                 1780 non-null   float64
#  60  ndpi_stats_LLC-loads                1780 non-null   float64
#  61  payload_scan_LLC-loads              1780 non-null   float64
#  62  bridge_LLC-loads                    1780 non-null   float64
# dtypes: float64(63)
# memory usage: 890.0 KB

# %%
# heatmap
import seaborn as sns   
corr = data.corr()
plt.figure()
sns.heatmap(corr, cmap="coolwarm", annot=False, fmt=".2f")
plt.show()

# %%
# Reset the index starting from 0
data = data.reset_index(drop=True)
data
# Out:
#       input_rate  output_rate  latency  firewall_instructions  \
# 0     187.224333   185.229798    8.963           1.121128e+10
# 1     516.725065   528.201666    6.377           1.123944e+10
# 2     528.457327   528.471292    8.489           1.123918e+10
# 3     528.405466   528.386996    6.083           1.115283e+10
# 4     528.280111   528.273735    6.669           1.114634e+10
# ...          ...          ...      ...                    ...
# 1775  528.304727   528.279457    7.984           1.039272e+10
# 1776  528.163537   528.143816   10.436           1.106339e+10
# 1777  528.181344   528.193240    7.571           1.106637e+10
# 1778  528.257088   528.244387    7.856           1.106855e+10
# 1779  528.156461   528.196065    6.829           1.105939e+10
#
#       nf_router_instructions  ndpi_stats_instructions  \
# 0               1.088710e+10             1.097567e+10
# 1               1.103156e+10             1.106136e+10
# 2               1.093461e+10             1.105879e+10
# 3               1.110961e+10             1.040465e+10
# 4               1.111768e+10             1.104884e+10
# ...                      ...                      ...
# 1775            4.937809e+09             1.100087e+10
# 1776            4.945872e+09             1.101974e+10
# 1777            4.946184e+09             1.101764e+10
# 1778            4.876261e+09             1.102374e+10
# 1779            4.869291e+09             1.101165e+10
#
#       payload_scan_instructions  bridge_instructions  firewall_branches  \
# 0                  1.071371e+10         1.089431e+10       2.199691e+09
# 1                  1.090837e+10         1.099876e+10       2.214683e+09
# 2                  1.084090e+10         1.101288e+10       2.214670e+09
# 3                  1.102334e+10         1.101689e+10       2.202532e+09
# 4                  1.102454e+10         1.100556e+10       2.201304e+09
# ...                         ...                  ...                ...
# 1775               1.078004e+10         1.081339e+10       2.008173e+09
# 1776               1.084847e+10         1.085886e+10       2.156310e+09
# 1777               1.102158e+10         1.103224e+10       2.180885e+09
# 1778               1.101932e+10         1.102733e+10       2.181184e+09
# 1779               1.101963e+10         1.102879e+10       2.179842e+09
#
#       nf_router_branches  ...  firewall_LLC-stores  nf_router_LLC-stores  \
# 0           2.158305e+09  ...             834535.0              895849.0
# 1           2.178411e+09  ...             859218.0              914788.0
# 2           2.164707e+09  ...             874257.0              933491.0
# 3           2.161446e+09  ...             859178.0              928322.0
# 4           2.178992e+09  ...             865321.0              915119.0
# ...                  ...  ...                  ...                   ...
# 1775        9.738864e+08  ...             907775.0              954458.0
# 1776        9.751099e+08  ...             931882.0              980508.0
# 1777        9.754146e+08  ...             943730.0              980374.0
# 1778        9.653966e+08  ...             941239.0              986006.0
# 1779        9.637707e+08  ...             935970.0              958647.0
#
#       ndpi_stats_LLC-stores  payload_scan_LLC-stores  bridge_LLC-stores  \
# 0                  826518.0                 882691.0           711973.0
# 1                  849676.0                 901211.0           733000.0
# 2                  860351.0                 920450.0           745286.0
# 3                  860363.0                 910669.0           742446.0
# 4                  844880.0                 901566.0           729822.0
# ...                     ...                      ...                ...
# 1775               803313.0                 894700.0           709400.0
# 1776               819043.0                 934299.0           741995.0
# 1777               830687.0                 947226.0           751013.0
# 1778               831849.0                 951043.0           751156.0
# 1779               823865.0                 945596.0           745967.0
#
#       firewall_LLC-loads  nf_router_LLC-loads  ndpi_stats_LLC-loads  \
# 0              1360317.0            1387358.0             1584910.0
# 1              1391619.0            1499959.0             1598652.0
# 2              1379152.0            1533535.0             1602503.0
# 3              1371159.0            1514267.0             1587722.0
# 4              1378034.0            1529598.0             1590916.0
# ...                  ...                  ...                   ...
# 1775           2018602.0            1313729.0             1737253.0
# 1776           2112353.0            1335817.0             1804011.0
# 1777           2158944.0            1357346.0             1826802.0
# 1778           2157861.0            1367278.0             1825576.0
# 1779           2158505.0            1352077.0             1818851.0
#
#       payload_scan_LLC-loads  bridge_LLC-loads
# 0                  2121682.0         1951730.0
# 1                  2270153.0         1987013.0
# 2                  2302810.0         2035047.0
# 3                  2277497.0         2027721.0
# 4                  2317227.0         2014587.0
# ...                      ...               ...
# 1775               2095720.0         2015800.0
# 1776               2165449.0         2107840.0
# 1777               2180764.0         2146076.0
# 1778               2202860.0         2187825.0
# 1779               2213249.0         2180835.0
#
# [1780 rows x 63 columns]

# %%
data.iloc[:, 1:3].plot(logy=True)
# Out:
# <Axes: >

# %%
corr = data.corr()
correlation_list = []
for i in range(1,2):
    for j in range(i+1, len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between output_rate and ndpi_stats_LLC-loads: 0.98
# Correlation between output_rate and ndpi_stats_L1-dcache-load-misses: 0.98
# Correlation between output_rate and ndpi_stats_cache-references: 0.98
# Correlation between output_rate and payload_scan_LLC-loads: 0.98
# Correlation between output_rate and payload_scan_cache-references: 0.97
# Correlation between output_rate and nf_router_LLC-loads: 0.97
# Correlation between output_rate and payload_scan_L1-dcache-load-misses: 0.97
# Correlation between output_rate and firewall_LLC-stores: 0.97
# Correlation between output_rate and nf_router_cache-references: 0.97
# Correlation between output_rate and nf_router_L1-dcache-load-misses: 0.97
# Correlation between output_rate and firewall_cache-references: 0.97
# Correlation between output_rate and bridge_LLC-stores: 0.97
# Correlation between output_rate and ndpi_stats_LLC-stores: 0.97
# Correlation between output_rate and firewall_L1-dcache-load-misses: 0.97
# Correlation between output_rate and firewall_LLC-loads: 0.96
# Correlation between output_rate and payload_scan_LLC-stores: 0.96
# Correlation between output_rate and nf_router_LLC-stores: 0.96
# Correlation between output_rate and bridge_L1-dcache-load-misses: 0.95
# Correlation between output_rate and bridge_cache-references: 0.95
# Correlation between output_rate and bridge_LLC-loads: 0.94
# Correlation between output_rate and payload_scan_L1-dcache-loads: 0.92
# Correlation between output_rate and payload_scan_instructions: 0.92
# Correlation between output_rate and payload_scan_branches: 0.92
# Correlation between output_rate and firewall_L1-dcache-loads: 0.89
# Correlation between output_rate and firewall_instructions: 0.89
# Correlation between output_rate and firewall_branches: 0.89
# Correlation between output_rate and nf_router_L1-dcache-loads: 0.86
# Correlation between output_rate and nf_router_instructions: 0.86
# Correlation between output_rate and nf_router_branches: 0.86
# Correlation between output_rate and bridge_L1-dcache-loads: 0.79
# Correlation between output_rate and bridge_branches: 0.79
# Correlation between output_rate and bridge_instructions: 0.79
# Correlation between output_rate and ndpi_stats_branches: 0.78
# Correlation between output_rate and ndpi_stats_L1-dcache-loads: 0.78
# Correlation between output_rate and ndpi_stats_instructions: 0.78
# Correlation between output_rate and latency: 0.67
# Correlation between output_rate and firewall_branch-load-misses: 0.65
# Correlation between output_rate and firewall_branch-misses: 0.65
# Correlation between output_rate and ndpi_stats_cache-misses: 0.65
# Correlation between output_rate and bridge_branch-load-misses: 0.52
# Correlation between output_rate and bridge_branch-misses: 0.52
# Correlation between output_rate and payload_scan_branch-misses: 0.50
# Correlation between output_rate and payload_scan_branch-load-misses: 0.50
# Correlation between output_rate and nf_router_branch-misses: 0.40
# Correlation between output_rate and nf_router_branch-load-misses: 0.40
# Correlation between output_rate and ndpi_stats_LLC-load-misses: 0.40
# Correlation between output_rate and nf_router_LLC-load-misses: 0.37
# Correlation between output_rate and firewall_cache-misses: 0.36
# Correlation between output_rate and nf_router_cache-misses: 0.35
# Correlation between output_rate and firewall_LLC-load-misses: 0.33
# Correlation between output_rate and bridge_cache-misses: 0.32
# Correlation between output_rate and bridge_LLC-load-misses: 0.28
# Correlation between output_rate and payload_scan_cache-misses: 0.18
# Correlation between output_rate and payload_scan_LLC-load-misses: 0.16
# Correlation between output_rate and nf_router_cycles: 0.14
# Correlation between output_rate and bridge_cycles: 0.14
# Correlation between output_rate and ndpi_stats_cycles: 0.14
# Correlation between output_rate and ndpi_stats_branch-misses: 0.10
# Correlation between output_rate and ndpi_stats_branch-load-misses: 0.10
# Correlation between output_rate and payload_scan_cycles: 0.08
# Correlation between output_rate and firewall_cycles: 0.06

# %%
corr = data.corr()
correlation_list = []
for i in range(2,3):
    for j in range(len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between latency and latency: 1.00
# Correlation between latency and input_rate: 0.67
# Correlation between latency and output_rate: 0.67
# Correlation between latency and ndpi_stats_LLC-loads: 0.59
# Correlation between latency and ndpi_stats_cache-references: 0.58
# Correlation between latency and ndpi_stats_L1-dcache-load-misses: 0.57
# Correlation between latency and payload_scan_LLC-loads: 0.57
# Correlation between latency and firewall_LLC-loads: 0.56
# Correlation between latency and firewall_cache-references: 0.56
# Correlation between latency and firewall_L1-dcache-load-misses: 0.56
# Correlation between latency and payload_scan_cache-references: 0.56
# Correlation between latency and nf_router_LLC-loads: 0.56
# Correlation between latency and payload_scan_L1-dcache-load-misses: 0.56
# Correlation between latency and firewall_LLC-stores: 0.56
# Correlation between latency and nf_router_L1-dcache-loads: 0.56
# Correlation between latency and nf_router_instructions: 0.55
# Correlation between latency and nf_router_branches: 0.55
# Correlation between latency and nf_router_cache-references: 0.55
# Correlation between latency and nf_router_L1-dcache-load-misses: 0.55
# Correlation between latency and ndpi_stats_LLC-stores: 0.54
# Correlation between latency and bridge_LLC-stores: 0.54
# Correlation between latency and nf_router_LLC-stores: 0.53
# Correlation between latency and payload_scan_LLC-stores: 0.53
# Correlation between latency and bridge_L1-dcache-load-misses: 0.50
# Correlation between latency and bridge_cache-references: 0.50
# Correlation between latency and payload_scan_L1-dcache-loads: 0.48
# Correlation between latency and firewall_L1-dcache-loads: 0.48
# Correlation between latency and payload_scan_instructions: 0.48
# Correlation between latency and bridge_LLC-loads: 0.48
# Correlation between latency and firewall_instructions: 0.48
# Correlation between latency and firewall_branches: 0.48
# Correlation between latency and payload_scan_branches: 0.48
# Correlation between latency and ndpi_stats_branches: 0.47
# Correlation between latency and ndpi_stats_L1-dcache-loads: 0.47
# Correlation between latency and ndpi_stats_instructions: 0.47
# Correlation between latency and bridge_branches: 0.41
# Correlation between latency and bridge_L1-dcache-loads: 0.41
# Correlation between latency and bridge_instructions: 0.41
# Correlation between latency and ndpi_stats_cache-misses: 0.33
# Correlation between latency and nf_router_branch-misses: 0.33
# Correlation between latency and nf_router_branch-load-misses: 0.33
# Correlation between latency and firewall_branch-load-misses: 0.30
# Correlation between latency and firewall_branch-misses: 0.29
# Correlation between latency and bridge_branch-load-misses: 0.27
# Correlation between latency and bridge_branch-misses: 0.27
# Correlation between latency and nf_router_cycles: 0.25
# Correlation between latency and ndpi_stats_LLC-load-misses: 0.24
# Correlation between latency and bridge_LLC-load-misses: 0.16
# Correlation between latency and nf_router_LLC-load-misses: 0.14
# Correlation between latency and ndpi_stats_cycles: 0.14
# Correlation between latency and ndpi_stats_branch-misses: 0.14
# Correlation between latency and ndpi_stats_branch-load-misses: 0.14
# Correlation between latency and firewall_LLC-load-misses: 0.13
# Correlation between latency and nf_router_cache-misses: 0.13
# Correlation between latency and bridge_cache-misses: 0.12
# Correlation between latency and payload_scan_branch-misses: 0.10
# Correlation between latency and payload_scan_branch-load-misses: 0.10
# Correlation between latency and firewall_cache-misses: 0.09
# Correlation between latency and bridge_cycles: 0.05
# Correlation between latency and payload_scan_LLC-load-misses: 0.05
# Correlation between latency and payload_scan_cache-misses: 0.05
# Correlation between latency and firewall_cycles: 0.04
# Correlation between latency and payload_scan_cycles: 0.02

# %% [markdown]
# # Resource stimulus

# %%
resouce_stimulus_global = pd.DataFrame()
file_names = []
file_names_1 = []
for i in range(3, 8):
    for j in [1,3]:
        for k in range(1,6):
            item = 'resource_stimulus_exp-{}-{}-{}.csv'.format(i,j,k)
            file_names.append(item)

print(file_names) 
        
folder_path = os.path.abspath(os.path.join("../datasets"))
resource_stimulus_global = pd.DataFrame()

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_csv(file_path)
    resource_stimulus_global = pd.concat([resource_stimulus_global, df], ignore_index=True)

# Save the combined DataFrame as a new CSV file
abs_path = os.path.join("..\\datasets", 'resource_stimulus_global.csv')
resource_stimulus_global.to_csv(abs_path, index=False)
# Out:
# ['resource_stimulus_exp-3-1-1.csv', 'resource_stimulus_exp-3-1-2.csv', 'resource_stimulus_exp-3-1-3.csv', 'resource_stimulus_exp-3-1-4.csv', 'resource_stimulus_exp-3-1-5.csv', 'resource_stimulus_exp-3-3-1.csv', 'resource_stimulus_exp-3-3-2.csv', 'resource_stimulus_exp-3-3-3.csv', 'resource_stimulus_exp-3-3-4.csv', 'resource_stimulus_exp-3-3-5.csv', 'resource_stimulus_exp-4-1-1.csv', 'resource_stimulus_exp-4-1-2.csv', 'resource_stimulus_exp-4-1-3.csv', 'resource_stimulus_exp-4-1-4.csv', 'resource_stimulus_exp-4-1-5.csv', 'resource_stimulus_exp-4-3-1.csv', 'resource_stimulus_exp-4-3-2.csv', 'resource_stimulus_exp-4-3-3.csv', 'resource_stimulus_exp-4-3-4.csv', 'resource_stimulus_exp-4-3-5.csv', 'resource_stimulus_exp-5-1-1.csv', 'resource_stimulus_exp-5-1-2.csv', 'resource_stimulus_exp-5-1-3.csv', 'resource_stimulus_exp-5-1-4.csv', 'resource_stimulus_exp-5-1-5.csv', 'resource_stimulus_exp-5-3-1.csv', 'resource_stimulus_exp-5-3-2.csv', 'resource_stimulus_exp-5-3-3.csv', 'resource_stimulus_exp-5-3-4.csv', 'resource_stimulus_exp-5-3-5.csv', 'resource_stimulus_exp-6-1-1.csv', 'resource_stimulus_exp-6-1-2.csv', 'resource_stimulus_exp-6-1-3.csv', 'resource_stimulus_exp-6-1-4.csv', 'resource_stimulus_exp-6-1-5.csv', 'resource_stimulus_exp-6-3-1.csv', 'resource_stimulus_exp-6-3-2.csv', 'resource_stimulus_exp-6-3-3.csv', 'resource_stimulus_exp-6-3-4.csv', 'resource_stimulus_exp-6-3-5.csv', 'resource_stimulus_exp-7-1-1.csv', 'resource_stimulus_exp-7-1-2.csv', 'resource_stimulus_exp-7-1-3.csv', 'resource_stimulus_exp-7-1-4.csv', 'resource_stimulus_exp-7-1-5.csv', 'resource_stimulus_exp-7-3-1.csv', 'resource_stimulus_exp-7-3-2.csv', 'resource_stimulus_exp-7-3-3.csv', 'resource_stimulus_exp-7-3-4.csv', 'resource_stimulus_exp-7-3-5.csv']

# %%
current_dir = os.getcwd()

exp_rs = "resource_stimulus_global.csv"

file_path = os.path.abspath(os.path.join("..\\datasets", exp_rs))

data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2284 entries, 0 to 45
# Data columns (total 78 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   input_rate                          2284 non-null   float64
#  1   output_rate                         2284 non-null   float64
#  2   firewall_instructions               2284 non-null   float64
#  3   nf_router_instructions              2284 non-null   float64
#  4   ndpi_stats_instructions             2284 non-null   float64
#  5   payload_scan_instructions           2284 non-null   float64
#  6   bridge_instructions                 2284 non-null   float64
#  7   firewall_branches                   2284 non-null   float64
#  8   nf_router_branches                  2284 non-null   float64
#  9   ndpi_stats_branches                 2284 non-null   float64
#  10  payload_scan_branches               2284 non-null   float64
#  11  bridge_branches                     2284 non-null   float64
#  12  firewall_branch-misses              2284 non-null   float64
#  13  nf_router_branch-misses             2284 non-null   float64
#  14  ndpi_stats_branch-misses            2284 non-null   float64
#  15  payload_scan_branch-misses          2284 non-null   float64
#  16  bridge_branch-misses                2284 non-null   float64
#  17  firewall_branch-load-misses         2284 non-null   float64
#  18  nf_router_branch-load-misses        2284 non-null   float64
#  19  ndpi_stats_branch-load-misses       2284 non-null   float64
#  20  payload_scan_branch-load-misses     2284 non-null   float64
#  21  bridge_branch-load-misses           2284 non-null   float64
#  22  firewall_cache-misses               2284 non-null   float64
#  23  nf_router_cache-misses              2284 non-null   float64
#  24  ndpi_stats_cache-misses             2284 non-null   float64
#  25  payload_scan_cache-misses           2284 non-null   float64
#  26  bridge_cache-misses                 2284 non-null   float64
#  27  firewall_cache-references           2284 non-null   float64
#  28  nf_router_cache-references          2284 non-null   float64
#  29  ndpi_stats_cache-references         2284 non-null   float64
#  30  payload_scan_cache-references       2284 non-null   float64
#  31  bridge_cache-references             2284 non-null   float64
#  32  firewall_cycles                     2284 non-null   float64
#  33  nf_router_cycles                    2284 non-null   float64
#  34  ndpi_stats_cycles                   2284 non-null   float64
#  35  payload_scan_cycles                 2284 non-null   float64
#  36  bridge_cycles                       2284 non-null   float64
#  37  firewall_L1-dcache-load-misses      2284 non-null   float64
#  38  nf_router_L1-dcache-load-misses     2284 non-null   float64
#  39  ndpi_stats_L1-dcache-load-misses    2284 non-null   float64
#  40  payload_scan_L1-dcache-load-misses  2284 non-null   float64
#  41  bridge_L1-dcache-load-misses        2284 non-null   float64
#  42  firewall_L1-dcache-loads            2284 non-null   float64
#  43  nf_router_L1-dcache-loads           2284 non-null   float64
#  44  ndpi_stats_L1-dcache-loads          2284 non-null   float64
#  45  payload_scan_L1-dcache-loads        2284 non-null   float64
#  46  bridge_L1-dcache-loads              2284 non-null   float64
#  47  firewall_LLC-load-misses            2284 non-null   float64
#  48  nf_router_LLC-load-misses           2284 non-null   float64
#  49  ndpi_stats_LLC-load-misses          2284 non-null   float64
#  50  payload_scan_LLC-load-misses        2284 non-null   float64
#  51  bridge_LLC-load-misses              2284 non-null   float64
#  52  firewall_LLC-stores                 2284 non-null   float64
#  53  nf_router_LLC-stores                2284 non-null   float64
#  54  ndpi_stats_LLC-stores               2284 non-null   float64
#  55  payload_scan_LLC-stores             2284 non-null   float64
#  56  bridge_LLC-stores                   2284 non-null   float64
#  57  firewall_LLC-loads                  2284 non-null   float64
#  58  nf_router_LLC-loads                 2284 non-null   float64
#  59  ndpi_stats_LLC-loads                2284 non-null   float64
#  60  payload_scan_LLC-loads              2284 non-null   float64
#  61  bridge_LLC-loads                    2284 non-null   float64
#  62  latency                             2239 non-null   float64
#  63  firewall_mem-stores                 2239 non-null   float64
#  64  nf_router_mem-stores                2239 non-null   float64
#  65  ndpi_stats_mem-stores               2239 non-null   float64
#  66  payload_scan_mem-stores             2239 non-null   float64
#  67  bridge_mem-stores                   2239 non-null   float64
#  68  firewall_iTLB-loads                 2239 non-null   float64
#  69  nf_router_iTLB-loads                2239 non-null   float64
#  70  ndpi_stats_iTLB-loads               2239 non-null   float64
#  71  payload_scan_iTLB-loads             2239 non-null   float64
#  72  bridge_iTLB-loads                   2239 non-null   float64
#  73  firewall_mem-loads                  2239 non-null   float64
#  74  nf_router_mem-loads                 2239 non-null   float64
#  75  ndpi_stats_mem-loads                2239 non-null   float64
#  76  payload_scan_mem-loads              2239 non-null   float64
#  77  bridge_mem-loads                    2239 non-null   float64
# dtypes: float64(78)
# memory usage: 1.4 MB

# %%
# heatmap
import seaborn as sns   
corr = data.corr()
plt.figure()
sns.heatmap(corr, cmap="coolwarm", annot=False, fmt=".2f")
plt.show()

# %%
# Reset the index starting from 0
data = data.reset_index(drop=True)
data
# Out:
#        input_rate  output_rate  firewall_instructions  nf_router_instructions  \
# 0      437.485913   408.289094           1.007456e+10            1.023861e+10
# 1     1946.264200  2087.554913           1.003758e+10            1.023424e+10
# 2     2112.990288  2109.825867           1.002860e+10            1.011452e+10
# 3     2113.241497  2110.122887           1.001283e+10            1.007096e+10
# 4     2113.282442  2111.026947           1.001703e+10            1.022266e+10
# ...           ...          ...                    ...                     ...
# 2279  2113.231027  2111.061204           1.011092e+10            1.005456e+10
# 2280  2113.091275  2111.659747           1.003967e+10            1.010051e+10
# 2281  2113.161550  2110.611039           1.002225e+10            1.023681e+10
# 2282  2113.002816  2110.378591           1.001656e+10            1.023499e+10
# 2283  2112.968968  2109.596582           1.003401e+10            1.033923e+10
#
#       ndpi_stats_instructions  payload_scan_instructions  bridge_instructions  \
# 0                1.007545e+10               1.017486e+10         1.017149e+10
# 1                1.003521e+10               1.017753e+10         1.016055e+10
# 2                1.001347e+10               1.017163e+10         1.014080e+10
# 3                9.194822e+09               1.016614e+10         9.937670e+09
# 4                9.924643e+09               1.015817e+10         1.004848e+10
# ...                       ...                        ...                  ...
# 2279             9.777458e+09               9.866212e+09         9.890201e+09
# 2280             9.814001e+09               1.018566e+10         1.015294e+10
# 2281             9.934005e+09               1.017895e+10         1.015468e+10
# 2282             9.930095e+09               1.017085e+10         1.015106e+10
# 2283             1.003288e+10               1.017214e+10         1.015406e+10
#
#       firewall_branches  nf_router_branches  ndpi_stats_branches  ...  \
# 0          1.953639e+09        2.032784e+09         1.986191e+09  ...
# 1          1.964291e+09        2.025162e+09         1.971102e+09  ...
# 2          1.960454e+09        2.006851e+09         1.968240e+09  ...
# 3          1.974081e+09        1.999396e+09         1.817389e+09  ...
# 4          1.974356e+09        2.023176e+09         1.954416e+09  ...
# ...                 ...                 ...                  ...  ...
# 2279       1.963701e+09        1.996518e+09         1.933514e+09  ...
# 2280       1.965180e+09        2.005148e+09         1.939415e+09  ...
# 2281       1.960511e+09        2.025402e+09         1.956688e+09  ...
# 2282       1.975234e+09        2.006311e+09         1.938396e+09  ...
# 2283       1.977963e+09        2.023308e+09         1.954952e+09  ...
#
#       firewall_iTLB-loads  nf_router_iTLB-loads  ndpi_stats_iTLB-loads  \
# 0                     NaN                   NaN                    NaN
# 1                     NaN                   NaN                    NaN
# 2                     NaN                   NaN                    NaN
# 3                     NaN                   NaN                    NaN
# 4                     NaN                   NaN                    NaN
# ...                   ...                   ...                    ...
# 2279                  0.0                  33.0                   58.0
# 2280                 17.0                   9.0                   37.0
# 2281                 34.0                 825.0                    0.0
# 2282                 64.0                   0.0                    0.0
# 2283                 17.0                  28.0                    0.0
#
#       payload_scan_iTLB-loads  bridge_iTLB-loads  firewall_mem-loads  \
# 0                         NaN                NaN                 NaN
# 1                         NaN                NaN                 NaN
# 2                         NaN                NaN                 NaN
# 3                         NaN                NaN                 NaN
# 4                         NaN                NaN                 NaN
# ...                       ...                ...                 ...
# 2279                      0.0                0.0                 0.0
# 2280                      0.0                0.0                 0.0
# 2281                      8.0                0.0                 0.0
# 2282                      0.0                0.0                 0.0
# 2283                     84.0               56.0                 0.0
#
#       nf_router_mem-loads  ndpi_stats_mem-loads  payload_scan_mem-loads  \
# 0                     NaN                   NaN                     NaN
# 1                     NaN                   NaN                     NaN
# 2                     NaN                   NaN                     NaN
# 3                     NaN                   NaN                     NaN
# 4                     NaN                   NaN                     NaN
# ...                   ...                   ...                     ...
# 2279                  0.0                   0.0                     0.0
# 2280                  0.0                   0.0                     0.0
# 2281                  0.0                   0.0                     0.0
# 2282                  0.0                   0.0                     0.0
# 2283                  0.0                   0.0                     0.0
#
#       bridge_mem-loads
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 2279               0.0
# 2280               0.0
# 2281               0.0
# 2282               0.0
# 2283               0.0
#
# [2284 rows x 78 columns]

# %%
data.iloc[:, 1:2].plot(logy=True)
# Out:
# <Axes: >

# %%
corr = data.corr()
correlation_list = []
for i in range(1,2):
    for j in range(i+1, len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between output_rate and bridge_cache-references: 0.81
# Correlation between output_rate and bridge_L1-dcache-load-misses: 0.81
# Correlation between output_rate and bridge_LLC-loads: 0.80
# Correlation between output_rate and bridge_LLC-stores: 0.80
# Correlation between output_rate and payload_scan_LLC-stores: 0.74
# Correlation between output_rate and payload_scan_cache-references: 0.73
# Correlation between output_rate and payload_scan_L1-dcache-load-misses: 0.72
# Correlation between output_rate and payload_scan_LLC-loads: 0.67
# Correlation between output_rate and nf_router_LLC-stores: 0.60
# Correlation between output_rate and nf_router_L1-dcache-load-misses: 0.58
# Correlation between output_rate and nf_router_cache-references: 0.58
# Correlation between output_rate and nf_router_LLC-loads: 0.55
# Correlation between output_rate and latency: 0.54
# Correlation between output_rate and firewall_LLC-loads: 0.54
# Correlation between output_rate and ndpi_stats_cache-references: 0.46
# Correlation between output_rate and ndpi_stats_L1-dcache-load-misses: 0.45
# Correlation between output_rate and firewall_L1-dcache-load-misses: 0.45
# Correlation between output_rate and firewall_cache-references: 0.45
# Correlation between output_rate and ndpi_stats_LLC-stores: 0.45
# Correlation between output_rate and ndpi_stats_LLC-loads: 0.44
# Correlation between output_rate and bridge_cycles: 0.35
# Correlation between output_rate and firewall_LLC-stores: 0.32
# Correlation between output_rate and bridge_branch-misses: 0.31
# Correlation between output_rate and bridge_branch-load-misses: 0.31
# Correlation between output_rate and payload_scan_cycles: 0.30
# Correlation between output_rate and nf_router_branch-misses: 0.30
# Correlation between output_rate and nf_router_branch-load-misses: 0.30
# Correlation between output_rate and nf_router_cycles: 0.29
# Correlation between output_rate and payload_scan_branch-misses: 0.28
# Correlation between output_rate and payload_scan_branch-load-misses: 0.28
# Correlation between output_rate and ndpi_stats_cycles: 0.25
# Correlation between output_rate and nf_router_branches: 0.24
# Correlation between output_rate and nf_router_instructions: 0.24
# Correlation between output_rate and nf_router_L1-dcache-loads: 0.24
# Correlation between output_rate and ndpi_stats_branch-load-misses: 0.23
# Correlation between output_rate and ndpi_stats_branch-misses: 0.23
# Correlation between output_rate and firewall_cycles: 0.22
# Correlation between output_rate and payload_scan_instructions: 0.21
# Correlation between output_rate and bridge_instructions: 0.21
# Correlation between output_rate and ndpi_stats_branches: 0.21
# Correlation between output_rate and bridge_L1-dcache-loads: 0.21
# Correlation between output_rate and payload_scan_branches: 0.21
# Correlation between output_rate and bridge_branches: 0.21
# Correlation between output_rate and ndpi_stats_L1-dcache-loads: 0.21
# Correlation between output_rate and payload_scan_L1-dcache-loads: 0.21
# Correlation between output_rate and ndpi_stats_instructions: 0.21
# Correlation between output_rate and firewall_instructions: 0.19
# Correlation between output_rate and firewall_L1-dcache-loads: 0.19
# Correlation between output_rate and firewall_branches: 0.19
# Correlation between output_rate and firewall_branch-misses: 0.19
# Correlation between output_rate and firewall_branch-load-misses: 0.19
# Correlation between output_rate and payload_scan_LLC-load-misses: 0.06
# Correlation between output_rate and bridge_LLC-load-misses: 0.06
# Correlation between output_rate and ndpi_stats_LLC-load-misses: 0.04
# Correlation between output_rate and firewall_LLC-load-misses: 0.04
# Correlation between output_rate and nf_router_LLC-load-misses: 0.00
# Correlation between output_rate and firewall_mem-stores: nan
# Correlation between output_rate and nf_router_mem-stores: nan
# Correlation between output_rate and ndpi_stats_mem-stores: nan
# Correlation between output_rate and payload_scan_mem-stores: nan
# Correlation between output_rate and bridge_mem-stores: nan
# Correlation between output_rate and bridge_iTLB-loads: 0.11
# Correlation between output_rate and firewall_iTLB-loads: 0.09
# Correlation between output_rate and payload_scan_cache-misses: 0.06
# Correlation between output_rate and firewall_cache-misses: 0.05
# Correlation between output_rate and payload_scan_iTLB-loads: 0.04
# Correlation between output_rate and nf_router_cache-misses: 0.04
# Correlation between output_rate and ndpi_stats_cache-misses: 0.03
# Correlation between output_rate and ndpi_stats_iTLB-loads: 0.02
# Correlation between output_rate and bridge_cache-misses: 0.00
# Correlation between output_rate and nf_router_iTLB-loads: 0.00
# Correlation between output_rate and firewall_mem-loads: nan
# Correlation between output_rate and nf_router_mem-loads: nan
# Correlation between output_rate and ndpi_stats_mem-loads: nan
# Correlation between output_rate and payload_scan_mem-loads: nan
# Correlation between output_rate and bridge_mem-loads: nan

# %%
corr = data.corr()
correlation_list = []
for i in range(62,63):
    for j in range( len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between latency and latency: 1.00
# Correlation between latency and bridge_L1-dcache-load-misses: 0.66
# Correlation between latency and bridge_LLC-loads: 0.66
# Correlation between latency and bridge_LLC-stores: 0.65
# Correlation between latency and bridge_cache-references: 0.65
# Correlation between latency and payload_scan_LLC-stores: 0.61
# Correlation between latency and payload_scan_cache-references: 0.60
# Correlation between latency and payload_scan_L1-dcache-load-misses: 0.60
# Correlation between latency and payload_scan_LLC-loads: 0.57
# Correlation between latency and output_rate: 0.54
# Correlation between latency and nf_router_LLC-stores: 0.50
# Correlation between latency and nf_router_L1-dcache-load-misses: 0.47
# Correlation between latency and nf_router_cache-references: 0.47
# Correlation between latency and nf_router_LLC-loads: 0.45
# Correlation between latency and firewall_LLC-loads: 0.45
# Correlation between latency and firewall_L1-dcache-load-misses: 0.38
# Correlation between latency and ndpi_stats_L1-dcache-load-misses: 0.38
# Correlation between latency and ndpi_stats_LLC-loads: 0.37
# Correlation between latency and firewall_cache-references: 0.37
# Correlation between latency and ndpi_stats_cache-references: 0.37
# Correlation between latency and ndpi_stats_LLC-stores: 0.37
# Correlation between latency and payload_scan_cycles: 0.29
# Correlation between latency and payload_scan_branch-misses: 0.27
# Correlation between latency and firewall_LLC-stores: 0.27
# Correlation between latency and payload_scan_branch-load-misses: 0.27
# Correlation between latency and bridge_cycles: 0.24
# Correlation between latency and payload_scan_branches: 0.21
# Correlation between latency and payload_scan_instructions: 0.21
# Correlation between latency and bridge_branch-misses: 0.21
# Correlation between latency and payload_scan_L1-dcache-loads: 0.21
# Correlation between latency and bridge_branch-load-misses: 0.21
# Correlation between latency and nf_router_branch-misses: 0.21
# Correlation between latency and nf_router_branch-load-misses: 0.21
# Correlation between latency and ndpi_stats_cycles: 0.20
# Correlation between latency and nf_router_cycles: 0.20
# Correlation between latency and firewall_cycles: 0.19
# Correlation between latency and ndpi_stats_branch-load-misses: 0.19
# Correlation between latency and ndpi_stats_branch-misses: 0.19
# Correlation between latency and firewall_L1-dcache-loads: 0.17
# Correlation between latency and firewall_branches: 0.17
# Correlation between latency and firewall_branch-load-misses: 0.17
# Correlation between latency and ndpi_stats_branches: 0.17
# Correlation between latency and firewall_branch-misses: 0.17
# Correlation between latency and ndpi_stats_L1-dcache-loads: 0.17
# Correlation between latency and firewall_instructions: 0.17
# Correlation between latency and ndpi_stats_instructions: 0.17
# Correlation between latency and nf_router_branches: 0.16
# Correlation between latency and nf_router_instructions: 0.16
# Correlation between latency and nf_router_L1-dcache-loads: 0.16
# Correlation between latency and bridge_L1-dcache-loads: 0.13
# Correlation between latency and bridge_branches: 0.13
# Correlation between latency and bridge_instructions: 0.13
# Correlation between latency and input_rate: 0.10
# Correlation between latency and bridge_cache-misses: 0.06
# Correlation between latency and payload_scan_cache-misses: 0.05
# Correlation between latency and payload_scan_LLC-load-misses: 0.05
# Correlation between latency and ndpi_stats_LLC-load-misses: 0.05
# Correlation between latency and bridge_LLC-load-misses: 0.04
# Correlation between latency and firewall_LLC-load-misses: 0.02
# Correlation between latency and nf_router_LLC-load-misses: 0.01
# Correlation between latency and firewall_mem-stores: nan
# Correlation between latency and nf_router_mem-stores: nan
# Correlation between latency and ndpi_stats_mem-stores: nan
# Correlation between latency and payload_scan_mem-stores: nan
# Correlation between latency and bridge_mem-stores: nan
# Correlation between latency and bridge_iTLB-loads: 0.05
# Correlation between latency and firewall_cache-misses: 0.04
# Correlation between latency and ndpi_stats_cache-misses: 0.03
# Correlation between latency and payload_scan_iTLB-loads: 0.03
# Correlation between latency and firewall_iTLB-loads: 0.02
# Correlation between latency and nf_router_cache-misses: 0.02
# Correlation between latency and ndpi_stats_iTLB-loads: 0.02
# Correlation between latency and nf_router_iTLB-loads: 0.02
# Correlation between latency and firewall_mem-loads: nan
# Correlation between latency and nf_router_mem-loads: nan
# Correlation between latency and ndpi_stats_mem-loads: nan
# Correlation between latency and payload_scan_mem-loads: nan
# Correlation between latency and bridge_mem-loads: nan

# %%
# combine random_rates

file_names = ["random_rates_exp-1.csv","random_rates_exp-2.csv"]

folder_path = os.path.abspath(os.path.join("../datasets"))
load_stimulus_random_rates = pd.DataFrame()

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_csv(file_path)
    load_stimulus_random_rates = pd.concat([load_stimulus_random_rates, df], ignore_index=True)

# Save the combined DataFrame as a new CSV file
abs_path = os.path.join("..\\datasets", 'load_stimulus_random_rates.csv')
load_stimulus_random_rates.to_csv(abs_path, index=False)

# %%
# combine intervention
file_names = []
for i in range(25,35):
    item = 'intervention_exp-{}.csv'.format(i)
    file_names.append(item)

folder_path = os.path.abspath(os.path.join("../datasets"))
intervention_global_1 = pd.DataFrame()

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_csv(file_path)
    intervention_global_1 = pd.concat([intervention_global_1, df], ignore_index=True)

# Save the combined DataFrame as a new CSV file
abs_path = os.path.join("..\\datasets", 'intervention_global_1.csv')
intervention_global_1.to_csv(abs_path, index=False)

current_dir = os.getcwd()

exp_ls = "intervention_global_1.csv"
#exp_ls="load_stimulus_exp1.csv"
file_path = os.path.abspath(os.path.join("..\\datasets", exp_ls))

data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21578 entries, 0 to 2849
# Data columns (total 63 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   firewall_instructions               21561 non-null  float64
#  1   nf_router_instructions              21553 non-null  float64
#  2   ndpi_stats_instructions             21552 non-null  float64
#  3   payload_scan_instructions           21559 non-null  float64
#  4   bridge_instructions                 21552 non-null  float64
#  5   firewall_branches                   21566 non-null  float64
#  6   nf_router_branches                  21565 non-null  float64
#  7   ndpi_stats_branches                 21564 non-null  float64
#  8   payload_scan_branches               21567 non-null  float64
#  9   bridge_branches                     21565 non-null  float64
#  10  firewall_branch-misses              21572 non-null  float64
#  11  nf_router_branch-misses             21573 non-null  float64
#  12  ndpi_stats_branch-misses            21574 non-null  float64
#  13  payload_scan_branch-misses          21572 non-null  float64
#  14  bridge_branch-misses                21572 non-null  float64
#  15  firewall_branch-load-misses         21575 non-null  float64
#  16  nf_router_branch-load-misses        21573 non-null  float64
#  17  ndpi_stats_branch-load-misses       21574 non-null  float64
#  18  payload_scan_branch-load-misses     21572 non-null  float64
#  19  bridge_branch-load-misses           21575 non-null  float64
#  20  firewall_cache-misses               21577 non-null  float64
#  21  nf_router_cache-misses              21574 non-null  float64
#  22  ndpi_stats_cache-misses             21575 non-null  float64
#  23  payload_scan_cache-misses           21569 non-null  float64
#  24  bridge_cache-misses                 21573 non-null  float64
#  25  firewall_cache-references           21566 non-null  float64
#  26  nf_router_cache-references          21567 non-null  float64
#  27  ndpi_stats_cache-references         21569 non-null  float64
#  28  payload_scan_cache-references       21564 non-null  float64
#  29  bridge_cache-references             21562 non-null  float64
#  30  firewall_cycles                     21561 non-null  float64
#  31  nf_router_cycles                    21566 non-null  float64
#  32  ndpi_stats_cycles                   21566 non-null  float64
#  33  payload_scan_cycles                 21564 non-null  float64
#  34  bridge_cycles                       21566 non-null  float64
#  35  firewall_L1-dcache-load-misses      21562 non-null  float64
#  36  nf_router_L1-dcache-load-misses     21574 non-null  float64
#  37  ndpi_stats_L1-dcache-load-misses    21573 non-null  float64
#  38  payload_scan_L1-dcache-load-misses  21570 non-null  float64
#  39  bridge_L1-dcache-load-misses        21573 non-null  float64
#  40  firewall_L1-dcache-loads            21567 non-null  float64
#  41  nf_router_L1-dcache-loads           21570 non-null  float64
#  42  ndpi_stats_L1-dcache-loads          21575 non-null  float64
#  43  payload_scan_L1-dcache-loads        21572 non-null  float64
#  44  bridge_L1-dcache-loads              21572 non-null  float64
#  45  firewall_LLC-load-misses            21516 non-null  float64
#  46  nf_router_LLC-load-misses           21536 non-null  float64
#  47  ndpi_stats_LLC-load-misses          21533 non-null  float64
#  48  payload_scan_LLC-load-misses        21527 non-null  float64
#  49  bridge_LLC-load-misses              21531 non-null  float64
#  50  firewall_LLC-stores                 21531 non-null  float64
#  51  nf_router_LLC-stores                21531 non-null  float64
#  52  ndpi_stats_LLC-stores               21530 non-null  float64
#  53  payload_scan_LLC-stores             21527 non-null  float64
#  54  bridge_LLC-stores                   21533 non-null  float64
#  55  firewall_LLC-loads                  21531 non-null  float64
#  56  nf_router_LLC-loads                 21539 non-null  float64
#  57  ndpi_stats_LLC-loads                21534 non-null  float64
#  58  payload_scan_LLC-loads              21532 non-null  float64
#  59  bridge_LLC-loads                    21538 non-null  float64
#  60  input_rate                          21578 non-null  float64
#  61  output_rate                         21578 non-null  float64
#  62  latency                             21578 non-null  float64
# dtypes: float64(63)
# memory usage: 10.5 MB

# %%
# Reset the index starting from 0
data = data.reset_index(drop=True)
data
# Out:
#        firewall_instructions  nf_router_instructions  ndpi_stats_instructions  \
# 0               1.784380e+05            2.166442e+09             2.344566e+09
# 1               8.725932e+08            7.433388e+09             7.938936e+09
# 2               2.343685e+09            6.866432e+09             4.867167e+09
# 3               2.386229e+09            7.035409e+09             4.724220e+09
# 4               2.376255e+09            6.991497e+09             4.946863e+09
# ...                      ...                     ...                      ...
# 21573           7.962502e+09            7.892241e+09             7.868706e+09
# 21574           7.515474e+09            7.925682e+09             7.823012e+09
# 21575           7.381892e+09            7.495733e+09             7.434971e+09
# 21576           7.563969e+09            7.469506e+09             7.326896e+09
# 21577           7.579644e+09            7.408511e+09             7.418678e+09
#
#        payload_scan_instructions  bridge_instructions  firewall_branches  \
# 0                   3.594936e+09         3.623531e+09       3.567800e+04
# 1                   8.983584e+09         8.797672e+09       1.668305e+08
# 2                   7.690254e+09         6.642576e+09       4.718919e+08
# 3                   7.111924e+09         7.142203e+09       4.858310e+08
# 4                   2.972079e+09         6.608453e+09       4.800007e+08
# ...                          ...                  ...                ...
# 21573               7.165000e+09         9.569379e+09       1.584457e+09
# 21574               7.297206e+09         9.392759e+09       1.487400e+09
# 21575               6.898812e+09         9.089272e+09       1.469360e+09
# 21576               6.773307e+09         8.966362e+09       1.470878e+09
# 21577               6.893705e+09                  NaN       1.489056e+09
#
#        nf_router_branches  ndpi_stats_branches  payload_scan_branches  \
# 0            4.301991e+08         4.412206e+08           6.953730e+08
# 1            1.462517e+09         1.558124e+09           1.785756e+09
# 2            1.388445e+09         9.335953e+08           1.551510e+09
# 3            1.420111e+09         8.937214e+08           1.446139e+09
# 4            1.401817e+09         9.521797e+08           6.008605e+08
# ...                   ...                  ...                    ...
# 21573        1.571428e+09         1.550379e+09           1.416005e+09
# 21574        1.579090e+09         1.540602e+09           1.451313e+09
# 21575        1.495661e+09         1.456561e+09           1.368786e+09
# 21576        1.488276e+09         1.439725e+09           1.349429e+09
# 21577        1.479491e+09         1.452366e+09           1.341191e+09
#
#        bridge_branches  ...  payload_scan_LLC-stores  bridge_LLC-stores  \
# 0         7.002405e+08  ...                    495.0              492.0
# 1         1.744504e+09  ...                3387104.0          3929469.0
# 2         1.329289e+09  ...                7419949.0          7177319.0
# 3         1.404327e+09  ...                7179664.0          6368610.0
# 4         1.279155e+09  ...                7869184.0          7506020.0
# ...                ...  ...                      ...                ...
# 21573     1.893127e+09  ...                6869343.0          2469471.0
# 21574     1.859968e+09  ...                7951588.0          2624206.0
# 21575     1.796230e+09  ...                9588583.0          3513319.0
# 21576     1.778916e+09  ...                9730217.0          3600477.0
# 21577              NaN  ...                9582875.0                NaN
#
#        firewall_LLC-loads  nf_router_LLC-loads  ndpi_stats_LLC-loads  \
# 0                     NaN               2428.0                1706.0
# 1               7939506.0            7486359.0            12499511.0
# 2              22362862.0           18335905.0            27947413.0
# 3              21586524.0           16167112.0            27403763.0
# 4              22243506.0           17946642.0            28312648.0
# ...                   ...                  ...                   ...
# 21573          10525018.0           10724013.0            12528296.0
# 21574          10526229.0           11314307.0            13011970.0
# 21575          13763829.0           13632303.0            16253194.0
# 21576          13534690.0           13193763.0            16460056.0
# 21577          14141645.0           13079978.0            16458935.0
#
#        payload_scan_LLC-loads  bridge_LLC-loads   input_rate  output_rate  \
# 0                      6474.0            8502.0  1069.808291     0.000000
# 1                  12394918.0         5532247.0  3261.967487     0.000000
# 2                  25423736.0        10133479.0  3329.265873  2273.344672
# 3                  24924450.0         9240302.0  3327.506901  3324.853252
# 4                  25439558.0        10452273.0  3269.983075  3249.341975
# ...                       ...               ...          ...          ...
# 21573              12714243.0         5256909.0  3285.762904  1643.013080
# 21574              14519316.0         5727769.0  3285.294129  1639.358514
# 21575              18061308.0         7311754.0  3282.676659  1632.220317
# 21576              18141558.0         7332520.0  3936.451637  2038.851517
# 21577              17810016.0               NaN  5365.036330  2684.344563
#
#          latency
# 0         20.292
# 1        666.954
# 2         12.771
# 3        160.998
# 4         28.185
# ...          ...
# 21573  15000.000
# 21574    261.674
# 21575  15000.000
# 21576    174.102
# 21577  15000.000
#
# [21578 rows x 63 columns]

# %%
data.iloc[:, 61].plot(logy=True)
# Out:
# <Axes: >
