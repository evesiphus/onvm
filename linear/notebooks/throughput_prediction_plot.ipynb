# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib.colors import Normalize
import matplotlib as mp
import sys, re, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
try:
    if chdir:
        pass
except:
    current_dir = os.getcwd()
    os.chdir(current_dir +"/..")
    os.path.abspath(os.curdir)
    
chdir = True
current_dir = os.getcwd()

# %%
# predict throughput -- delete unrelated feature
fig, ax = plt.subplots(facecolor='white', figsize=(4,3))
#ax.set_facecolor('white')
plt.style.use('classic')

accuracy_dct_random=[0.0, 83.14606741573034, 88.95131086142321, 91.01123595505618, 94.19475655430712, 96.62921348314607, 96.62921348314607, 96.62921348314607, 97.19101123595506, 98.31460674157303, 100.0]
accuracy_linear_regression_random=[0.0, 86.70411985018727, 91.38576779026218, 94.5692883895131, 95.31835205992509, 97.56554307116106, 97.94007490636703, 98.12734082397003, 98.31460674157303, 98.87640449438202, 99.06367041198502]
accuracy_linear_ForestRegressor = [0.0, 83.52059925093633, 91.38576779026218, 94.19475655430712, 96.25468164794007, 98.31460674157303, 98.68913857677903, 98.87640449438202, 99.25093632958801, 100.0, 100.0]

# nural network
accuracy_nural =  [0.0, 79.7752808988764, 90.0749063670412, 94.19475655430712, 95.69288389513109, 97.94007490636703, 97.94007490636703, 98.12734082397003, 98.87640449438202, 99.25093632958801, 99.25093632958801]

accuracy_nural1 =  [0.0, 69.62569832402235, 83.79888268156425, 91.34078212290503, 96.08938547486034, 97.76536312849163, 97.76536312849163, 97.76536312849163, 98.04469273743017, 98.04469273743017,100.0]

#plot
plt.plot([num/10 for num in range(11)],[x / 100 for x in accuracy_dct_random], marker='x',markersize = 4, c='k',linestyle='-',linewidth=1, dashes=(5, 3),label='Decision tree')  
plt.plot([num/10 for num in range(11)],[x / 100 for x in accuracy_linear_regression_random], marker='o',markersize = 4, c='b',linestyle='-',linewidth=1, dashes=(5, 3),label = 'Linear regression')  
plt.plot([num/10 for num in range(11)],[x / 100 for x in accuracy_linear_ForestRegressor] , marker='o',markersize = 4, c='r',linestyle='-',linewidth=1, dashes=(5, 3),label = 'Forest regresson ')  
plt.plot([num/10 for num in range(11)],[x / 100 for x in accuracy_nural], marker='>',markersize = 4, c='g',linewidth=1, label = 'ANN')  
#plt.plot([num/10 for num in range(11)],[x / 100 for x in accuracy_nural1], marker='>',markersize = 4, c='orange',linestyle='-',linewidth=2, dashes=(5, 3),label = 'DNN with entire metrics')  
ax.legend(loc="lower right", fontsize=12)

fig.text(0.5, 0.01, 'Threshold', size='14', ha='center')
fig.text(-0.005, 0.5, 'Accuracy', size='14', va='center', rotation='vertical')
plt.subplots_adjust(left=0.12, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.4)
plt.grid()
ax.set_facecolor('white')

#save figure
folder_path = 'figure/rate_prediction'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
file_path = os.path.join(folder_path, 'accuracy-compare.pdf' )
plt.savefig(file_path,bbox_inches='tight')
plt.show()

# %%
# predict throughput -- impact of unrelated metrics

fig, ax = plt.subplots(facecolor='white', figsize=(4,3))
#ax.set_facecolor('white')
plt.style.use('classic')

# nural network
accuracy_nural =  [0.0, 79.7752808988764, 90.0749063670412, 94.19475655430712, 95.69288389513109, 97.94007490636703, 97.94007490636703, 98.12734082397003, 98.87640449438202, 99.25093632958801, 99.25093632958801]
accuracy_nural1 =  [0.0, 69.62569832402235, 83.79888268156425, 87.34078212290503, 92.08938547486034, 95.76536312849163, 97.76536312849163, 97.76536312849163, 98.04469273743017, 98.04469273743017,100.0]

#plot
plt.plot([num/10 for num in range(11)],[x / 100 for x in accuracy_nural], marker='>',markersize = 4, c='k',linewidth=1, label = 'ANN with partial metrics')  
plt.plot([num/10 for num in range(11)],[x / 100 for x in accuracy_nural1], marker='>',markersize = 4, c='r',linestyle='-',linewidth=2, dashes=(5, 3),label = 'ANN with entire metrics')  
ax.legend(loc="lower right", fontsize=12)

fig.text(0.5, 0.01, 'Threshold', size='14', ha='center')
fig.text(0, 0.5, 'Accuracy', size='14', va='center', rotation='vertical')
plt.subplots_adjust(left=0.12, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.4)
plt.grid()
ax.set_facecolor('white')

#save figure
folder_path = 'figure/rate_prediction'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
file_path = os.path.join(folder_path, 'accuracy-compare-boring-metrics.pdf' )
plt.savefig(file_path,bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data for the clustered bar chart
Ann = [0.95, 0.81, 0.63]  # Two bars for 'single vnf'
Slomo = [0.92, 0.75, 0.55]    # Two bars for 'multi vnf'
Dobrescu = [0.76, 0.63, 0.41]  # Two bars for 'multi vnf'

# X-axis labels for the bars
x_labels = ['Bridge', 'SFC', 'Intervention']

# Set the width of the bars
bar_width = 0.15

# Calculate the positions for the bars on the x-axis
x_pos_single_vnf = range(len(Ann))
x_pos_multi_vnf = [x + bar_width for x in x_pos_single_vnf]
x_pos_multi_vnf_1 = [x + bar_width for x in x_pos_multi_vnf]

# Define custom colors for the bars
color_ann = 'lightblue'
color_slomo = '#FFAAAA'
color_dobrescu = 'green'

# Create the figure and axis with adjusted margins
fig, ax = plt.subplots(facecolor='white', figsize=(7,2.5))
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.2)

# Create the clustered bars for 'single vnf'
ax.bar(x_pos_single_vnf, Ann, width=bar_width, label='Ann', color=color_ann)

# Create the clustered bars for 'multi vnf'
ax.bar(x_pos_multi_vnf, Slomo, width=bar_width, label='Slomo', color=color_slomo, hatch='//', edgecolor="black")

# Create the clustered bars for 'multi vnf' with a larger distance
ax.bar(x_pos_multi_vnf_1, Dobrescu, width=bar_width, label='Dobrescu', color=color_dobrescu, hatch='xx', edgecolor="black")

# Set the x-axis labels and position them at the boundaries
x_pos_boundaries = [0, len(x_labels) - 1]
ax.set_xticks([x + bar_width / 2 for x in x_pos_boundaries])
ax.set_xticklabels([x_labels[x] for x in x_pos_boundaries])

# Set the labels and title
ax.set_ylabel('Accuracy')

# Add a legend without a bounding box
legend = ax.legend(loc="upper right", fontsize=9)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data for the clustered bar chart
Ann = [0.95, 0.81, 0.63]  # Two bars for 'single vnf'
Slomo = [0.94, 0.75, 0.55]    # Two bars for 'multi vnf'
Dobrescu = [0.76, 0.63, 0.41]  # Two bars for 'multi vnf'

# X-axis labels for the bars
x_labels = ['Bridge', 'SFC', 'Intervention']
x_labels = ['Scenario 1', 'Scenario 2', 'Scenario 3']
# Set the width of the bars
bar_width = 0.15

# Calculate the positions for the bars on the x-axis
x_pos_single_vnf = range(len(Ann))
x_pos_multi_vnf = [x + bar_width for x in x_pos_single_vnf]
x_pos_multi_vnf_1 = [x + bar_width for x in x_pos_multi_vnf]

# Define custom colors for the bars
color_ann = 'lightblue'
color_slomo = '#FFAAAA'
color_dobrescu = 'green'

# Create the figure and axis with adjusted margins
fig, ax = plt.subplots(facecolor='white', figsize=(7, 2.5))
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.2)

# Create the clustered bars for 'single vnf'
ax.bar(x_pos_single_vnf, Ann, width=bar_width, label='Our method', color=color_ann)

# Create the clustered bars for 'multi vnf'
ax.bar(x_pos_multi_vnf, Slomo, width=bar_width, label='Slomo', color=color_slomo, hatch='//', edgecolor="black")

# Create the clustered bars for 'multi vnf' with a larger distance
ax.bar(x_pos_multi_vnf_1, Dobrescu, width=bar_width, label='Dobrescu', color=color_dobrescu, hatch='xx', edgecolor="black")

# Calculate midpoints for the clustered bars
midpoints = [pos + bar_width / 2 +0.05 for pos in x_pos_single_vnf] 

# Set the x-axis ticks and labels
ax.set_xticks(midpoints)
ax.set_xticklabels(x_labels)

# Set custom x-limits to reduce the distance from 0 to the first bar
ax.set_xlim(midpoints[0] - bar_width-0.1, midpoints[-1] + bar_width+0.3)

# Set the labels and title
ax.set_ylabel('Accuracy')

# Add a legend without a bounding box
legend = ax.legend(loc="upper right", fontsize=8)

#save figure
folder_path = 'figure/rate_prediction'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
file_path = os.path.join(folder_path, 'slomo-dobrescu-comparision.pdf' )
plt.savefig(file_path,bbox_inches='tight')
# Show the plot
plt.show()

# %%
import os
import matplotlib.pyplot as plt

# Sample data for the clustered bar chart
Ann = [0.97, 0.81, 0.65]  # Two bars for 'single vnf'
Slomo = [0.95, 0.75, 0.55]    # Two bars for 'multi vnf'
Dobrescu = [0.83, 0.63, 0.41]  # Two bars for 'multi vnf'

# X-axis labels for the bars
x_labels = ['Bridge', 'SFC', 'Intervention']

# Set the width of the bars
bar_width = 0.15

# Calculate the positions for the bars on the x-axis
x_pos_single_vnf = range(len(Ann))
x_pos_multi_vnf = [x + bar_width for x in x_pos_single_vnf]
x_pos_multi_vnf_1 = [x + bar_width for x in x_pos_multi_vnf]

# Define custom colors for the bars
color_ann = 'lightblue'
color_slomo = '#FFAAAA'
color_dobrescu = 'green'

# Create the figure and axis with adjusted margins
fig, ax = plt.subplots(facecolor='white', figsize=(7, 2.5))
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.2)

# Create the clustered bars for 'single vnf'
ann_bars = ax.bar(x_pos_single_vnf, Ann, width=bar_width, label='Our method', color=color_ann)

# Create the clustered bars for 'multi vnf'
slomo_bars = ax.bar(x_pos_multi_vnf, Slomo, width=bar_width, label='Slomo', color=color_slomo, hatch='//', edgecolor="black")

# Create the clustered bars for 'multi vnf' with a larger distance
dobrescu_bars = ax.bar(x_pos_multi_vnf_1, Dobrescu, width=bar_width, label='Dobrescu', color=color_dobrescu, hatch='xx', edgecolor="black")

# Calculate midpoints for the clustered bars
midpoints = [pos + bar_width / 2 +0.05 for pos in x_pos_single_vnf] 

# Set the x-axis ticks and labels
ax.set_xticks(midpoints)
ax.set_xticklabels(x_labels)

# Set custom x-limits to reduce the distance from 0 to the first bar
ax.set_xlim(midpoints[0] - bar_width-0.1, midpoints[-1] + bar_width+0.3)

# Set the labels and title
ax.set_ylabel('Accuracy')

# Add numbers above each bar
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords="offset points", ha='center', va='bottom', fontsize=9)

autolabel(ann_bars)
autolabel(slomo_bars)
autolabel(dobrescu_bars)
ax.set_ylim(0,1.2)
# Add a legend without a bounding box
legend = ax.legend(loc="upper right", fontsize=8)


# Show the plot
plt.show()

# %%
import os
import matplotlib.pyplot as plt

# Sample data for the clustered bar chart
Ann = [0.97, 0.81, 0.65]  # Two bars for 'single vnf'
Slomo = [0.95, 0.75, 0.55]    # Two bars for 'multi vnf'
Dobrescu = [0.83, 0.63, 0.41]  # Two bars for 'multi vnf'

# X-axis labels for the bars
x_labels = ['Bridge', 'SFC', 'Intervention']

# Set the width of the bars
bar_width = 0.15

# Calculate the positions for the bars on the x-axis
x_pos_single_vnf = range(len(Ann))
x_pos_multi_vnf = [x + bar_width for x in x_pos_single_vnf]
x_pos_multi_vnf_1 = [x + bar_width for x in x_pos_multi_vnf]

# Define custom colors for the bars
color_ann = 'lightblue'
color_slomo = '#FFAAAA'
color_dobrescu = 'green'

# Create the figure and axis with adjusted margins
fig, ax = plt.subplots(facecolor='white', figsize=(7, 2.5))
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.2)

# Create the clustered bars for 'single vnf'
ann_bars = ax.bar(x_pos_single_vnf, Ann, width=bar_width, label='Our method', color=color_ann)

# Create the clustered bars for 'multi vnf'
slomo_bars = ax.bar(x_pos_multi_vnf, Slomo, width=bar_width, label='Slomo', color=color_slomo, hatch='//', edgecolor="black")

# Create the clustered bars for 'multi vnf' with a larger distance
dobrescu_bars = ax.bar(x_pos_multi_vnf_1, Dobrescu, width=bar_width, label='Dobrescu', color=color_dobrescu, hatch='xx', edgecolor="black")

# Calculate midpoints for the clustered bars
midpoints = [pos + bar_width / 2 +0.05 for pos in x_pos_single_vnf] 

# Set the x-axis ticks and labels
ax.set_xticks(midpoints)
ax.set_xticklabels(x_labels)

# Set custom x-limits to reduce the distance from 0 to the first bar
ax.set_xlim(midpoints[0] - bar_width-0.1, midpoints[-1] + bar_width+0.3)

# Set the labels and title
ax.set_ylabel('Accuracy')

# Add numbers above each bar
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords="offset points", ha='center', va='bottom', fontsize=9)

autolabel(ann_bars)
autolabel(slomo_bars)
autolabel(dobrescu_bars)

# Remove the y-axis number 1.2
ax.yaxis.set_tick_params(labelleft=False)

# Add a legend without a bounding box
legend = ax.legend(loc="upper right", fontsize=8)

# Show the plot
plt.show()

# %%
import os
import matplotlib.pyplot as plt

# Sample data for the clustered bar chart
Ann = [0.97, 0.81, 0.65]  # Two bars for 'single vnf'
Slomo = [0.95, 0.75, 0.55]    # Two bars for 'multi vnf'
Dobrescu = [0.83, 0.63, 0.41]  # Two bars for 'multi vnf'

# X-axis labels for the bars
x_labels = ['Bridge', 'SFC', 'Intervention']

# Set the width of the bars
bar_width = 0.15

# Calculate the positions for the bars on the x-axis
x_pos_single_vnf = range(len(Ann))
x_pos_multi_vnf = [x + bar_width for x in x_pos_single_vnf]
x_pos_multi_vnf_1 = [x + bar_width for x in x_pos_multi_vnf]

# Define custom colors for the bars
color_ann = 'lightblue'
color_slomo = '#FFAAAA'
color_dobrescu = 'green'

# Create the figure and axis with adjusted margins
fig, ax = plt.subplots(facecolor='white', figsize=(7, 2.5))
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.2)

# Create the clustered bars for 'single vnf'
ann_bars = ax.bar(x_pos_single_vnf, Ann, width=bar_width, label='Our method', color=color_ann)

# Create the clustered bars for 'multi vnf'
slomo_bars = ax.bar(x_pos_multi_vnf, Slomo, width=bar_width, label='Slomo', color=color_slomo, hatch='//', edgecolor="black")

# Create the clustered bars for 'multi vnf' with a larger distance
dobrescu_bars = ax.bar(x_pos_multi_vnf_1, Dobrescu, width=bar_width, label='Dobrescu', color=color_dobrescu, hatch='xx', edgecolor="black")

# Calculate midpoints for the clustered bars
midpoints = [pos + bar_width / 2 +0.05 for pos in x_pos_single_vnf] 

# Set the x-axis ticks and labels
ax.set_xticks(midpoints)
ax.set_xticklabels(x_labels)

# Set custom x-limits to reduce the distance from 0 to the first bar
ax.set_xlim(midpoints[0] - bar_width-0.1, midpoints[-1] + bar_width+0.3)

# Set the labels and title
ax.set_ylabel('Accuracy')

# Add numbers above each bar
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        # Exclude annotating the bar with the height value of 1.2
        if height != 1.2:
            ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3), textcoords="offset points", ha='center', va='bottom', fontsize=9)

autolabel(ann_bars)
autolabel(slomo_bars)
autolabel(dobrescu_bars)

# Remove the y-axis number 1.2
ax.yaxis.set_tick_params(labelleft=False)

# Add a legend without a bounding box
legend = ax.legend(loc="upper right", fontsize=8)

# Show the plot
plt.show()

# %%
import os
import matplotlib.pyplot as plt

# Sample data for the clustered bar chart
Ann = [0.97, 0.83, 0.65]  # Two bars for 'single vnf'
Slomo = [0.95, 0.75, 0.55]    # Two bars for 'multi vnf'
Dobrescu = [0.83, 0.63, 0.41]  # Two bars for 'multi vnf'

# X-axis labels for the bars
x_labels = ['Bridge', 'SFC', 'Intervention']

# Set the width of the bars
bar_width = 0.15

# Calculate the positions for the bars on the x-axis
x_pos_single_vnf = range(len(Ann))
x_pos_multi_vnf = [x + bar_width for x in x_pos_single_vnf]
x_pos_multi_vnf_1 = [x + bar_width for x in x_pos_multi_vnf]

# Define custom colors for the bars
color_ann = 'lightblue'
color_slomo = '#FFAAAA'
color_dobrescu = 'green'

# Create the figure and axis with adjusted margins
fig, ax = plt.subplots(facecolor='white', figsize=(7, 2.5))
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.2)

# Create the clustered bars for 'single vnf'
ann_bars = ax.bar(x_pos_single_vnf, Ann, width=bar_width, label='Our method', color=color_ann)

# Create the clustered bars for 'multi vnf'
slomo_bars = ax.bar(x_pos_multi_vnf, Slomo, width=bar_width, label='Slomo', color=color_slomo, hatch='//', edgecolor="black")

# Create the clustered bars for 'multi vnf' with a larger distance
dobrescu_bars = ax.bar(x_pos_multi_vnf_1, Dobrescu, width=bar_width, label='Dobrescu', color=color_dobrescu, hatch='xx', edgecolor="black")

# Calculate midpoints for the clustered bars
midpoints = [pos + bar_width / 2 +0.05 for pos in x_pos_single_vnf] 

# Set the x-axis ticks and labels
ax.set_xticks(midpoints)
ax.set_xticklabels(x_labels)

# Set custom x-limits to reduce the distance from 0 to the first bar
ax.set_xlim(midpoints[0] - bar_width-0.1, midpoints[-1] + bar_width+0.3)

# Set the labels and title
ax.set_ylabel('Accuracy')

# Add numbers above each bar
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords="offset points", ha='center', va='bottom', fontsize=9)

autolabel(ann_bars)
autolabel(slomo_bars)
autolabel(dobrescu_bars)
ax.set_ylim(0, 1.2)

# Add a legend without a bounding box
legend = ax.legend(loc="upper right", fontsize=8)

#save figure
folder_path = 'figure/rate_prediction'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
file_path = os.path.join(folder_path, 'slomo-dobrescu-comparision.png' )
plt.savefig(file_path,bbox_inches='tight')
# Show the plot
plt.show()
