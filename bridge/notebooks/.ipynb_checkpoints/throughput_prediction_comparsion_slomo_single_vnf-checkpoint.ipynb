# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys, re, os

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.ensemble import RandomForestRegressor

# %%
# %matplotlib inline

plt.rc('font', family='serif')
plt.rcParams.update({'font.size': 11})

plt.rcParams['figure.dpi'] = 200
plt.rcParams['savefig.dpi'] = 300

# %%
# Change the work directory to the parent
try:
    if chdir:
        pass
except:
    current_dir = os.getcwd()
    os.chdir(current_dir +"/..")
    os.path.abspath(os.curdir)

# %%
chdir = True

# %%
import itertools
marker = itertools.cycle(('x',',', '+', '.', 'o', '*'))
cycol = itertools.cycle('bgrcmk')

# %% [markdown]
# # Service chain configuration

# %%
current_dir = os.getcwd()
file_path = os.path.abspath('../bridge/datasets/load_stimulus_exp-12.csv')
#file_path = os.path.abspath('../linear/datasets/random_rates_exp-1.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
#data = data.drop('latency', axis=1)
df = data.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12024 entries, 0 to 12023
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   input_rate                    12024 non-null  float64
#  1   output_rate                   12024 non-null  float64
#  2   latency                       12024 non-null  float64
#  3   bridge_instructions           12024 non-null  float64
#  4   bridge_branches               12024 non-null  float64
#  5   bridge_branch-misses          12024 non-null  float64
#  6   bridge_branch-load-misses     12024 non-null  float64
#  7   bridge_cache-misses           12024 non-null  float64
#  8   bridge_cache-references       12024 non-null  float64
#  9   bridge_cycles                 12024 non-null  float64
#  10  bridge_L1-dcache-load-misses  12024 non-null  float64
#  11  bridge_L1-dcache-loads        12024 non-null  float64
#  12  bridge_LLC-load-misses        12024 non-null  float64
#  13  bridge_LLC-stores             12024 non-null  float64
#  14  bridge_LLC-loads              12024 non-null  float64
#  15  bridge_mem-stores             12024 non-null  float64
#  16  bridge_iTLB-loads             12024 non-null  float64
#  17  bridge_mem-loads              12024 non-null  float64
#  18  bridge_bus-cycles             12024 non-null  float64
# dtypes: float64(19)
# memory usage: 1.8 MB

# %%
corr = data.corr()
correlation_list = []
for i in range(1, 2):
    for j in range(i+1, len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between output_rate and firewall_LLC-loads: 0.98
# Correlation between output_rate and firewall_cache-references: 0.98
# Correlation between output_rate and firewall_L1-dcache-load-misses: 0.98
# Correlation between output_rate and payload_scan_LLC-loads: 0.98
# Correlation between output_rate and ndpi_stats_LLC-loads: 0.98
# Correlation between output_rate and ndpi_stats_L1-dcache-load-misses: 0.97
# Correlation between output_rate and payload_scan_cache-references: 0.97
# Correlation between output_rate and payload_scan_L1-dcache-load-misses: 0.97
# Correlation between output_rate and ndpi_stats_cache-references: 0.97
# Correlation between output_rate and nf_router_LLC-stores: 0.97
# Correlation between output_rate and payload_scan_LLC-stores: 0.97
# Correlation between output_rate and firewall_LLC-stores: 0.96
# Correlation between output_rate and ndpi_stats_LLC-load-misses: 0.96
# Correlation between output_rate and ndpi_stats_LLC-stores: 0.96
# Correlation between output_rate and nf_router_L1-dcache-load-misses: 0.96
# Correlation between output_rate and nf_router_cache-references: 0.96
# Correlation between output_rate and bridge_LLC-loads: 0.96
# Correlation between output_rate and bridge_cache-references: 0.96
# Correlation between output_rate and bridge_LLC-stores: 0.96
# Correlation between output_rate and ndpi_stats_branches: 0.96
# Correlation between output_rate and bridge_L1-dcache-load-misses: 0.96
# Correlation between output_rate and ndpi_stats_L1-dcache-loads: 0.96
# Correlation between output_rate and payload_scan_LLC-load-misses: 0.96
# Correlation between output_rate and nf_router_LLC-loads: 0.96
# Correlation between output_rate and ndpi_stats_instructions: 0.95
# Correlation between output_rate and ndpi_stats_cache-misses: 0.95
# Correlation between output_rate and payload_scan_cache-misses: 0.94
# Correlation between output_rate and bridge_LLC-load-misses: 0.94
# Correlation between output_rate and firewall_L1-dcache-loads: 0.91
# Correlation between output_rate and firewall_branches: 0.91
# Correlation between output_rate and firewall_instructions: 0.91
# Correlation between output_rate and bridge_cache-misses: 0.88
# Correlation between output_rate and nf_router_L1-dcache-loads: 0.86
# Correlation between output_rate and nf_router_instructions: 0.85
# Correlation between output_rate and nf_router_branches: 0.85
# Correlation between output_rate and firewall_LLC-load-misses: 0.81
# Correlation between output_rate and ndpi_stats_branch-load-misses: 0.81
# Correlation between output_rate and ndpi_stats_branch-misses: 0.81
# Correlation between output_rate and bridge_L1-dcache-loads: 0.81
# Correlation between output_rate and bridge_branches: 0.80
# Correlation between output_rate and bridge_instructions: 0.80
# Correlation between output_rate and firewall_cache-misses: 0.79
# Correlation between output_rate and nf_router_LLC-load-misses: 0.77
# Correlation between output_rate and firewall_branch-load-misses: 0.69
# Correlation between output_rate and firewall_branch-misses: 0.69
# Correlation between output_rate and latency: 0.67
# Correlation between output_rate and payload_scan_L1-dcache-loads: 0.63
# Correlation between output_rate and payload_scan_instructions: 0.63
# Correlation between output_rate and payload_scan_branches: 0.62
# Correlation between output_rate and nf_router_cache-misses: 0.61
# Correlation between output_rate and bridge_branch-misses: 0.50
# Correlation between output_rate and bridge_branch-load-misses: 0.50
# Correlation between output_rate and nf_router_branch-misses: 0.46
# Correlation between output_rate and nf_router_branch-load-misses: 0.46
# Correlation between output_rate and payload_scan_branch-misses: 0.29
# Correlation between output_rate and payload_scan_branch-load-misses: 0.29
# Correlation between output_rate and firewall_cycles: 0.24
# Correlation between output_rate and bridge_cycles: 0.11
# Correlation between output_rate and ndpi_stats_cycles: 0.11
# Correlation between output_rate and nf_router_cycles: 0.04
# Correlation between output_rate and payload_scan_cycles: 0.01

# %%
corr = data.corr()
correlation_list = []
for i in range(2,3):
    for j in range(i+1, len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between latency and ndpi_stats_LLC-loads: 0.59
# Correlation between latency and ndpi_stats_cache-references: 0.58
# Correlation between latency and ndpi_stats_L1-dcache-load-misses: 0.57
# Correlation between latency and payload_scan_LLC-loads: 0.57
# Correlation between latency and firewall_LLC-loads: 0.56
# Correlation between latency and firewall_cache-references: 0.56
# Correlation between latency and firewall_L1-dcache-load-misses: 0.56
# Correlation between latency and payload_scan_cache-references: 0.56
# Correlation between latency and nf_router_LLC-loads: 0.56
# Correlation between latency and payload_scan_L1-dcache-load-misses: 0.56
# Correlation between latency and firewall_LLC-stores: 0.56
# Correlation between latency and nf_router_L1-dcache-loads: 0.56
# Correlation between latency and nf_router_instructions: 0.55
# Correlation between latency and nf_router_branches: 0.55
# Correlation between latency and nf_router_cache-references: 0.55
# Correlation between latency and nf_router_L1-dcache-load-misses: 0.55
# Correlation between latency and ndpi_stats_LLC-stores: 0.54
# Correlation between latency and bridge_LLC-stores: 0.54
# Correlation between latency and nf_router_LLC-stores: 0.53
# Correlation between latency and payload_scan_LLC-stores: 0.53
# Correlation between latency and bridge_L1-dcache-load-misses: 0.50
# Correlation between latency and bridge_cache-references: 0.50
# Correlation between latency and payload_scan_L1-dcache-loads: 0.48
# Correlation between latency and firewall_L1-dcache-loads: 0.48
# Correlation between latency and payload_scan_instructions: 0.48
# Correlation between latency and bridge_LLC-loads: 0.48
# Correlation between latency and firewall_instructions: 0.48
# Correlation between latency and firewall_branches: 0.48
# Correlation between latency and payload_scan_branches: 0.48
# Correlation between latency and ndpi_stats_branches: 0.47
# Correlation between latency and ndpi_stats_L1-dcache-loads: 0.47
# Correlation between latency and ndpi_stats_instructions: 0.47
# Correlation between latency and bridge_branches: 0.41
# Correlation between latency and bridge_L1-dcache-loads: 0.41
# Correlation between latency and bridge_instructions: 0.41
# Correlation between latency and ndpi_stats_cache-misses: 0.33
# Correlation between latency and nf_router_branch-misses: 0.33
# Correlation between latency and nf_router_branch-load-misses: 0.33
# Correlation between latency and firewall_branch-load-misses: 0.30
# Correlation between latency and firewall_branch-misses: 0.29
# Correlation between latency and bridge_branch-load-misses: 0.27
# Correlation between latency and bridge_branch-misses: 0.27
# Correlation between latency and nf_router_cycles: 0.25
# Correlation between latency and ndpi_stats_LLC-load-misses: 0.24
# Correlation between latency and bridge_LLC-load-misses: 0.16
# Correlation between latency and nf_router_LLC-load-misses: 0.14
# Correlation between latency and ndpi_stats_cycles: 0.14
# Correlation between latency and ndpi_stats_branch-misses: 0.14
# Correlation between latency and ndpi_stats_branch-load-misses: 0.14
# Correlation between latency and firewall_LLC-load-misses: 0.13
# Correlation between latency and nf_router_cache-misses: 0.13
# Correlation between latency and bridge_cache-misses: 0.12
# Correlation between latency and payload_scan_branch-misses: 0.10
# Correlation between latency and payload_scan_branch-load-misses: 0.10
# Correlation between latency and firewall_cache-misses: 0.09
# Correlation between latency and bridge_cycles: 0.05
# Correlation between latency and payload_scan_LLC-load-misses: 0.05
# Correlation between latency and payload_scan_cache-misses: 0.05
# Correlation between latency and firewall_cycles: 0.04
# Correlation between latency and payload_scan_cycles: 0.02

# %% [markdown]
# # Several ML algorithm to predict rate

# %%
# training  

X = df.drop(['input_rate','output_rate', 'latency','firewall_cycles','payload_scan_cycles','ndpi_stats_branch-load-misses',
             'nf_router_cycles','bridge_cycles','payload_scan_LLC-load-misses','payload_scan_LLC-load-misses','bridge_LLC-load-misses',
             'bridge_cache-misses','bridge_cache-misses','nf_router_cache-misses','firewall_cache-misses','nf_router_LLC-load-misses',
             'ndpi_stats_LLC-load-misses','nf_router_branch-load-misses','nf_router_branch-misses','payload_scan_branch-load-misses',
             'payload_scan_branch-misses','bridge_branch-misses','ndpi_stats_branch-load-misses','ndpi_stats_cache-misses','firewall_branch-misses'], axis=1)
#X = df.drop(['input_rate','output_rate', 'latency'], axis=1)
y = df['output_rate']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# ML model
model = DecisionTreeRegressor(random_state=0)
#model = LinearRegression()
#model = RandomForestRegressor(n_estimators=100, random_state=42)

# train the regressor
model.fit(X_train, y_train)
y_pred = model.predict(X_test)


# Evaluate
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

#accuracy
threshold = 0.05 
distances = [abs(real - pred) / real for real, pred in zip(y_test.values.tolist(), y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print("Accuracy within 5% threshold:", accuracy_within_threshold)


accuracy_cdf=[]
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test.values.tolist(), y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)
# Out:
# Accuracy within 5% threshold: 83.70786516853933
# [0.0, 83.70786516853933, 88.57677902621724, 91.01123595505618, 94.3820224719101, 97.00374531835206, 97.00374531835206, 97.00374531835206, 97.00374531835206, 97.75280898876404, 100.0]

# %%
# predict dataset 'dag'/ 'resource_stimulus'

# Read the CSV file
path = '../Dag/dag-1/datasets/load_stimulus_global.csv'
#path = '../linear/datasets/resource_stimulus_global.csv'
path = '../linear/datasets/random_rates_exp-1.csv'
df = pd.read_csv(path)
df = df.replace(['<not counted>'], np.nan)
df = df.dropna()

# Separate the features and target variable
X_test = df.drop(['Unnamed: 0','input_rate', 'output_rate', 'latency'], axis=1)
X_test =  df.drop(['Unnamed: 0','input_rate','output_rate', 'latency','firewall_cycles','payload_scan_cycles','ndpi_stats_branch-load-misses',
             'nf_router_cycles','bridge_cycles','payload_scan_LLC-load-misses','payload_scan_LLC-load-misses','bridge_LLC-load-misses',
             'bridge_cache-misses','bridge_cache-misses','nf_router_cache-misses','firewall_cache-misses','nf_router_LLC-load-misses',
             'ndpi_stats_LLC-load-misses','nf_router_branch-load-misses','nf_router_branch-misses','payload_scan_branch-load-misses',
             'payload_scan_branch-misses','bridge_branch-misses','ndpi_stats_branch-load-misses','ndpi_stats_cache-misses','firewall_branch-misses'], axis=1)
y_test =df['input_rate'].values


# Standardize the features
scaler = StandardScaler()
X_test = scaler.fit_transform(X_test)

# Evaluate
y_pred = model.predict(X_test)
y_pred = np.array(y_pred)
mse = mean_squared_error(y_test, y_pred)

# accuracy
threshold = 0.05
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print(f'accurancy with thoreshold 5%:{accuracy_within_threshold}')

accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)
# Out:
# accurancy with thoreshold 5%:16.180552395686398
# [0.0, 36.78846066342085, 47.20844519270146, 53.5514401419666, 57.84683987805433, 61.17759475815625, 64.33089138644948, 67.0382672794285, 69.45897984256267, 71.05610410884105, 73.14465122628202]
# C:\Users\Qiong\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
fig, ax = plt.subplots(figsize=(4,3))
plt.plot(y_pred[:300], marker='o',c='r',markersize = 1, linestyle='-', dashes=(5, 3),label='predicted data')
plt.plot(y_test[:300].tolist(), c='b',linestyle='-',linewidth = 1,label='real data')

plt.xlabel('Series',fontsize=8)
plt.ylabel('Values',fontsize=8)

plt.legend(loc="upper right", fontsize=6)
plt.grid()

# %% [markdown]
# # DNN to predict rate (training set: global)

# %%
current_dir = os.getcwd()
file_path = os.path.abspath('../DAG/dag-1/datasets/load_stimulus_global.csv')
#file_path = os.path.abspath('../linear/datasets/load_stimulus_global_4.csv')
#file_path = os.path.abspath('../linear/datasets/random_rates_exp-1.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
df = data.dropna()

# %%
# data set
# load_stimulus_global.csv: exp1_exp10
# load_stimulus_global_1.csv:exp1_exp10+fixed_5000+fixed_7500
# load_stimulus_global_2.csv:exp1_exp10+fixed_5000+fixed_7500+random
# load_stimulus_global_3.csv:exp1_exp10+random
#load_stimulus_global_4.csv:exp1_exp10+stage_random
# performance: global>3>2>1

# %%
# training 
X = df.drop(['input_rate','output_rate', 'latency'], axis=1)
X = df.drop(['input_rate','output_rate', 'latency','firewall_cycles','payload_scan_cycles','ndpi_stats_branch-load-misses',
             'nf_router_cycles','bridge_cycles','payload_scan_LLC-load-misses','payload_scan_LLC-load-misses','bridge_LLC-load-misses',
             'bridge_cache-misses','bridge_cache-misses','nf_router_cache-misses','firewall_cache-misses','nf_router_LLC-load-misses',
             'ndpi_stats_LLC-load-misses','nf_router_branch-load-misses','nf_router_branch-misses','payload_scan_branch-load-misses',
             'payload_scan_branch-misses','bridge_branch-misses','ndpi_stats_branch-load-misses','ndpi_stats_cache-misses','firewall_branch-misses'], axis=1)

y = df['output_rate']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

column_order = X_train.columns
X_test = X_test[column_order]


# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print(len(y))
# Out:
# 1776

# %%
# model
model = Sequential()

# Add input layer and hidden layers
model.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(16, activation='relu'))

# Add output layer
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=16, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 78/78 [==============================] - 1s 1ms/step - loss: 19879676.0000
# Epoch 2/100
# 78/78 [==============================] - 0s 2ms/step - loss: 3047292.5000
# Epoch 3/100
# 78/78 [==============================] - 0s 2ms/step - loss: 1727035.1250
# Epoch 4/100
# 78/78 [==============================] - 0s 5ms/step - loss: 739130.0625
# Epoch 5/100
# 78/78 [==============================] - 0s 2ms/step - loss: 522086.1562
# Epoch 6/100
# 78/78 [==============================] - 0s 2ms/step - loss: 448795.8125
# Epoch 7/100
# 78/78 [==============================] - 0s 2ms/step - loss: 391368.9375
# Epoch 8/100
# 78/78 [==============================] - 0s 2ms/step - loss: 354294.7188
# Epoch 9/100
# 78/78 [==============================] - 0s 1ms/step - loss: 329966.5312
# Epoch 10/100
# 78/78 [==============================] - 0s 2ms/step - loss: 298148.3438
# Epoch 11/100
# 78/78 [==============================] - 0s 2ms/step - loss: 277051.8750
# Epoch 12/100
# 78/78 [==============================] - 0s 2ms/step - loss: 271085.2188
# Epoch 13/100
# 78/78 [==============================] - 0s 3ms/step - loss: 262067.7656
# Epoch 14/100
# 78/78 [==============================] - 0s 3ms/step - loss: 249164.6719
# Epoch 15/100
# 78/78 [==============================] - 0s 3ms/step - loss: 234558.7656
# Epoch 16/100
# 78/78 [==============================] - 0s 4ms/step - loss: 225531.5156
# Epoch 17/100
# 78/78 [==============================] - 0s 1ms/step - loss: 217356.4844
# Epoch 18/100
# 78/78 [==============================] - 0s 2ms/step - loss: 214088.1250
# Epoch 19/100
# 78/78 [==============================] - 0s 4ms/step - loss: 215370.6250
# Epoch 20/100
# 78/78 [==============================] - 0s 4ms/step - loss: 210574.7188
# Epoch 21/100
# 78/78 [==============================] - 0s 4ms/step - loss: 199390.8750
# Epoch 22/100
# 78/78 [==============================] - 0s 2ms/step - loss: 207210.9219
# Epoch 23/100
# 78/78 [==============================] - 0s 1ms/step - loss: 198948.9844
# Epoch 24/100
# 78/78 [==============================] - 0s 1ms/step - loss: 194240.5938
# Epoch 25/100
# 78/78 [==============================] - 0s 1ms/step - loss: 203371.9219
# Epoch 26/100
# 78/78 [==============================] - 0s 2ms/step - loss: 187995.4844
dashes=(5, 3),label='Prediction')
plt.plot(y_test.tolist()[0:100], c='b',linestyle='-',linewidth = 0.8,label='Real data')


plt.legend(loc="upper right", fontsize=8)
fig.text(0.5, 0.01, 'Series', size='12', ha='center')
fig.text(0.01, 0.5, 'Values', size='12', va='center', rotation='vertical')
plt.subplots_adjust(left=0.12, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.4)
#plt.grid()
ax.set_facecolor('white')

# Set y-axis tick format
formatter = mticker.FuncFormatter(lambda x, pos: f"{int(x/1000)}")
ax.yaxis.set_major_formatter(formatter)
# Set text in the upper left corner of the figure
fig.text(0.12, 0.98, '1e3', size='12', ha='left', va='top')

#save figure
#folder_path = 'figure/rate_prediction'
#if not os.path.exists(folder_path):
#    os.makedirs(folder_path)
#file_path = os.path.join(folder_path, 'accuracy-linear.pdf' )
#plt.savefig(file_path)

plt.show()
# Out:
# 687/687 [==============================] - 1s 2ms/step
# [0.0, 39.48218592164536, 58.28821040178368, 66.49224188924785, 73.09914911043364, 78.82331528416071, 82.3724803203349, 84.45192701460617, 85.92619556809392, 86.73158301861037, 87.45051644901488]

# %%
# predict dataset 'dag-1'

# read the CSV file
path = ('../linear/datasets/random_rates_exp-1.csv')

df = pd.read_csv(path)
df = df.replace(['<not counted>'], np.nan)
df = df.dropna()

# separate the features and target variable
X_test = df.drop(['Unnamed: 0','input_rate', 'output_rate', 'latency'], axis=1)
X_test = df.drop(['Unnamed: 0','input_rate','output_rate', 'latency','firewall_cycles','payload_scan_cycles','ndpi_stats_branch-load-misses',
             'nf_router_cycles','bridge_cycles','payload_scan_LLC-load-misses','payload_scan_LLC-load-misses','bridge_LLC-load-misses',
             'bridge_cache-misses','bridge_cache-misses','nf_router_cache-misses','firewall_cache-misses','nf_router_LLC-load-misses',
             'ndpi_stats_LLC-load-misses','nf_router_branch-load-misses','nf_router_branch-misses','payload_scan_branch-load-misses',
             'payload_scan_branch-misses','bridge_branch-misses','ndpi_stats_branch-load-misses','ndpi_stats_cache-misses','firewall_branch-misses'], axis=1)
y_test =df['output_rate'].values

# standardize the features
scaler = StandardScaler()
X_test = scaler.fit_transform(X_test)

# evaluate
y_pred = model.predict(X_test)
y_pred = np.array(y_pred)
mse = mean_squared_error(y_test, y_pred)

# accuracy
threshold = 0.05
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print(f'accurancy with thoreshold 5%:{accuracy_within_threshold}')

accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot

fig, ax = plt.subplots(facecolor='white', figsize=(4,3))
#ax.set_facecolor('white')
plt.style.use('classic')

plt.plot(y_pred[400:600], marker='o', c='r',markersize = 2,linewidth = 0.8,  markeredgecolor='red', linestyle='-', dashes=(5, 3),label='Prediction')
plt.plot(y_test.tolist()[400:600], c='b',linestyle='-',linewidth = 0.8, label='Real')

plt.legend(loc="lower right", fontsize=10)
fig.text(0.5, 0.01, 'Time sequence', size='14', ha='center')
fig.text(0.01, 0.5, 'Throughput', size='14', va='center', rotation='vertical')
plt.subplots_adjust(left=0.12, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.4)
#plt.grid()
ax.set_facecolor('white')

# Set y-axis tick format
formatter = mticker.FuncFormatter(lambda x, pos: f"{int(x/1000)}")
ax.yaxis.set_major_formatter(formatter)
# Set text in the upper left corner of the figure
fig.text(0.12, 0.98, '1e3', size='12', ha='left', va='top')


#save figure
folder_path = 'figure/rate_prediction'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
file_path = os.path.join(folder_path, 'accuracy-random_rate.pdf' )
plt.savefig(file_path)

plt.show()
# Out:
# 687/687 [==============================] - 1s 1ms/step
# accurancy with thoreshold 5%:[9.72380216]
# [array([0.]), array([18.49205988]), array([45.19725167]), array([64.98157164]), array([72.04805023]), array([77.04418255]), array([80.27483278]), array([83.72389316]), array([86.57687582]), array([89.06129135]), array([92.29649179])]

# %%
# predict dataset 'linear'

# read the CSV file
path = '../linear/datasets/load_stimulus_exp4.csv'

df = pd.read_csv(path)
df = df.replace(['<not counted>'], np.nan)
df = df.dropna()

# separate the features and target variable
X_test = df.drop(['Unnamed: 0','input_rate', 'output_rate', 'latency'], axis=1)
X_test = df.drop(['Unnamed: 0','input_rate','output_rate', 'latency','firewall_cycles','payload_scan_cycles','ndpi_stats_branch-load-misses',
             'nf_router_cycles','bridge_cycles','payload_scan_LLC-load-misses','payload_scan_LLC-load-misses','bridge_LLC-load-misses',
             'bridge_cache-misses','bridge_cache-misses','nf_router_cache-misses','firewall_cache-misses','nf_router_LLC-load-misses',
             'ndpi_stats_LLC-load-misses','nf_router_branch-load-misses','nf_router_branch-misses','payload_scan_branch-load-misses',
             'payload_scan_branch-misses','bridge_branch-misses','ndpi_stats_branch-load-misses','ndpi_stats_cache-misses','firewall_branch-misses'], axis=1)
y_test =df['input_rate'].values

# standardize the features
scaler = StandardScaler()
X_test = scaler.fit_transform(X_test)

# evaluate
y_pred = model.predict(X_test)
y_pred = np.array(y_pred)
mse = mean_squared_error(y_test, y_pred)

# accuracy
threshold = 0.05
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print(f'accurancy with thoreshold 5%:{accuracy_within_threshold}')

accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot

fig, ax = plt.subplots(facecolor='white', figsize=(4,3))
#ax.set_facecolor('white')
plt.style.use('classic')

plt.plot(y_pred, marker='o', c='r',markersize = 2,linewidth = 0.8,  markeredgecolor='red', linestyle='-', dashes=(5, 3),label='Prediction')
plt.plot(y_test.tolist(), c='b',linestyle='-',linewidth = 0.8, label='Real')

plt.legend(loc="upper right", fontsize=10)
fig.text(0.5, 0, 'Time sequences', size='14', ha='center')
fig.text(0.01, 0.5, 'Throughput', size='14', va='center', rotation='vertical')
plt.subplots_adjust(left=0.12, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.4)
#plt.grid()
ax.set_facecolor('white')

# Set x-axis and y-axis limits
plt.xlim(0, 180)
plt.ylim(0, 11000)

# Set y-axis tick format
formatter = mticker.FuncFormatter(lambda x, pos: f"{int(x/1000)}")
ax.yaxis.set_major_formatter(formatter)
# Set text in the upper left corner of the figure
fig.text(0.12, 0.98, '1e3', size='12', ha='left', va='top')


#save figure
folder_path = 'figure/rate_prediction'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
file_path = os.path.join(folder_path, 'accuracy-linear-1.pdf' )
plt.savefig(file_path, bbox_inches='tight')

plt.show()
# Out:
# 6/6 [==============================] - 0s 1ms/step
# accurancy with thoreshold 5%:[7.30337079]
# [array([0.]), array([34.26966292]), array([69.1011236]), array([76.40449438]), array([78.65168539]), array([79.21348315]), array([80.8988764]), array([87.64044944]), array([88.20224719]), array([89.3258427]), array([89.3258427])]

# %%
# predict dataset 'dag-1'

# read the CSV file
path = '../Dag/dag-1/datasets/load_stimulus_exp9.csv'

df = pd.read_csv(path)
df = df.replace(['<not counted>'], np.nan)
df = df.dropna()

# separate the features and target variable
X_test = df.drop(['Unnamed: 0','input_rate', 'output_rate', 'latency'], axis=1)
X_test = df.drop(['Unnamed: 0','input_rate','output_rate', 'latency','firewall_cycles','payload_scan_cycles','ndpi_stats_branch-load-misses',
             'nf_router_cycles','bridge_cycles','payload_scan_LLC-load-misses','payload_scan_LLC-load-misses','bridge_LLC-load-misses',
             'bridge_cache-misses','bridge_cache-misses','nf_router_cache-misses','firewall_cache-misses','nf_router_LLC-load-misses',
             'ndpi_stats_LLC-load-misses','nf_router_branch-load-misses','nf_router_branch-misses','payload_scan_branch-load-misses',
             'payload_scan_branch-misses','bridge_branch-misses','ndpi_stats_branch-load-misses','ndpi_stats_cache-misses','firewall_branch-misses'], axis=1)
y_test =df['input_rate'].values

# standardize the features
scaler = StandardScaler()
X_test = scaler.fit_transform(X_test)

# evaluate
y_pred = model.predict(X_test)
y_pred = np.array(y_pred)
mse = mean_squared_error(y_test, y_pred)

# accuracy
threshold = 0.05
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print(f'accurancy with thoreshold 5%:{accuracy_within_threshold}')

accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot

fig, ax = plt.subplots(facecolor='white', figsize=(4,3))
#ax.set_facecolor('white')
plt.style.use('classic')

plt.plot(y_pred, marker='o', c='r',markersize = 2,linewidth = 0.8,  markeredgecolor='red', linestyle='-', dashes=(5, 3),label='Prediction')
plt.plot(y_test.tolist(), c='b',linestyle='-',linewidth = 0.8, label='Real')

plt.legend(loc="upper right", fontsize=10)
fig.text(0.5, 0, 'Time sequence', size='14', ha='center')
fig.text(0.01, 0.5, 'Throughput', size='14', va='center', rotation='vertical')
plt.subplots_adjust(left=0.12, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.4)
#plt.grid()
ax.set_facecolor('white')

# Set y-axis tick format
formatter = mticker.FuncFormatter(lambda x, pos: f"{int(x/1000)}")
ax.yaxis.set_major_formatter(formatter)
# Set text in the upper left corner of the figure
fig.text(0.12, 0.98, '1e3', size='12', ha='left', va='top')
ax.set_ylim(0, 12000)

#save figure
folder_path = 'figure/rate_prediction'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
file_path = os.path.join(folder_path, 'accuracy-dag-1.pdf' )
plt.savefig(file_path, bbox_inches='tight')

plt.show()
# Out:
# 6/6 [==============================] - 0s 1ms/step
# accurancy with thoreshold 5%:[57.62711864]
# [array([0.]), array([76.83615819]), array([87.57062147]), array([95.48022599]), array([96.61016949]), array([97.74011299]), array([98.30508475]), array([98.8700565]), array([98.8700565]), array([99.43502825]), array([99.43502825])]

# %%
# predict dataset 'dag-2'

# read the CSV file
path = '../Dag/dag-2/datasets/load_stimulus_exp8.csv'

df = pd.read_csv(path)
df = df.replace(['<not counted>'], np.nan)
df = df.dropna()

# separate the features and target variable
X_test = df.drop(['Unnamed: 0','input_rate', 'output_rate', 'latency'], axis=1)
X_test = df.drop(['Unnamed: 0','input_rate','output_rate', 'latency','flow_tracker_cycles','payload_scan_cycles','ndpi_stats_branch-load-misses',
             'nf_router_cycles','bridge_cycles','payload_scan_LLC-load-misses','payload_scan_LLC-load-misses','bridge_LLC-load-misses',
             'bridge_cache-misses','bridge_cache-misses','nf_router_cache-misses','flow_tracker_cache-misses','nf_router_LLC-load-misses',
             'ndpi_stats_LLC-load-misses','nf_router_branch-load-misses','nf_router_branch-misses','payload_scan_branch-load-misses',
             'payload_scan_branch-misses','bridge_branch-misses','ndpi_stats_branch-load-misses','ndpi_stats_cache-misses','flow_tracker_branch-misses'], axis=1)
y_test =df['input_rate'].values

# standardize the features
scaler = StandardScaler()
X_test = scaler.fit_transform(X_test)

# evaluate
y_pred = model.predict(X_test)
y_pred = np.array(y_pred)
mse = mean_squared_error(y_test, y_pred)

# accuracy
threshold = 0.05
distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
print(f'accurancy with thoreshold 5%:{accuracy_within_threshold}')

accuracy_cdf=[]
# plot cdf of accurancy
for threshold in range(11):
    threshold = threshold/10
    distances = [abs(real - pred) / real for real, pred in zip(y_test, y_pred)]
    accuracy_within_threshold = sum(dist <= threshold for dist in distances) / len(distances) * 100
    accuracy_cdf.append(accuracy_within_threshold)
print(accuracy_cdf)

# plot

fig, ax = plt.subplots(facecolor='white', figsize=(4,3))
#ax.set_facecolor('white')
plt.style.use('classic')

plt.plot(y_pred, marker='o',c='r',markersize = 2,linewidth = 0.8, markeredgecolor='red',  linestyle='-', dashes=(5, 3),label='Prediction')
plt.plot(y_test.tolist(), c='b',linestyle='-',linewidth = 0.8, label='Real')

plt.legend(loc="upper right", fontsize=10)
fig.text(0.5, 0.01, 'Time sequence', size='14', ha='center')
fig.text(0.01, 0.5, 'Throughput', size='14', va='center', rotation='vertical')
plt.subplots_adjust(left=0.12, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.4)
#plt.grid()
ax.set_facecolor('white')

# Set x-axis and y-axis limits
plt.xlim(0, 210)
plt.ylim(0, 11000)


# Set y-axis tick format
formatter = mticker.FuncFormatter(lambda x, pos: f"{int(x/1000)}")
ax.yaxis.set_major_formatter(formatter)
# Set text in the upper left corner of the figure
fig.text(0.12, 0.98, '1e3', size='12', ha='left', va='top')



#save figure
folder_path = 'figure/rate_prediction'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
file_path = os.path.join(folder_path, 'accuracy-dag-2.pdf' )
plt.savefig(file_path, bbox_inches='tight')

plt.show()
# Out:
# 7/7 [==============================] - 0s 2ms/step
# accurancy with thoreshold 5%:[15.38461538]
# [array([0.]), array([46.15384615]), array([85.09615385]), array([91.34615385]), array([93.26923077]), array([96.15384615]), array([99.51923077]), array([99.51923077]), array([99.51923077]), array([99.51923077]), array([99.51923077])]
