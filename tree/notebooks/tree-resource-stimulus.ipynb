# %%
import sys, re, os
import numpy as np
import pandas as pd

# %%
# Change the work directory to the parent
try:
    if chdir:
        pass
except:
    current_dir = os.getcwd()
    os.chdir(current_dir +"/..")
    os.path.abspath(os.curdir)

# %%
chdir = True

# %%
import zipfile

def unzip_file(zip_file_path, destination_folder):
    with zipfile.ZipFile(zip_file_path, 'r') as files:
        files.extractall(destination_folder)

# %%
load_stimulus_global = pd.DataFrame()
file_names = []

for i in range(3, 8):
    for j in [1,3]:
        for k in range(1,6):
            item = 'resource_stimulus_exp-{}-{}-{}.csv'.format(i,j,k)
            file_names.append(item)

file_names.remove('resource_stimulus_exp-3-1-1.csv')
print(file_names)
# Out:
# ['resource_stimulus_exp-3-1-2.csv', 'resource_stimulus_exp-3-1-3.csv', 'resource_stimulus_exp-3-1-4.csv', 'resource_stimulus_exp-3-1-5.csv', 'resource_stimulus_exp-3-3-1.csv', 'resource_stimulus_exp-3-3-2.csv', 'resource_stimulus_exp-3-3-3.csv', 'resource_stimulus_exp-3-3-4.csv', 'resource_stimulus_exp-3-3-5.csv', 'resource_stimulus_exp-4-1-1.csv', 'resource_stimulus_exp-4-1-2.csv', 'resource_stimulus_exp-4-1-3.csv', 'resource_stimulus_exp-4-1-4.csv', 'resource_stimulus_exp-4-1-5.csv', 'resource_stimulus_exp-4-3-1.csv', 'resource_stimulus_exp-4-3-2.csv', 'resource_stimulus_exp-4-3-3.csv', 'resource_stimulus_exp-4-3-4.csv', 'resource_stimulus_exp-4-3-5.csv', 'resource_stimulus_exp-5-1-1.csv', 'resource_stimulus_exp-5-1-2.csv', 'resource_stimulus_exp-5-1-3.csv', 'resource_stimulus_exp-5-1-4.csv', 'resource_stimulus_exp-5-1-5.csv', 'resource_stimulus_exp-5-3-1.csv', 'resource_stimulus_exp-5-3-2.csv', 'resource_stimulus_exp-5-3-3.csv', 'resource_stimulus_exp-5-3-4.csv', 'resource_stimulus_exp-5-3-5.csv', 'resource_stimulus_exp-6-1-1.csv', 'resource_stimulus_exp-6-1-2.csv', 'resource_stimulus_exp-6-1-3.csv', 'resource_stimulus_exp-6-1-4.csv', 'resource_stimulus_exp-6-1-5.csv', 'resource_stimulus_exp-6-3-1.csv', 'resource_stimulus_exp-6-3-2.csv', 'resource_stimulus_exp-6-3-3.csv', 'resource_stimulus_exp-6-3-4.csv', 'resource_stimulus_exp-6-3-5.csv', 'resource_stimulus_exp-7-1-1.csv', 'resource_stimulus_exp-7-1-2.csv', 'resource_stimulus_exp-7-1-3.csv', 'resource_stimulus_exp-7-1-4.csv', 'resource_stimulus_exp-7-1-5.csv', 'resource_stimulus_exp-7-3-1.csv', 'resource_stimulus_exp-7-3-2.csv', 'resource_stimulus_exp-7-3-3.csv', 'resource_stimulus_exp-7-3-4.csv', 'resource_stimulus_exp-7-3-5.csv']

# %%
# Read the combined DataFrame from the CSV file
file_path = os.path.abspath('../tree/datasets/resource_stimulus_global.csv')
data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)
df = data.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3193 entries, 0 to 45
# Data columns (total 51 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   input_rate                          3193 non-null   float64
#  1   output_rate                         3193 non-null   float64
#  2   latency                             3193 non-null   float64
#  3   flow_tracker_instructions           3193 non-null   float64
#  4   nf_router_instructions              3193 non-null   float64
#  5   ndpi_stats_instructions             3193 non-null   float64
#  6   payload_scan_instructions           3193 non-null   float64
#  7   flow_tracker_branches               3193 non-null   float64
#  8   nf_router_branches                  3193 non-null   float64
#  9   ndpi_stats_branches                 3193 non-null   float64
#  10  payload_scan_branches               3193 non-null   float64
#  11  flow_tracker_branch-misses          3193 non-null   float64
#  12  nf_router_branch-misses             3193 non-null   float64
#  13  ndpi_stats_branch-misses            3193 non-null   float64
#  14  payload_scan_branch-misses          3193 non-null   float64
#  15  flow_tracker_branch-load-misses     3193 non-null   float64
#  16  nf_router_branch-load-misses        3193 non-null   float64
#  17  ndpi_stats_branch-load-misses       3193 non-null   float64
#  18  payload_scan_branch-load-misses     3193 non-null   float64
#  19  flow_tracker_cache-misses           3193 non-null   float64
#  20  nf_router_cache-misses              3193 non-null   float64
#  21  ndpi_stats_cache-misses             3193 non-null   float64
#  22  payload_scan_cache-misses           3193 non-null   float64
#  23  flow_tracker_cache-references       3193 non-null   float64
#  24  nf_router_cache-references          3193 non-null   float64
#  25  ndpi_stats_cache-references         3193 non-null   float64
#  26  payload_scan_cache-references       3193 non-null   float64
#  27  flow_tracker_cycles                 3193 non-null   float64
#  28  nf_router_cycles                    3193 non-null   float64
#  29  ndpi_stats_cycles                   3193 non-null   float64
#  30  payload_scan_cycles                 3193 non-null   float64
#  31  flow_tracker_L1-dcache-load-misses  3193 non-null   float64
#  32  nf_router_L1-dcache-load-misses     3193 non-null   float64
#  33  ndpi_stats_L1-dcache-load-misses    3193 non-null   float64
#  34  payload_scan_L1-dcache-load-misses  3193 non-null   float64
#  35  flow_tracker_L1-dcache-loads        3193 non-null   float64
#  36  nf_router_L1-dcache-loads           3193 non-null   float64
#  37  ndpi_stats_L1-dcache-loads          3193 non-null   float64
#  38  payload_scan_L1-dcache-loads        3193 non-null   float64
#  39  flow_tracker_LLC-load-misses        3193 non-null   float64
#  40  nf_router_LLC-load-misses           3193 non-null   float64
#  41  ndpi_stats_LLC-load-misses          3193 non-null   float64
#  42  payload_scan_LLC-load-misses        3193 non-null   float64
#  43  flow_tracker_LLC-stores             3193 non-null   float64
#  44  nf_router_LLC-stores                3193 non-null   float64
#  45  ndpi_stats_LLC-stores               3193 non-null   float64
#  46  payload_scan_LLC-stores             3193 non-null   float64
#  47  flow_tracker_LLC-loads              3193 non-null   float64
#  48  nf_router_LLC-loads                 3193 non-null   float64
#  49  ndpi_stats_LLC-loads                3193 non-null   float64
#  50  payload_scan_LLC-loads              3193 non-null   float64
# dtypes: float64(51)
# memory usage: 1.3 MB

# %%
# heatmap
import matplotlib.pyplot as plt
import seaborn as sns   
corr = df.corr()
plt.figure()
sns.heatmap(corr, cmap="coolwarm", annot=False, fmt=".2f")
plt.show()

# %%
corr = data.corr()
correlation_list = []
for i in range(1,2):
    for j in range(i+1, len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between output_rate and nf_router_LLC-stores: 0.64
# Correlation between output_rate and nf_router_L1-dcache-load-misses: 0.63
# Correlation between output_rate and nf_router_cache-references: 0.63
# Correlation between output_rate and nf_router_LLC-loads: 0.62
# Correlation between output_rate and nf_router_branch-misses: 0.57
# Correlation between output_rate and nf_router_branch-load-misses: 0.57
# Correlation between output_rate and nf_router_cycles: 0.57
# Correlation between output_rate and nf_router_instructions: 0.57
# Correlation between output_rate and nf_router_branches: 0.56
# Correlation between output_rate and nf_router_L1-dcache-loads: 0.56
# Correlation between output_rate and flow_tracker_LLC-loads: 0.51
# Correlation between output_rate and payload_scan_cache-references: 0.51
# Correlation between output_rate and flow_tracker_L1-dcache-load-misses: 0.51
# Correlation between output_rate and ndpi_stats_L1-dcache-load-misses: 0.51
# Correlation between output_rate and payload_scan_L1-dcache-load-misses: 0.51
# Correlation between output_rate and payload_scan_LLC-loads: 0.51
# Correlation between output_rate and flow_tracker_cache-references: 0.50
# Correlation between output_rate and ndpi_stats_LLC-loads: 0.50
# Correlation between output_rate and ndpi_stats_cache-references: 0.50
# Correlation between output_rate and payload_scan_LLC-stores: 0.49
# Correlation between output_rate and ndpi_stats_LLC-stores: 0.46
# Correlation between output_rate and flow_tracker_LLC-stores: 0.46
# Correlation between output_rate and latency: 0.31
# Correlation between output_rate and nf_router_cache-misses: 0.15
# Correlation between output_rate and nf_router_LLC-load-misses: 0.12
# Correlation between output_rate and payload_scan_cycles: 0.10
# Correlation between output_rate and payload_scan_branch-load-misses: 0.09
# Correlation between output_rate and payload_scan_branch-misses: 0.09
# Correlation between output_rate and payload_scan_cache-misses: 0.07
# Correlation between output_rate and payload_scan_branches: 0.07
# Correlation between output_rate and payload_scan_instructions: 0.07
# Correlation between output_rate and payload_scan_L1-dcache-loads: 0.07
# Correlation between output_rate and ndpi_stats_cache-misses: 0.07
# Correlation between output_rate and flow_tracker_cache-misses: 0.05
# Correlation between output_rate and ndpi_stats_cycles: 0.03
# Correlation between output_rate and ndpi_stats_L1-dcache-loads: 0.02
# Correlation between output_rate and flow_tracker_cycles: 0.02
# Correlation between output_rate and ndpi_stats_branches: 0.02
# Correlation between output_rate and ndpi_stats_instructions: 0.02
# Correlation between output_rate and flow_tracker_L1-dcache-loads: 0.02
# Correlation between output_rate and flow_tracker_LLC-load-misses: 0.02
# Correlation between output_rate and flow_tracker_branches: 0.01
# Correlation between output_rate and flow_tracker_instructions: 0.01
# Correlation between output_rate and payload_scan_LLC-load-misses: 0.01
# Correlation between output_rate and ndpi_stats_LLC-load-misses: 0.01
# Correlation between output_rate and flow_tracker_branch-misses: 0.00
# Correlation between output_rate and flow_tracker_branch-load-misses: 0.00
# Correlation between output_rate and ndpi_stats_branch-misses: 0.00
# Correlation between output_rate and ndpi_stats_branch-load-misses: 0.00

# %%
corr = data.corr()
correlation_list = []
for i in range(2,3):
    for j in range(len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))


sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)

for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between latency and latency: 1.00
# Correlation between latency and ndpi_stats_LLC-stores: 0.57
# Correlation between latency and ndpi_stats_cache-references: 0.53
# Correlation between latency and ndpi_stats_L1-dcache-load-misses: 0.53
# Correlation between latency and ndpi_stats_LLC-loads: 0.49
# Correlation between latency and nf_router_LLC-loads: 0.37
# Correlation between latency and nf_router_L1-dcache-load-misses: 0.37
# Correlation between latency and nf_router_cache-references: 0.37
# Correlation between latency and nf_router_LLC-stores: 0.37
# Correlation between latency and nf_router_cycles: 0.37
# Correlation between latency and nf_router_L1-dcache-loads: 0.36
# Correlation between latency and nf_router_branch-load-misses: 0.36
# Correlation between latency and nf_router_branches: 0.36
# Correlation between latency and nf_router_branch-misses: 0.36
# Correlation between latency and nf_router_instructions: 0.36
# Correlation between latency and flow_tracker_LLC-loads: 0.31
# Correlation between latency and output_rate: 0.31
# Correlation between latency and flow_tracker_cache-references: 0.28
# Correlation between latency and ndpi_stats_cycles: 0.28
# Correlation between latency and flow_tracker_L1-dcache-load-misses: 0.28
# Correlation between latency and ndpi_stats_branch-misses: 0.26
# Correlation between latency and ndpi_stats_branch-load-misses: 0.26
# Correlation between latency and ndpi_stats_L1-dcache-loads: 0.25
# Correlation between latency and ndpi_stats_branches: 0.24
# Correlation between latency and ndpi_stats_instructions: 0.24
# Correlation between latency and payload_scan_LLC-loads: 0.20
# Correlation between latency and payload_scan_cache-references: 0.18
# Correlation between latency and flow_tracker_LLC-stores: 0.18
# Correlation between latency and payload_scan_L1-dcache-load-misses: 0.17
# Correlation between latency and ndpi_stats_LLC-load-misses: 0.15
# Correlation between latency and payload_scan_LLC-stores: 0.14
# Correlation between latency and ndpi_stats_cache-misses: 0.12
# Correlation between latency and payload_scan_instructions: 0.09
# Correlation between latency and payload_scan_L1-dcache-loads: 0.09
# Correlation between latency and payload_scan_branches: 0.09
# Correlation between latency and nf_router_LLC-load-misses: 0.09
# Correlation between latency and payload_scan_branch-misses: 0.08
# Correlation between latency and payload_scan_branch-load-misses: 0.08
# Correlation between latency and flow_tracker_instructions: 0.08
# Correlation between latency and flow_tracker_branches: 0.08
# Correlation between latency and flow_tracker_L1-dcache-loads: 0.07
# Correlation between latency and payload_scan_cycles: 0.07
# Correlation between latency and nf_router_cache-misses: 0.07
# Correlation between latency and flow_tracker_branch-load-misses: 0.06
# Correlation between latency and flow_tracker_branch-misses: 0.06
# Correlation between latency and input_rate: 0.06
# Correlation between latency and payload_scan_cache-misses: 0.06
# Correlation between latency and flow_tracker_cycles: 0.05
# Correlation between latency and flow_tracker_cache-misses: 0.04
# Correlation between latency and payload_scan_LLC-load-misses: 0.03
# Correlation between latency and flow_tracker_LLC-load-misses: 0.03

# %%
data = data.reset_index(drop=True)
data
data.iloc[:, :3].plot(logy=True)
# Out:
# <Axes: >

# %%
# the input-rate is fixed, thus no relationship between input-rate and cpu feature
